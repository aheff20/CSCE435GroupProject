# %% [markdown]
# # FINAL PROJECT THICKET

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

print("done")
# Out:
# done

# %% [markdown]
# Read in all the files

# %% [markdown]
# # MPI Thicket Variables

# %%
mpi_strong_random_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/strong/random/*.cali"))
mpi_strong_reverse_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/strong/reverse/*.cali"))
mpi_strong_perturbed_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/strong/perturbed/*.cali"))
mpi_strong_sorted_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/strong/sorted/*.cali"))
mpi_weak_random_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/weak/random/*.cali"))
mpi_weak_reverse_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/weak/reverse/*.cali"))
mpi_weak_perturbed_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/weak/perturbed/*.cali"))
mpi_weak_sorted_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/weak/sorted/*.cali"))

# %% [markdown]
# # CUDA Thicket Variables

# %%
cuda_strong_random_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/strong/random/*.cali"))
cuda_strong_reverse_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/strong/reverse/*.cali"))
cuda_strong_perturbed_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/strong/perturbed/*.cali"))
cuda_strong_sorted_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/strong/sorted/*.cali"))
cuda_weak_random_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/weak/random/*.cali"))
cuda_weak_reverse_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/weak/reverse/*.cali"))
cuda_weak_perturbed_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/weak/perturbed/*.cali"))
cuda_weak_sorted_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/weak/sorted/*.cali"))

cuda_su_strong_random_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/speed_up_strong/random/*.cali"))
cuda_su_strong_reverse_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/speed_up_strong/reverse/*.cali"))
cuda_su_strong_perturbed_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/speed_up_strong/perturbed/*.cali"))
cuda_su_strong_sorted_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/speed_up_strong/sorted/*.cali"))

# %%
tks = {}

tks["cuda_weak_sorted"] = cuda_weak_sorted_tk
tks["cuda_weak_reverse"] = cuda_weak_reverse_tk
tks["cuda_weak_random"] = cuda_weak_random_tk
tks["cuda_weak_perturbed"] = cuda_weak_perturbed_tk

tks["cuda_strong_sorted"] = cuda_strong_sorted_tk
tks["cuda_strong_reverse"] = cuda_strong_reverse_tk
tks["cuda_strong_random"] = cuda_strong_random_tk
tks["cuda_strong_perturbed"] = cuda_strong_perturbed_tk

tks["cuda_su_strong_sorted"] = cuda_su_strong_sorted_tk
tks["cuda_su_strong_reverse"] = cuda_su_strong_reverse_tk
tks["cuda_su_strong_random"] = cuda_su_strong_random_tk
tks["cuda_su_strong_perturbed"] = cuda_su_strong_perturbed_tk

tks["mpi_weak_sorted"] = mpi_weak_sorted_tk
tks["mpi_weak_reverse"] = mpi_weak_reverse_tk
tks["mpi_weak_random"] = mpi_weak_random_tk
tks["mpi_weak_perturbed"] = mpi_weak_perturbed_tk

tks["mpi_strong_sorted"] = mpi_strong_sorted_tk
tks["mpi_strong_reverse"] = mpi_strong_reverse_tk
tks["mpi_strong_random"] = mpi_strong_random_tk
tks["mpi_strong_perturbed"] = mpi_strong_perturbed_tk

# %%
# Performance data
tks["cuda_strong_random"].dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              510540058     1
#                                                   750582785     1
#                                                   1416753650    1
#                                                   2834938187    1
#                                                   3847507659    1
# {'name': 'comm', 'type': 'function'}              510540058     3
#                                                   750582785     3
#                                                   1416753650    3
#                                                   2834938187    3
#                                                   3847507659    3
# {'name': 'comm_large', 'type': 'function'}        510540058     4
#                                                   750582785     4
#                                                   1416753650    4
#                                                   2834938187    4
#                                                   3847507659    4
# {'name': 'comm_small', 'type': 'function'}        510540058     7
#                                                   750582785     7
#                                                   1416753650    7
#                                                   2834938187    7
#                                                   3847507659    7
# {'name': 'comp', 'type': 'function'}              510540058     5
#                                                   750582785     5
#                                                   1416753650    5
#                                                   2834938187    5
#                                                   3847507659    5
# {'name': 'comp_large', 'type': 'function'}        510540058     6
#                                                   750582785     6
#                                                   1416753650    6
#                                                   2834938187    6
#                                                   3847507659    6
# {'name': 'comp_small', 'type': 'function'}        510540058     8
#                                                   750582785     8
#                                                   1416753650    8
#                                                   2834938187    8
#                                                   3847507659    8
# {'name': 'correctness_check', 'type': 'function'} 510540058     9
#                                                   750582785     9
#                                                   1416753650    9
#                                                   2834938187    9
#                                                   3847507659    9
# {'name': 'data_init', 'type': 'function'}         510540058     2
#                                                   750582785     2
#                                                   1416753650    2
#                                                   2834938187    2
#                                                   3847507659    2
#
#                                                                spot.channel  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              510540058   regionprofile
#                                                   750582785   regionprofile
#                                                   1416753650  regionprofile
#                                                   2834938187  regionprofile
#                                                   3847507659  regionprofile
# {'name': 'comm', 'type': 'function'}              510540058   regionprofile
#                                                   750582785   regionprofile
#                                                   1416753650  regionprofile
#                                                   2834938187  regionprofile
#                                                   3847507659  regionprofile
# {'name': 'comm_large', 'type': 'function'}        510540058   regionprofile
#                                                   750582785   regionprofile
#                                                   1416753650  regionprofile
#                                                   2834938187  regionprofile
#                                                   3847507659  regionprofile
# {'name': 'comm_small', 'type': 'function'}        510540058   regionprofile
#                                                   750582785   regionprofile
#                                                   1416753650  regionprofile
#                                                   2834938187  regionprofile
#                                                   3847507659  regionprofile
# {'name': 'comp', 'type': 'function'}              510540058   regionprofile
#                                                   750582785   regionprofile
#                                                   1416753650  regionprofile
#                                                   2834938187  regionprofile
#                                                   3847507659  regionprofile
# {'name': 'comp_large', 'type': 'function'}        510540058   regionprofile
#                                                   750582785   regionprofile
#                                                   1416753650  regionprofile
#                                                   2834938187  regionprofile
#                                                   3847507659  regionprofile
# {'name': 'comp_small', 'type': 'function'}        510540058   regionprofile
#                                                   750582785   regionprofile
#                                                   1416753650  regionprofile
#                                                   2834938187  regionprofile
#                                                   3847507659  regionprofile
# {'name': 'correctness_check', 'type': 'function'} 510540058   regionprofile
#                                                   750582785   regionprofile
#                                                   1416753650  regionprofile
#                                                   2834938187  regionprofile
#                                                   3847507659  regionprofile
# {'name': 'data_init', 'type': 'function'}         510540058   regionprofile
#                                                   750582785   regionprofile
#                                                   1416753650  regionprofile
#                                                   2834938187  regionprofile
#                                                   3847507659  regionprofile
#
#                                                               Min time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              510540058        0.392961
#                                                   750582785        0.393480
#                                                   1416753650       0.543705
#                                                   2834938187       0.383923
#                                                   3847507659       0.379103
# {'name': 'comm', 'type': 'function'}              510540058        0.000317
#                                                   750582785        0.000344
#                                                   1416753650       0.000307
#                                                   2834938187       0.000321
#                                                   3847507659       0.000320
# {'name': 'comm_large', 'type': 'function'}        510540058        0.000231
#                                                   750582785        0.000256
#                                                   1416753650       0.000215
#                                                   2834938187       0.000235
#                                                   3847507659       0.000232
# {'name': 'comm_small', 'type': 'function'}        510540058        0.000007
#                                                   750582785        0.000009
#                                                   1416753650       0.000008
#                                                   2834938187       0.000007
#                                                   3847507659       0.000008
# {'name': 'comp', 'type': 'function'}              510540058        0.031697
#                                                   750582785        0.031550
#                                                   1416753650       0.021258
#                                                   2834938187       0.029330
#                                                   3847507659       0.031281
# {'name': 'comp_large', 'type': 'function'}        510540058        0.031665
#                                                   750582785        0.031514
#                                                   1416753650       0.021223
#                                                   2834938187       0.029297
#                                                   3847507659       0.031246
# {'name': 'comp_small', 'type': 'function'}        510540058        0.000005
#                                                   750582785        0.000006
#                                                   1416753650       0.000006
#                                                   2834938187       0.000005
#                                                   3847507659       0.000006
# {'name': 'correctness_check', 'type': 'function'} 510540058        0.000202
#                                                   750582785        0.000205
#                                                   1416753650       0.000205
#                                                   2834938187       0.000209
#                                                   3847507659       0.000207
# {'name': 'data_init', 'type': 'function'}         510540058        0.001729
#                                                   750582785        0.001551
#                                                   1416753650       0.001519
#                                                   2834938187       0.001533
#                                                   3847507659       0.001545
#
#                                                               Max time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              510540058        0.392961
#                                                   750582785        0.393480
#                                                   1416753650       0.543705
#                                                   2834938187       0.383923
#                                                   3847507659       0.379103
# {'name': 'comm', 'type': 'function'}              510540058        0.000317
#                                                   750582785        0.000344
#                                                   1416753650       0.000307
#                                                   2834938187       0.000321
#                                                   3847507659       0.000320
# {'name': 'comm_large', 'type': 'function'}        510540058        0.000231
#                                                   750582785        0.000256
#                                                   1416753650       0.000215
#                                                   2834938187       0.000235
#                                                   3847507659       0.000232
# {'name': 'comm_small', 'type': 'function'}        510540058        0.000007
#                                                   750582785        0.000009
#                                                   1416753650       0.000008
#                                                   2834938187       0.000007
#                                                   3847507659       0.000008
# {'name': 'comp', 'type': 'function'}              510540058        0.031697
#                                                   750582785        0.031550
#                                                   1416753650       0.021258
#                                                   2834938187       0.029330
#                                                   3847507659       0.031281
# {'name': 'comp_large', 'type': 'function'}        510540058        0.031665
#                                                   750582785        0.031514
#                                                   1416753650       0.021223
#                                                   2834938187       0.029297
#                                                   3847507659       0.031246
# {'name': 'comp_small', 'type': 'function'}        510540058        0.000005
#                                                   750582785        0.000006
#                                                   1416753650       0.000006
#                                                   2834938187       0.000005
#                                                   3847507659       0.000006
# {'name': 'correctness_check', 'type': 'function'} 510540058        0.000202
#                                                   750582785        0.000205
#                                                   1416753650       0.000205
#                                                   2834938187       0.000209
#                                                   3847507659       0.000207
# {'name': 'data_init', 'type': 'function'}         510540058        0.001729
#                                                   750582785        0.001551
#                                                   1416753650       0.001519
#                                                   2834938187       0.001533
#                                                   3847507659       0.001545
#
#                                                               Avg time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              510540058        0.392961
#                                                   750582785        0.393480
#                                                   1416753650       0.543705
#                                                   2834938187       0.383923
#                                                   3847507659       0.379103
# {'name': 'comm', 'type': 'function'}              510540058        0.000317
#                                                   750582785        0.000344
#                                                   1416753650       0.000307
#                                                   2834938187       0.000321
#                                                   3847507659       0.000320
# {'name': 'comm_large', 'type': 'function'}        510540058        0.000231
#                                                   750582785        0.000256
#                                                   1416753650       0.000215
#                                                   2834938187       0.000235
#                                                   3847507659       0.000232
# {'name': 'comm_small', 'type': 'function'}        510540058        0.000007
#                                                   750582785        0.000009
#                                                   1416753650       0.000008
#                                                   2834938187       0.000007
#                                                   3847507659       0.000008
# {'name': 'comp', 'type': 'function'}              510540058        0.031697
#                                                   750582785        0.031550
#                                                   1416753650       0.021258
#                                                   2834938187       0.029330
#                                                   3847507659       0.031281
# {'name': 'comp_large', 'type': 'function'}        510540058        0.031665
#                                                   750582785        0.031514
#                                                   1416753650       0.021223
#                                                   2834938187       0.029297
#                                                   3847507659       0.031246
# {'name': 'comp_small', 'type': 'function'}        510540058        0.000005
#                                                   750582785        0.000006
#                                                   1416753650       0.000006
#                                                   2834938187       0.000005
#                                                   3847507659       0.000006
# {'name': 'correctness_check', 'type': 'function'} 510540058        0.000202
#                                                   750582785        0.000205
#                                                   1416753650       0.000205
#                                                   2834938187       0.000209
#                                                   3847507659       0.000207
# {'name': 'data_init', 'type': 'function'}         510540058        0.001729
#                                                   750582785        0.001551
#                                                   1416753650       0.001519
#                                                   2834938187       0.001533
#                                                   3847507659       0.001545
#
#                                                               Total time  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              510540058     0.392961
#                                                   750582785     0.393480
#                                                   1416753650    0.543705
#                                                   2834938187    0.383923
#                                                   3847507659    0.379103
# {'name': 'comm', 'type': 'function'}              510540058     0.000317
#                                                   750582785     0.000344
#                                                   1416753650    0.000307
#                                                   2834938187    0.000321
#                                                   3847507659    0.000320
# {'name': 'comm_large', 'type': 'function'}        510540058     0.000231
#                                                   750582785     0.000256
#                                                   1416753650    0.000215
#                                                   2834938187    0.000235
#                                                   3847507659    0.000232
# {'name': 'comm_small', 'type': 'function'}        510540058     0.000007
#                                                   750582785     0.000009
#                                                   1416753650    0.000008
#                                                   2834938187    0.000007
#                                                   3847507659    0.000008
# {'name': 'comp', 'type': 'function'}              510540058     0.031697
#                                                   750582785     0.031550
#                                                   1416753650    0.021258
#                                                   2834938187    0.029330
#                                                   3847507659    0.031281
# {'name': 'comp_large', 'type': 'function'}        510540058     0.031665
#                                                   750582785     0.031514
#                                                   1416753650    0.021223
#                                                   2834938187    0.029297
#                                                   3847507659    0.031246
# {'name': 'comp_small', 'type': 'function'}        510540058     0.000005
#                                                   750582785     0.000006
#                                                   1416753650    0.000006
#                                                   2834938187    0.000005
#                                                   3847507659    0.000006
# {'name': 'correctness_check', 'type': 'function'} 510540058     0.000202
#                                                   750582785     0.000205
#                                                   1416753650    0.000205
#                                                   2834938187    0.000209
#                                                   3847507659    0.000207
# {'name': 'data_init', 'type': 'function'}         510540058     0.001729
#                                                   750582785     0.001551
#                                                   1416753650    0.001519
#                                                   2834938187    0.001533
#                                                   3847507659    0.001545
#
#                                                               Avg GPU time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              510540058            0.031391
#                                                   750582785            0.031218
#                                                   1416753650           0.021012
#                                                   2834938187           0.029042
#                                                   3847507659           0.031017
# {'name': 'comm', 'type': 'function'}              510540058            0.000047
#                                                   750582785            0.000048
#                                                   1416753650           0.000046
#                                                   2834938187           0.000047
#                                                   3847507659           0.000048
# {'name': 'comm_large', 'type': 'function'}        510540058            0.000047
#                                                   750582785            0.000048
#                                                   1416753650           0.000046
#                                                   2834938187           0.000047
#                                                   3847507659           0.000048
# {'name': 'comm_small', 'type': 'function'}        510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
# {'name': 'comp', 'type': 'function'}              510540058            0.031344
#                                                   750582785            0.031170
#                                                   1416753650           0.020966
#                                                   2834938187           0.028995
#                                                   3847507659           0.030969
# {'name': 'comp_large', 'type': 'function'}        510540058            0.031344
#                                                   750582785            0.031170
#                                                   1416753650           0.020966
#                                                   2834938187           0.028995
#                                                   3847507659           0.030969
# {'name': 'comp_small', 'type': 'function'}        510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
# {'name': 'correctness_check', 'type': 'function'} 510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
# {'name': 'data_init', 'type': 'function'}         510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
#
#                                                               Min GPU time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              510540058            0.031391
#                                                   750582785            0.031218
#                                                   1416753650           0.021012
#                                                   2834938187           0.029042
#                                                   3847507659           0.031017
# {'name': 'comm', 'type': 'function'}              510540058            0.000047
#                                                   750582785            0.000048
#                                                   1416753650           0.000046
#                                                   2834938187           0.000047
#                                                   3847507659           0.000048
# {'name': 'comm_large', 'type': 'function'}        510540058            0.000047
#                                                   750582785            0.000048
#                                                   1416753650           0.000046
#                                                   2834938187           0.000047
#                                                   3847507659           0.000048
# {'name': 'comm_small', 'type': 'function'}        510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
# {'name': 'comp', 'type': 'function'}              510540058            0.031344
#                                                   750582785            0.031170
#                                                   1416753650           0.020966
#                                                   2834938187           0.028995
#                                                   3847507659           0.030969
# {'name': 'comp_large', 'type': 'function'}        510540058            0.031344
#                                                   750582785            0.031170
#                                                   1416753650           0.020966
#                                                   2834938187           0.028995
#                                                   3847507659           0.030969
# {'name': 'comp_small', 'type': 'function'}        510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
# {'name': 'correctness_check', 'type': 'function'} 510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
# {'name': 'data_init', 'type': 'function'}         510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
#
#                                                               Max GPU time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              510540058            0.031391
#                                                   750582785            0.031218
#                                                   1416753650           0.021012
#                                                   2834938187           0.029042
#                                                   3847507659           0.031017
# {'name': 'comm', 'type': 'function'}              510540058            0.000047
#                                                   750582785            0.000048
#                                                   1416753650           0.000046
#                                                   2834938187           0.000047
#                                                   3847507659           0.000048
# {'name': 'comm_large', 'type': 'function'}        510540058            0.000047
#                                                   750582785            0.000048
#                                                   1416753650           0.000046
#                                                   2834938187           0.000047
#                                                   3847507659           0.000048
# {'name': 'comm_small', 'type': 'function'}        510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
# {'name': 'comp', 'type': 'function'}              510540058            0.031344
#                                                   750582785            0.031170
#                                                   1416753650           0.020966
#                                                   2834938187           0.028995
#                                                   3847507659           0.030969
# {'name': 'comp_large', 'type': 'function'}        510540058            0.031344
#                                                   750582785            0.031170
#                                                   1416753650           0.020966
#                                                   2834938187           0.028995
#                                                   3847507659           0.030969
# {'name': 'comp_small', 'type': 'function'}        510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
# {'name': 'correctness_check', 'type': 'function'} 510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
# {'name': 'data_init', 'type': 'function'}         510540058                 NaN
#                                                   750582785                 NaN
#                                                   1416753650                NaN
#                                                   2834938187                NaN
#                                                   3847507659                NaN
#
#                                                               Total GPU time  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              510540058         0.031391
#                                                   750582785         0.031218
#                                                   1416753650        0.021012
#                                                   2834938187        0.029042
#                                                   3847507659        0.031017
# {'name': 'comm', 'type': 'function'}              510540058         0.000047
#                                                   750582785         0.000048
#                                                   1416753650        0.000046
#                                                   2834938187        0.000047
#                                                   3847507659        0.000048
# {'name': 'comm_large', 'type': 'function'}        510540058         0.000047
#                                                   750582785         0.000048
#                                                   1416753650        0.000046
#                                                   2834938187        0.000047
#                                                   3847507659        0.000048
# {'name': 'comm_small', 'type': 'function'}        510540058              NaN
#                                                   750582785              NaN
#                                                   1416753650             NaN
#                                                   2834938187             NaN
#                                                   3847507659             NaN
# {'name': 'comp', 'type': 'function'}              510540058         0.031344
#                                                   750582785         0.031170
#                                                   1416753650        0.020966
#                                                   2834938187        0.028995
#                                                   3847507659        0.030969
# {'name': 'comp_large', 'type': 'function'}        510540058         0.031344
#                                                   750582785         0.031170
#                                                   1416753650        0.020966
#                                                   2834938187        0.028995
#                                                   3847507659        0.030969
# {'name': 'comp_small', 'type': 'function'}        510540058              NaN
#                                                   750582785              NaN
#                                                   1416753650             NaN
#                                                   2834938187             NaN
#                                                   3847507659             NaN
# {'name': 'correctness_check', 'type': 'function'} 510540058              NaN
#                                                   750582785              NaN
#                                                   1416753650             NaN
#                                                   2834938187             NaN
#                                                   3847507659             NaN
# {'name': 'data_init', 'type': 'function'}         510540058              NaN
#                                                   750582785              NaN
#                                                   1416753650             NaN
#                                                   2834938187             NaN
#                                                   3847507659             NaN
#
#                                                                            name
# node                                              profile
# {'name': 'main', 'type': 'function'}              510540058                main
#                                                   750582785                main
#                                                   1416753650               main
#                                                   2834938187               main
#                                                   3847507659               main
# {'name': 'comm', 'type': 'function'}              510540058                comm
#                                                   750582785                comm
#                                                   1416753650               comm
#                                                   2834938187               comm
#                                                   3847507659               comm
# {'name': 'comm_large', 'type': 'function'}        510540058          comm_large
#                                                   750582785          comm_large
#                                                   1416753650         comm_large
#                                                   2834938187         comm_large
#                                                   3847507659         comm_large
# {'name': 'comm_small', 'type': 'function'}        510540058          comm_small
#                                                   750582785          comm_small
#                                                   1416753650         comm_small
#                                                   2834938187         comm_small
#                                                   3847507659         comm_small
# {'name': 'comp', 'type': 'function'}              510540058                comp
#                                                   750582785                comp
#                                                   1416753650               comp
#                                                   2834938187               comp
#                                                   3847507659               comp
# {'name': 'comp_large', 'type': 'function'}        510540058          comp_large
#                                                   750582785          comp_large
#                                                   1416753650         comp_large
#                                                   2834938187         comp_large
#                                                   3847507659         comp_large
# {'name': 'comp_small', 'type': 'function'}        510540058          comp_small
#                                                   750582785          comp_small
#                                                   1416753650         comp_small
#                                                   2834938187         comp_small
#                                                   3847507659         comp_small
# {'name': 'correctness_check', 'type': 'function'} 510540058   correctness_check
#                                                   750582785   correctness_check
#                                                   1416753650  correctness_check
#                                                   2834938187  correctness_check
#                                                   3847507659  correctness_check
# {'name': 'data_init', 'type': 'function'}         510540058           data_init
#                                                   750582785           data_init
#                                                   1416753650          data_init
#                                                   2834938187          data_init
#                                                   3847507659          data_init

# %%
for i in tks.values():
    i.statsframe.dataframe["time"] = 1

print(tks["cuda_strong_random"].tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  ├─ 1.000 comm_large
# │  └─ 1.000 comm_small
# ├─ 1.000 comp
# │  ├─ 1.000 comp_large
# │  └─ 1.000 comp_small
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tks["mpi_strong_random"].metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 532154303            2.11.0-dev              32
# 1672494934           2.11.0-dev               8
# 1806604446           2.11.0-dev               4
# 2709641341           2.11.0-dev             128
# 3556469625           2.11.0-dev             256
# 3624234511           2.11.0-dev              16
# 3802076064           2.11.0-dev               2
# 4156779003           2.11.0-dev              64
#
#                                                  spot.metrics  \
# profile
# 532154303   min#inclusive#sum#time.duration,max#inclusive#...
# 1672494934  min#inclusive#sum#time.duration,max#inclusive#...
# 1806604446  min#inclusive#sum#time.duration,max#inclusive#...
# 2709641341  min#inclusive#sum#time.duration,max#inclusive#...
# 3556469625  min#inclusive#sum#time.duration,max#inclusive#...
# 3624234511  min#inclusive#sum#time.duration,max#inclusive#...
# 3802076064  min#inclusive#sum#time.duration,max#inclusive#...
# 4156779003  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 532154303                                             2
# 1672494934                                            2
# 1806604446                                            2
# 2709641341                                            2
# 3556469625                                            2
# 3624234511                                            2
# 3802076064                                            2
# 4156779003                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 532154303   time.variance,node.order  regionprofile         spot
# 1672494934  time.variance,node.order  regionprofile         spot
# 1806604446  time.variance,node.order  regionprofile         spot
# 2709641341  time.variance,node.order  regionprofile         spot
# 3556469625  time.variance,node.order  regionprofile         spot
# 3624234511  time.variance,node.order  regionprofile         spot
# 3802076064  time.variance,node.order  regionprofile         spot
# 4156779003  time.variance,node.order  regionprofile         spot
#
#            spot:node.order                          spot:output  \
# profile
# 532154303             true   cali_recent_2/p32-a1048576-tp.cali
# 1672494934            true    cali_recent_2/p8-a1048576-tp.cali
# 1806604446            true    cali_recent_2/p4-a1048576-tp.cali
# 2709641341            true  cali_recent_2/p128-a1048576-tp.cali
# 3556469625            true  cali_recent_2/p256-a1048576-tp.cali
# 3624234511            true   cali_recent_2/p16-a1048576-tp.cali
# 3802076064            true    cali_recent_2/p2-a1048576-tp.cali
# 4156779003            true   cali_recent_2/p64-a1048576-tp.cali
#
#            spot:time.variance         user  launchdate  \
# profile
# 532154303                true  miguelgi347  1700955417
# 1672494934               true  miguelgi347  1700955397
# 1806604446               true  miguelgi347  1700955397
# 2709641341               true  miguelgi347  1700955478
# 3556469625               true  miguelgi347  1700955432
# 3624234511               true  miguelgi347  1700955403
# 3802076064               true  miguelgi347  1700955396
# 4156779003               true  miguelgi347  1700955417
#
#                                                     libraries  \
# profile
# 532154303   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1672494934  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1806604446  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2709641341  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3556469625  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3624234511  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3802076064  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4156779003  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                               cmdline cluster  num_procs  InputSize  \
# profile
# 532154303   [./merge_mpi, 1048576, p]       c         32    1048576
# 1672494934  [./merge_mpi, 1048576, p]       c          8    1048576
# 1806604446  [./merge_mpi, 1048576, p]       c          4    1048576
# 2709641341  [./merge_mpi, 1048576, p]       c        128    1048576
# 3556469625  [./merge_mpi, 1048576, p]       c        256    1048576
# 3624234511  [./merge_mpi, 1048576, p]       c         16    1048576
# 3802076064  [./merge_mpi, 1048576, p]       c          2    1048576
# 4156779003  [./merge_mpi, 1048576, p]       c         64    1048576
#
#              Algorithm Datatype  SizeOfDatatype     InputType  \
# profile
# 532154303   merge_sort    float               4  random_array
# 1672494934  merge_sort    float               4  random_array
# 1806604446  merge_sort    float               4  random_array
# 2709641341  merge_sort    float               4  random_array
# 3556469625  merge_sort    float               4  random_array
# 3624234511  merge_sort    float               4  random_array
# 3802076064  merge_sort    float               4  random_array
# 4156779003  merge_sort    float               4  random_array
#
#            ProgrammingModel MPI_Reduce-master_initialization_time  \
# profile
# 532154303               MPI                             data_init
# 1672494934              MPI                             data_init
# 1806604446              MPI                             data_init
# 2709641341              MPI                             data_init
# 3556469625              MPI                             data_init
# 3624234511              MPI                             data_init
# 3802076064              MPI                             data_init
# 4156779003              MPI                             data_init
#
#            MPI_Reduce-master_send_time MPI_Reduce-master_receive_time  \
# profile
# 532154303                         comm          comm_large_MPI_Gather
# 1672494934                        comm          comm_large_MPI_Gather
# 1806604446                        comm          comm_large_MPI_Gather
# 2709641341                        comm          comm_large_MPI_Gather
# 3556469625                        comm          comm_large_MPI_Gather
# 3624234511                        comm          comm_large_MPI_Gather
# 3802076064                        comm          comm_large_MPI_Gather
# 4156779003                        comm          comm_large_MPI_Gather
#
#             group_num num_threads num_blocks implementation_source  \
# profile
# 532154303           1         N/A        N/A             Online/AI
# 1672494934          1         N/A        N/A             Online/AI
# 1806604446          1         N/A        N/A             Online/AI
# 2709641341          1         N/A        N/A             Online/AI
# 3556469625          1         N/A        N/A             Online/AI
# 3624234511          1         N/A        N/A             Online/AI
# 3802076064          1         N/A        N/A             Online/AI
# 4156779003          1         N/A        N/A             Online/AI
#
#            MPI_Reduce-worker_comm_MPI_Barrier MPI_Reduce-worker_comp_large
# profile
# 532154303                    comm_MPI_Barrier                   comp_large
# 1672494934                   comm_MPI_Barrier                   comp_large
# 1806604446                   comm_MPI_Barrier                   comp_large
# 2709641341                   comm_MPI_Barrier                   comp_large
# 3556469625                   comm_MPI_Barrier                   comp_large
# 3624234511                   comm_MPI_Barrier                   comp_large
# 3802076064                   comm_MPI_Barrier                   comp_large
# 4156779003                   comm_MPI_Barrier                   comp_large

# %%
gbs = {}

for i in tks.keys():
    if "strong" in i:
        gbs[i] = tks[i].groupby("InputSize")
    else:
        if i.startswith("cuda"):
            gbs[i] = tks[i].groupby("num_threads")
        else:
            gbs[i] = tks[i].groupby("num_procs")
# Out:
# 1  thickets created...
# {1024: <thicket.thicket.Thicket object at 0x2b94cb01beb0>}
# 1  thickets created...
# {1024: <thicket.thicket.Thicket object at 0x2b94c94b8e80>}
# 1  thickets created...
# {1024: <thicket.thicket.Thicket object at 0x2b94ca370880>}
# 1  thickets created...
# {1024: <thicket.thicket.Thicket object at 0x2b94c9a179d0>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b94ca419550>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b94ca5315b0>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b94c6abe0d0>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b94cae953a0>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b94c6a07670>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b94c9577f40>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b94cb6c8fd0>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b94cb789670>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b94c6767fd0>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b94cb7980d0>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b94ca445b50>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b94ca331ee0>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b94cb7adb50>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b94c66996a0>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b94c68e6520>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b94c6a53af0>}

# %%
print(gbs.keys())
# Out:
# dict_keys(['cuda_weak_sorted', 'cuda_weak_reverse', 'cuda_weak_random', 'cuda_weak_perturbed', 'cuda_strong_sorted', 'cuda_strong_reverse', 'cuda_strong_random', 'cuda_strong_perturbed', 'cuda_su_strong_sorted', 'cuda_su_strong_reverse', 'cuda_su_strong_random', 'cuda_su_strong_perturbed', 'mpi_weak_sorted', 'mpi_weak_reverse', 'mpi_weak_random', 'mpi_weak_perturbed', 'mpi_strong_sorted', 'mpi_strong_reverse', 'mpi_strong_random', 'mpi_strong_perturbed'])

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
ctks = {}

for i in gbs.keys():
    if "strong" in i:
        if i.startswith("cuda"):
            ctks[i] = th.Thicket.concat_thickets(
                thickets=list(gbs[i].values()),
                headers=list(gbs[i].keys()),
                axis="columns",
                metadata_key="num_threads"
            )
        else:
            ctks[i] = th.Thicket.concat_thickets(
                thickets=list(gbs[i].values()),
                headers=list(gbs[i].keys()),
                axis="columns",
                metadata_key="num_procs"
            )
    else:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="InputSize"
        )

# %%
# mpi_strong_random_ctk.dataframe

ctks["cuda_weak_random"].dataframe
# Out:
#                                      1024                              \
#                             Min time/rank Max time/rank Avg time/rank
# name              InputSize
# main              65536          0.362296      0.362296      0.362296
#                   262144         0.477830      0.477830      0.477830
#                   1048576        1.149564      1.149564      1.149564
#                   4194304        2.498556      2.498556      2.498556
#                   16777216       9.114376      9.114376      9.114376
#                   67108864      42.763243     42.763243     42.763243
#                   268435456    185.992555    185.992555    185.992555
# comm              65536          0.000280      0.000280      0.000280
#                   262144         0.000714      0.000714      0.000714
#                   1048576        0.002006      0.002006      0.002006
#                   4194304        0.007863      0.007863      0.007863
#                   16777216       0.029309      0.029309      0.029309
#                   67108864       0.114663      0.114663      0.114663
#                   268435456      0.455943      0.455943      0.455943
# comm_large        65536          0.000199      0.000199      0.000199
#                   262144         0.000614      0.000614      0.000614
#                   1048576        0.001910      0.001910      0.001910
#                   4194304        0.007761      0.007761      0.007761
#                   16777216       0.029209      0.029209      0.029209
#                   67108864       0.114547      0.114547      0.114547
#                   268435456      0.455811      0.455811      0.455811
# comm_small        65536          0.000007      0.000007      0.000007
#                   262144         0.000009      0.000009      0.000009
#                   1048576        0.000010      0.000010      0.000010
#                   4194304        0.000015      0.000015      0.000015
#                   16777216       0.000015      0.000015      0.000015
#                   67108864       0.000017      0.000017      0.000017
#                   268435456      0.000018      0.000018      0.000018
# comp              65536          0.030554      0.030554      0.030554
#                   262144         0.125167      0.125167      0.125167
#                   1048576        0.462899      0.462899      0.462899
#                   4194304        1.769511      1.769511      1.769511
#                   16777216       8.139306      8.139306      8.139306
#                   67108864      40.606074     40.606074     40.606074
#                   268435456    178.693820    178.693820    178.693820
# comp_large        65536          0.030524      0.030524      0.030524
#                   262144         0.125131      0.125131      0.125131
#                   1048576        0.462863      0.462863      0.462863
#                   4194304        1.769461      1.769461      1.769461
#                   16777216       8.139252      8.139252      8.139252
#                   67108864      40.606009     40.606009     40.606009
#                   268435456    178.693755    178.693755    178.693755
# comp_small        65536          0.000006      0.000006      0.000006
#                   262144         0.000006      0.000006      0.000006
#                   1048576        0.000006      0.000006      0.000006
#                   4194304        0.000006      0.000006      0.000006
#                   16777216       0.000006      0.000006      0.000006
#                   67108864       0.000006      0.000006      0.000006
#                   268435456      0.000006      0.000006      0.000006
# correctness_check 65536          0.000206      0.000206      0.000206
#                   262144         0.000773      0.000773      0.000773
#                   1048576        0.004002      0.004002      0.004002
#                   4194304        0.012088      0.012088      0.012088
#                   16777216       0.048236      0.048236      0.048236
#                   67108864       0.193089      0.193089      0.193089
#                   268435456      0.770438      0.770438      0.770438
# data_init         65536          0.001499      0.001499      0.001499
#                   262144         0.005940      0.005940      0.005940
#                   1048576        0.023610      0.023610      0.023610
#                   4194304        0.093881      0.093881      0.093881
#                   16777216       0.374091      0.374091      0.374091
#                   67108864       1.494645      1.494645      1.494645
#                   268435456      5.720184      5.720184      5.720184
#
#                                                                              \
#                              Total time Avg GPU time/rank Min GPU time/rank
# name              InputSize
# main              65536        0.362296          0.030341          0.030341
#                   262144       0.477830          0.125001          0.125001
#                   1048576      1.149564          0.463890          0.463890
#                   4194304      2.498556          1.775948          1.775948
#                   16777216     9.114376          8.167051          8.167051
#                   67108864    42.763243         40.718928         40.718928
#                   268435456  185.992555        179.147575        179.147575
# comm              65536        0.000280          0.000047          0.000047
#                   262144       0.000714          0.000174          0.000174
#                   1048576      0.002006          0.001344          0.001344
#                   4194304      0.007863          0.006951          0.006951
#                   16777216     0.029309          0.028367          0.028367
#                   67108864     0.114663          0.113665          0.113665
#                   268435456    0.455943          0.454759          0.454759
# comm_large        65536        0.000199          0.000047          0.000047
#                   262144       0.000614          0.000174          0.000174
#                   1048576      0.001910          0.001344          0.001344
#                   4194304      0.007761          0.006951          0.006951
#                   16777216     0.029209          0.028367          0.028367
#                   67108864     0.114547          0.113665          0.113665
#                   268435456    0.455811          0.454759          0.454759
# comm_small        65536        0.000007               NaN               NaN
#                   262144       0.000009               NaN               NaN
#                   1048576      0.000010               NaN               NaN
#                   4194304      0.000015               NaN               NaN
#                   16777216     0.000015               NaN               NaN
#                   67108864     0.000017               NaN               NaN
#                   268435456    0.000018               NaN               NaN
# comp              65536        0.030554          0.030293          0.030293
#                   262144       0.125167          0.124827          0.124827
#                   1048576      0.462899          0.462546          0.462546
#                   4194304      1.769511          1.768996          1.768996
#                   16777216     8.139306          8.138684          8.138684
#                   67108864    40.606074         40.605263         40.605263
#                   268435456  178.693820        178.692816        178.692816
# comp_large        65536        0.030524          0.030293          0.030293
#                   262144       0.125131          0.124827          0.124827
#                   1048576      0.462863          0.462546          0.462546
#                   4194304      1.769461          1.768996          1.768996
#                   16777216     8.139252          8.138684          8.138684
#                   67108864    40.606009         40.605263         40.605263
#                   268435456  178.693755        178.692816        178.692816
# comp_small        65536        0.000006               NaN               NaN
#                   262144       0.000006               NaN               NaN
#                   1048576      0.000006               NaN               NaN
#                   4194304      0.000006               NaN               NaN
#                   16777216     0.000006               NaN               NaN
#                   67108864     0.000006               NaN               NaN
#                   268435456    0.000006               NaN               NaN
# correctness_check 65536        0.000206               NaN               NaN
#                   262144       0.000773               NaN               NaN
#                   1048576      0.004002               NaN               NaN
#                   4194304      0.012088               NaN               NaN
#                   16777216     0.048236               NaN               NaN
#                   67108864     0.193089               NaN               NaN
#                   268435456    0.770438               NaN               NaN
# data_init         65536        0.001499               NaN               NaN
#                   262144       0.005940               NaN               NaN
#                   1048576      0.023610               NaN               NaN
#                   4194304      0.093881               NaN               NaN
#                   16777216     0.374091               NaN               NaN
#                   67108864     1.494645               NaN               NaN
#                   268435456    5.720184               NaN               NaN
#
#
#                             Max GPU time/rank Total GPU time
# name              InputSize
# main              65536              0.030341       0.030341
#                   262144             0.125001       0.125001
#                   1048576            0.463890       0.463890
#                   4194304            1.775948       1.775948
#                   16777216           8.167051       8.167051
#                   67108864          40.718928      40.718928
#                   268435456        179.147575     179.147575
# comm              65536              0.000047       0.000047
#                   262144             0.000174       0.000174
#                   1048576            0.001344       0.001344
#                   4194304            0.006951       0.006951
#                   16777216           0.028367       0.028367
#                   67108864           0.113665       0.113665
#                   268435456          0.454759       0.454759
# comm_large        65536              0.000047       0.000047
#                   262144             0.000174       0.000174
#                   1048576            0.001344       0.001344
#                   4194304            0.006951       0.006951
#                   16777216           0.028367       0.028367
#                   67108864           0.113665       0.113665
#                   268435456          0.454759       0.454759
# comm_small        65536                   NaN            NaN
#                   262144                  NaN            NaN
#                   1048576                 NaN            NaN
#                   4194304                 NaN            NaN
#                   16777216                NaN            NaN
#                   67108864                NaN            NaN
#                   268435456               NaN            NaN
# comp              65536              0.030293       0.030293
#                   262144             0.124827       0.124827
#                   1048576            0.462546       0.462546
#                   4194304            1.768996       1.768996
#                   16777216           8.138684       8.138684
#                   67108864          40.605263      40.605263
#                   268435456        178.692816     178.692816
# comp_large        65536              0.030293       0.030293
#                   262144             0.124827       0.124827
#                   1048576            0.462546       0.462546
#                   4194304            1.768996       1.768996
#                   16777216           8.138684       8.138684
#                   67108864          40.605263      40.605263
#                   268435456        178.692816     178.692816
# comp_small        65536                   NaN            NaN
#                   262144                  NaN            NaN
#                   1048576                 NaN            NaN
#                   4194304                 NaN            NaN
#                   16777216                NaN            NaN
#                   67108864                NaN            NaN
#                   268435456               NaN            NaN
# correctness_check 65536                   NaN            NaN
#                   262144                  NaN            NaN
#                   1048576                 NaN            NaN
#                   4194304                 NaN            NaN
#                   16777216                NaN            NaN
#                   67108864                NaN            NaN
#                   268435456               NaN            NaN
# data_init         65536                   NaN            NaN
#                   262144                  NaN            NaN
#                   1048576                 NaN            NaN
#                   4194304                 NaN            NaN
#                   16777216                NaN            NaN
#                   67108864                NaN            NaN
#                   268435456               NaN            NaN

# %%
# ctks["mpi_weak_random"].dataframe
ctks["cuda_su_strong_random"].dataframe
# Out:
#                               1048576                               \
#                                   nid   spot.channel Min time/rank
# name              num_threads
# main              1                 1  regionprofile      0.762386
#                   2                 1  regionprofile      0.698222
#                   4                 1  regionprofile      0.760084
#                   8                 1  regionprofile      0.726959
#                   16                1  regionprofile      0.728259
#                   32                1  regionprofile      0.773383
#                   64                1  regionprofile      0.732465
#                   128               1  regionprofile      0.767974
#                   256               1  regionprofile      0.769619
#                   512               1  regionprofile      0.803334
#                   1024              1  regionprofile      0.750008
# comm              1                 3  regionprofile      0.002150
#                   2                 3  regionprofile      0.002075
#                   4                 3  regionprofile      0.002101
#                   8                 3  regionprofile      0.002132
#                   16                3  regionprofile      0.002024
#                   32                3  regionprofile      0.002025
#                   64                3  regionprofile      0.002117
#                   128               3  regionprofile      0.002046
#                   256               3  regionprofile      0.002114
#                   512               3  regionprofile      0.002004
#                   1024              3  regionprofile      0.002077
# comm_large        1                 4  regionprofile      0.002044
#                   2                 4  regionprofile      0.001971
#                   4                 4  regionprofile      0.002003
#                   8                 4  regionprofile      0.002025
#                   16                4  regionprofile      0.001928
#                   32                4  regionprofile      0.001932
#                   64                4  regionprofile      0.002005
#                   128               4  regionprofile      0.001952
#                   256               4  regionprofile      0.002009
#                   512               4  regionprofile      0.001908
#                   1024              4  regionprofile      0.001975
# comm_small        1                 7  regionprofile      0.000010
#                   2                 7  regionprofile      0.000010
#                   4                 7  regionprofile      0.000009
#                   8                 7  regionprofile      0.000011
#                   16                7  regionprofile      0.000009
#                   32                7  regionprofile      0.000009
#                   64                7  regionprofile      0.000010
#                   128               7  regionprofile      0.000009
#                   256               7  regionprofile      0.000011
#                   512               7  regionprofile      0.000010
#                   1024              7  regionprofile      0.000009
# comp              1                 5  regionprofile      0.382490
#                   2                 5  regionprofile      0.324482
#                   4                 5  regionprofile      0.371821
#                   8                 5  regionprofile      0.353738
#                   16                5  regionprofile      0.357431
#                   32                5  regionprofile      0.394476
#                   64                5  regionprofile      0.363624
#                   128               5  regionprofile      0.386286
#                   256               5  regionprofile      0.393440
#                   512               5  regionprofile      0.435204
#                   1024              5  regionprofile      0.378676
# comp_large        1                 6  regionprofile      0.382449
#                   2                 6  regionprofile      0.324441
#                   4                 6  regionprofile      0.371781
#                   8                 6  regionprofile      0.353697
#                   16                6  regionprofile      0.357394
#                   32                6  regionprofile      0.394441
#                   64                6  regionprofile      0.363576
#                   128               6  regionprofile      0.386252
#                   256               6  regionprofile      0.393398
#                   512               6  regionprofile      0.435167
#                   1024              6  regionprofile      0.378639
# comp_small        1                 8  regionprofile      0.000007
#                   2                 8  regionprofile      0.000006
#                   4                 8  regionprofile      0.000006
#                   8                 8  regionprofile      0.000006
#                   16                8  regionprofile      0.000006
#                   32                8  regionprofile      0.000006
#                   64                8  regionprofile      0.000007
#                   128               8  regionprofile      0.000005
#                   256               8  regionprofile      0.000006
#                   512               8  regionprofile      0.000005
#                   1024              8  regionprofile      0.000006
# correctness_check 1                 9  regionprofile      0.003023
#                   2                 9  regionprofile      0.003019
#                   4                 9  regionprofile      0.003031
#                   8                 9  regionprofile      0.003020
#                   16                9  regionprofile      0.003035
#                   32                9  regionprofile      0.003036
#                   64                9  regionprofile      0.003019
#                   128               9  regionprofile      0.003018
#                   256               9  regionprofile      0.003030
#                   512               9  regionprofile      0.003032
#                   1024              9  regionprofile      0.003016
# data_init         1                 2  regionprofile      0.023786
#                   2                 2  regionprofile      0.023972
#                   4                 2  regionprofile      0.023658
#                   8                 2  regionprofile      0.023811
#                   16                2  regionprofile      0.023561
#                   32                2  regionprofile      0.023548
#                   64                2  regionprofile      0.023691
#                   128               2  regionprofile      0.023559
#                   256               2  regionprofile      0.023862
#                   512               2  regionprofile      0.023562
#                   1024              2  regionprofile      0.023563
#
#                                                                       \
#                               Max time/rank Avg time/rank Total time
# name              num_threads
# main              1                0.762386      0.762386   0.762386
#                   2                0.698222      0.698222   0.698222
#                   4                0.760084      0.760084   0.760084
#                   8                0.726959      0.726959   0.726959
#                   16               0.728259      0.728259   0.728259
#                   32               0.773383      0.773383   0.773383
#                   64               0.732465      0.732465   0.732465
#                   128              0.767974      0.767974   0.767974
#                   256              0.769619      0.769619   0.769619
#                   512              0.803334      0.803334   0.803334
#                   1024             0.750008      0.750008   0.750008
# comm              1                0.002150      0.002150   0.002150
#                   2                0.002075      0.002075   0.002075
#                   4                0.002101      0.002101   0.002101
#                   8                0.002132      0.002132   0.002132
#                   16               0.002024      0.002024   0.002024
#                   32               0.002025      0.002025   0.002025
#                   64               0.002117      0.002117   0.002117
#                   128              0.002046      0.002046   0.002046
#                   256              0.002114      0.002114   0.002114
#                   512              0.002004      0.002004   0.002004
#                   1024             0.002077      0.002077   0.002077
# comm_large        1                0.002044      0.002044   0.002044
#                   2                0.001971      0.001971   0.001971
#                   4                0.002003      0.002003   0.002003
#                   8                0.002025      0.002025   0.002025
#                   16               0.001928      0.001928   0.001928
#                   32               0.001932      0.001932   0.001932
#                   64               0.002005      0.002005   0.002005
#                   128              0.001952      0.001952   0.001952
#                   256              0.002009      0.002009   0.002009
#                   512              0.001908      0.001908   0.001908
#                   1024             0.001975      0.001975   0.001975
# comm_small        1                0.000010      0.000010   0.000010
#                   2                0.000010      0.000010   0.000010
#                   4                0.000009      0.000009   0.000009
#                   8                0.000011      0.000011   0.000011
#                   16               0.000009      0.000009   0.000009
#                   32               0.000009      0.000009   0.000009
#                   64               0.000010      0.000010   0.000010
#                   128              0.000009      0.000009   0.000009
#                   256              0.000011      0.000011   0.000011
#                   512              0.000010      0.000010   0.000010
#                   1024             0.000009      0.000009   0.000009
# comp              1                0.382490      0.382490   0.382490
#                   2                0.324482      0.324482   0.324482
#                   4                0.371821      0.371821   0.371821
#                   8                0.353738      0.353738   0.353738
#                   16               0.357431      0.357431   0.357431
#                   32               0.394476      0.394476   0.394476
#                   64               0.363624      0.363624   0.363624
#                   128              0.386286      0.386286   0.386286
#                   256              0.393440      0.393440   0.393440
#                   512              0.435204      0.435204   0.435204
#                   1024             0.378676      0.378676   0.378676
# comp_large        1                0.382449      0.382449   0.382449
#                   2                0.324441      0.324441   0.324441
#                   4                0.371781      0.371781   0.371781
#                   8                0.353697      0.353697   0.353697
#                   16               0.357394      0.357394   0.357394
#                   32               0.394441      0.394441   0.394441
#                   64               0.363576      0.363576   0.363576
#                   128              0.386252      0.386252   0.386252
#                   256              0.393398      0.393398   0.393398
#                   512              0.435167      0.435167   0.435167
#                   1024             0.378639      0.378639   0.378639
# comp_small        1                0.000007      0.000007   0.000007
#                   2                0.000006      0.000006   0.000006
#                   4                0.000006      0.000006   0.000006
#                   8                0.000006      0.000006   0.000006
#                   16               0.000006      0.000006   0.000006
#                   32               0.000006      0.000006   0.000006
#                   64               0.000007      0.000007   0.000007
#                   128              0.000005      0.000005   0.000005
#                   256              0.000006      0.000006   0.000006
#                   512              0.000005      0.000005   0.000005
#                   1024             0.000006      0.000006   0.000006
# correctness_check 1                0.003023      0.003023   0.003023
#                   2                0.003019      0.003019   0.003019
#                   4                0.003031      0.003031   0.003031
#                   8                0.003020      0.003020   0.003020
#                   16               0.003035      0.003035   0.003035
#                   32               0.003036      0.003036   0.003036
#                   64               0.003019      0.003019   0.003019
#                   128              0.003018      0.003018   0.003018
#                   256              0.003030      0.003030   0.003030
#                   512              0.003032      0.003032   0.003032
#                   1024             0.003016      0.003016   0.003016
# data_init         1                0.023786      0.023786   0.023786
#                   2                0.023972      0.023972   0.023972
#                   4                0.023658      0.023658   0.023658
#                   8                0.023811      0.023811   0.023811
#                   16               0.023561      0.023561   0.023561
#                   32               0.023548      0.023548   0.023548
#                   64               0.023691      0.023691   0.023691
#                   128              0.023559      0.023559   0.023559
#                   256              0.023862      0.023862   0.023862
#                   512              0.023562      0.023562   0.023562
#                   1024             0.023563      0.023563   0.023563
#
#                                                                    \
#                               Avg GPU time/rank Min GPU time/rank
# name              num_threads
# main              1                    0.383485          0.383485
#                   2                    0.325448          0.325448
#                   4                    0.372780          0.372780
#                   8                    0.354753          0.354753
#                   16                   0.358472          0.358472
#                   32                   0.395467          0.395467
#                   64                   0.364631          0.364631
#                   128                  0.387303          0.387303
#                   256                  0.394422          0.394422
#                   512                  0.436199          0.436199
#                   1024                 0.379684          0.379684
# comm              1                    0.001393          0.001393
#                   2                    0.001368          0.001368
#                   4                    0.001397          0.001397
#                   8                    0.001402          0.001402
#                   16                   0.001375          0.001375
#                   32                   0.001350          0.001350
#                   64                   0.001385          0.001385
#                   128                  0.001381          0.001381
#                   256                  0.001379          0.001379
#                   512                  0.001343          0.001343
#                   1024                 0.001376          0.001376
# comm_large        1                    0.001393          0.001393
#                   2                    0.001368          0.001368
#                   4                    0.001397          0.001397
#                   8                    0.001402          0.001402
#                   16                   0.001375          0.001375
#                   32                   0.001350          0.001350
#                   64                   0.001385          0.001385
#                   128                  0.001381          0.001381
#                   256                  0.001379          0.001379
#                   512                  0.001343          0.001343
#                   1024                 0.001376          0.001376
# comm_small        1                         NaN               NaN
#                   2                         NaN               NaN
#                   4                         NaN               NaN
#                   8                         NaN               NaN
#                   16                        NaN               NaN
#                   32                        NaN               NaN
#                   64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# comp              1                    0.382092          0.382092
#                   2                    0.324080          0.324080
#                   4                    0.371383          0.371383
#                   8                    0.353351          0.353351
#                   16                   0.357096          0.357096
#                   32                   0.394117          0.394117
#                   64                   0.363247          0.363247
#                   128                  0.385922          0.385922
#                   256                  0.393043          0.393043
#                   512                  0.434857          0.434857
#                   1024                 0.378308          0.378308
# comp_large        1                    0.382092          0.382092
#                   2                    0.324080          0.324080
#                   4                    0.371383          0.371383
#                   8                    0.353351          0.353351
#                   16                   0.357096          0.357096
#                   32                   0.394117          0.394117
#                   64                   0.363247          0.363247
#                   128                  0.385922          0.385922
#                   256                  0.393043          0.393043
#                   512                  0.434857          0.434857
#                   1024                 0.378308          0.378308
# comp_small        1                         NaN               NaN
#                   2                         NaN               NaN
#                   4                         NaN               NaN
#                   8                         NaN               NaN
#                   16                        NaN               NaN
#                   32                        NaN               NaN
#                   64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# correctness_check 1                         NaN               NaN
#                   2                         NaN               NaN
#                   4                         NaN               NaN
#                   8                         NaN               NaN
#                   16                        NaN               NaN
#                   32                        NaN               NaN
#                   64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# data_init         1                         NaN               NaN
#                   2                         NaN               NaN
#                   4                         NaN               NaN
#                   8                         NaN               NaN
#                   16                        NaN               NaN
#                   32                        NaN               NaN
#                   64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
#
#
#                               Max GPU time/rank Total GPU time
# name              num_threads
# main              1                    0.383485       0.383485
#                   2                    0.325448       0.325448
#                   4                    0.372780       0.372780
#                   8                    0.354753       0.354753
#                   16                   0.358472       0.358472
#                   32                   0.395467       0.395467
#                   64                   0.364631       0.364631
#                   128                  0.387303       0.387303
#                   256                  0.394422       0.394422
#                   512                  0.436199       0.436199
#                   1024                 0.379684       0.379684
# comm              1                    0.001393       0.001393
#                   2                    0.001368       0.001368
#                   4                    0.001397       0.001397
#                   8                    0.001402       0.001402
#                   16                   0.001375       0.001375
#                   32                   0.001350       0.001350
#                   64                   0.001385       0.001385
#                   128                  0.001381       0.001381
#                   256                  0.001379       0.001379
#                   512                  0.001343       0.001343
#                   1024                 0.001376       0.001376
# comm_large        1                    0.001393       0.001393
#                   2                    0.001368       0.001368
#                   4                    0.001397       0.001397
#                   8                    0.001402       0.001402
#                   16                   0.001375       0.001375
#                   32                   0.001350       0.001350
#                   64                   0.001385       0.001385
#                   128                  0.001381       0.001381
#                   256                  0.001379       0.001379
#                   512                  0.001343       0.001343
#                   1024                 0.001376       0.001376
# comm_small        1                         NaN            NaN
#                   2                         NaN            NaN
#                   4                         NaN            NaN
#                   8                         NaN            NaN
#                   16                        NaN            NaN
#                   32                        NaN            NaN
#                   64                        NaN            NaN
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# comp              1                    0.382092       0.382092
#                   2                    0.324080       0.324080
#                   4                    0.371383       0.371383
#                   8                    0.353351       0.353351
#                   16                   0.357096       0.357096
#                   32                   0.394117       0.394117
#                   64                   0.363247       0.363247
#                   128                  0.385922       0.385922
#                   256                  0.393043       0.393043
#                   512                  0.434857       0.434857
#                   1024                 0.378308       0.378308
# comp_large        1                    0.382092       0.382092
#                   2                    0.324080       0.324080
#                   4                    0.371383       0.371383
#                   8                    0.353351       0.353351
#                   16                   0.357096       0.357096
#                   32                   0.394117       0.394117
#                   64                   0.363247       0.363247
#                   128                  0.385922       0.385922
#                   256                  0.393043       0.393043
#                   512                  0.434857       0.434857
#                   1024                 0.378308       0.378308
# comp_small        1                         NaN            NaN
#                   2                         NaN            NaN
#                   4                         NaN            NaN
#                   8                         NaN            NaN
#                   16                        NaN            NaN
#                   32                        NaN            NaN
#                   64                        NaN            NaN
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# correctness_check 1                         NaN            NaN
#                   2                         NaN            NaN
#                   4                         NaN            NaN
#                   8                         NaN            NaN
#                   16                        NaN            NaN
#                   32                        NaN            NaN
#                   64                        NaN            NaN
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# data_init         1                         NaN            NaN
#                   2                         NaN            NaN
#                   4                         NaN            NaN
#                   8                         NaN            NaN
#                   16                        NaN            NaN
#                   32                        NaN            NaN
#                   64                        NaN            NaN
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN

# %% [markdown]
# # STOPPED HERE, EVERYTHING BELOW IS NOT UPDATED

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
for i in ctks.keys(): #(1048576, "nid"), (65536, "spot.channel")
    if "strong" in i:
        if "cuda" in i:
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
            #ctks[i].dataframe.columns = ctks[i].dataframe.columns.droplevel(1)
        else: 
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", ""), (1048576, "nid"), (1048576, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
            #ctks[i].dataframe.columns = ctks[i].dataframe.columns.droplevel(1)
    else:
        if "cuda" in i:
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", ""), (1024, "nid"), (1024, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("InputSize", ""): "InputSize"}).set_index(["name", "InputSize"])
        else:
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", ""), (128, "nid"), (128, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("InputSize", ""): "InputSize"}).set_index(["name", "InputSize"])

# %%
ctks["mpi_weak_reverse"].dataframe.loc["comp_large"]
function_names = ("main", "comp", "comm", "comm_small", "comm_large", "comp_small", "comp_large")

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_random"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 

masterDF
# Out:
#          main      comp      comm  comm_small  comm_large  comp_small  \
# 2    0.609937  0.071240  0.024041    0.000005    0.024000    0.000006
# 4    0.775087  0.020973  0.039146    0.000005    0.039089    0.000006
# 8    0.833597  0.007242  0.045205    0.000005    0.045147    0.000006
# 16   1.130147  0.002831  0.048342    0.000005    0.048286    0.000006
# 32   1.361101  0.001460  0.053608    0.000005    0.053545    0.000006
# 64   2.184010  0.000776  0.052453    0.000005    0.052404    0.000006
# 128  2.893440  0.000646  0.081580    0.000005    0.081525    0.000006
# 256  6.694866  0.000458  0.228203    0.000005    0.228145    0.000006
#
#      comp_large
# 2      0.142438
# 4      0.083814
# 8      0.057778
# 16     0.044972
# 32     0.046089
# 64     0.048637
# 128    0.080300
# 256    0.112312

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_random"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI Random Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI Random Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_sorted"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI Sorted Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI Sorted Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_perturbed"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="Merge MPI 1%Perturbed Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'Merge MPI 1%Perturbed Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_reverse"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI Reverse Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI Reverse Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_random"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI Random Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI Random Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_sorted"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI Sorted Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI Sorted Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_reverse"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI Reverse Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI Reverse Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_perturbed"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI 1%Perturbed Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI 1%Perturbed Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %% [markdown]
# ## CUDA GRAPHS

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_random"].dataframe.loc[name][(65536, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort CUDA Random Input, Sorting 65536 Values, Avg time/rank",
    xlabel="Num_Threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort CUDA Random Input, Sorting 65536 Values, Avg time/rank'}, xlabel='Num_Threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_sorted"].dataframe.loc[name][(65536, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort CUDA Sorted Input, Sorting 65536 Values, Avg time/rank",
    xlabel="Num_Threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort CUDA Sorted Input, Sorting 65536 Values, Avg time/rank'}, xlabel='Num_Threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_reverse"].dataframe.loc[name][(65536, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort CUDA Reverse Input, Sorting 65536 Values, Avg time/rank",
    xlabel="Num_Threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort CUDA Reverse Input, Sorting 65536 Values, Avg time/rank'}, xlabel='Num_Threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_perturbed"].dataframe.loc[name][(65536, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort CUDA 1%Perturbed Input, Sorting 65536 Values, Avg time/rank",
    xlabel="Num_Threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort CUDA 1%Perturbed Input, Sorting 65536 Values, Avg time/rank'}, xlabel='Num_Threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_random"].dataframe.loc[name][(1024, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort CUDA Random Input, with 1024 Threads, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort CUDA Random Input, with 1024 Threads, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_sorted"].dataframe.loc[name][(1024, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort CUDA Sorted Input, with 1024 Threads, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort CUDA Sorted Input, with 1024 Threads, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_reverse"].dataframe.loc[name][(1024, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort CUDA Reverse Input, with 1024 Threads, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort CUDA Reverse Input, with 1024 Threads, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_perturbed"].dataframe.loc[name][(1024, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort CUDA 1%Perturbed Input, with 1024 Threads, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort CUDA 1%Perturbed Input, with 1024 Threads, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %% [markdown]
# ### Option 2
# Use `matplotlib.pyplot` directly for more fine-grained control. Specifically for our case we can change the x axis scaling from base 10 to base 2.

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(matrix_sizes)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %% [markdown]
# # Examples

# %% [markdown]
# ## time

# %%
ctk.dataframe.loc["main"]
# Out:
#               128      1024      4096
# threads
# 1        0.000270  0.000257  0.000367
# 2        0.000247  0.000284  0.000406
# 4        0.000256  0.000260  0.000374
# 8        0.000241  0.000278  0.000357
# 16       0.000262  0.000284  0.000356
# 32       0.000264  0.000264  0.000373
# 64       0.000256  0.000284  0.000453
# 96       0.000253  0.000305  0.000417
# 128      0.000287  0.000284  0.000414
# 256      0.000297  0.000317  0.000447
# 512      0.000277  0.000297  0.000446

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_random"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 

masterDF
# Out:
#          main      comp      comm  comm_small  comm_large  comp_small  \
# 2    0.609937  0.071240  0.024041    0.000005    0.024000    0.000006
# 4    0.775087  0.020973  0.039146    0.000005    0.039089    0.000006
# 8    0.833597  0.007242  0.045205    0.000005    0.045147    0.000006
# 16   1.130147  0.002831  0.048342    0.000005    0.048286    0.000006
# 32   1.361101  0.001460  0.053608    0.000005    0.053545    0.000006
# 64   2.184010  0.000776  0.052453    0.000005    0.052404    0.000006
# 128  2.893440  0.000646  0.081580    0.000005    0.081525    0.000006
# 256  6.694866  0.000458  0.228203    0.000005    0.228145    0.000006
#
#      comp_large
# 2      0.142438
# 4      0.083814
# 8      0.057778
# 16     0.044972
# 32     0.046089
# 64     0.048637
# 128    0.080300
# 256    0.112312

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Threads",
        ylabel="Time (seconds)",
        loglog=True
    )

# %%
for name in function_names:
    plot_mpl(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Threads",
        ylabel="Time (seconds)",
    )

# %% [markdown]
# ## Speedup

# %%
# speedup_df = ctks.dataframe.loc[(slice(None),1), :].reset_index().drop("threads", axis=1).set_index("name")/ctks.dataframe
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_su_strong_random"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
masterDF.index.name = 'thread_count'
masterDF.reset_index(inplace=True)

masterDF

plt.figure(figsize=(10, 6))
plt.plot(masterDF["thread_count"], masterDF["main"], marker='o') # Adding markers for clarity

plt.xlabel("Thread Count")
plt.ylabel("Main")
plt.title("Linearity Check for 'Main'")
plt.grid(True)
plt.show()
