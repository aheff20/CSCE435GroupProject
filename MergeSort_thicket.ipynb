# %% [markdown]
# # FINAL PROJECT THICKET

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

print("done")
# Out:
# done

# %% [markdown]
# Read in all the files

# %% [markdown]
# # MPI Thicket Variables

# %%
mpi_strong_random_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/strong/random/*.cali"))
mpi_strong_reverse_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/strong/reverse/*.cali"))
mpi_strong_perturbed_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/strong/perturbed/*.cali"))
mpi_strong_sorted_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/strong/sorted/*.cali"))
mpi_weak_random_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/weak/random/*.cali"))
mpi_weak_reverse_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/weak/reverse/*.cali"))
mpi_weak_perturbed_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/weak/perturbed/*.cali"))
mpi_weak_sorted_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/weak/sorted/*.cali"))

# %% [markdown]
# # CUDA Thicket Variables

# %%
cuda_strong_random_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/strong/random/*.cali"))
cuda_strong_reverse_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/strong/reverse/*.cali"))
cuda_strong_perturbed_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/strong/perturbed/*.cali"))
cuda_strong_sorted_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/strong/sorted/*.cali"))
cuda_weak_random_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/weak/random/*.cali"))
cuda_weak_reverse_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/weak/reverse/*.cali"))
cuda_weak_perturbed_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/weak/perturbed/*.cali"))
cuda_weak_sorted_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/weak/sorted/*.cali"))

# %%
tks = {}

tks["cuda_weak_sorted"] = cuda_weak_sorted_tk
tks["cuda_weak_reverse"] = cuda_weak_reverse_tk
tks["cuda_weak_random"] = cuda_weak_random_tk
tks["cuda_weak_perturbed"] = cuda_weak_perturbed_tk

tks["cuda_strong_sorted"] = cuda_strong_sorted_tk
tks["cuda_strong_reverse"] = cuda_strong_reverse_tk
tks["cuda_strong_random"] = cuda_strong_random_tk
tks["cuda_strong_perturbed"] = cuda_strong_perturbed_tk

tks["mpi_weak_sorted"] = mpi_weak_sorted_tk
tks["mpi_weak_reverse"] = mpi_weak_reverse_tk
tks["mpi_weak_random"] = mpi_weak_random_tk
tks["mpi_weak_perturbed"] = mpi_weak_perturbed_tk

tks["mpi_strong_sorted"] = mpi_strong_sorted_tk
tks["mpi_strong_reverse"] = mpi_strong_reverse_tk
tks["mpi_strong_random"] = mpi_strong_random_tk
tks["mpi_strong_perturbed"] = mpi_strong_perturbed_tk

# %%
# Performance data
tks["mpi_strong_random"].dataframe
# Out:
#                                                        nid   spot.channel  \
# node                                       profile
# {'name': 'main', 'type': 'function'}       532154303     1  regionprofile
#                                            1672494934    1  regionprofile
#                                            1806604446    1  regionprofile
#                                            2709641341    1  regionprofile
#                                            3556469625    1  regionprofile
#                                            3624234511    1  regionprofile
#                                            3802076064    1  regionprofile
#                                            4156779003    1  regionprofile
# {'name': 'comm', 'type': 'function'}       532154303     3  regionprofile
#                                            1672494934    3  regionprofile
#                                            1806604446    3  regionprofile
#                                            2709641341    3  regionprofile
#                                            3556469625    3  regionprofile
#                                            3624234511    3  regionprofile
#                                            3802076064    3  regionprofile
#                                            4156779003    3  regionprofile
# {'name': 'comm_large', 'type': 'function'} 532154303     4  regionprofile
#                                            1672494934    4  regionprofile
#                                            1806604446    4  regionprofile
#                                            2709641341    4  regionprofile
#                                            3556469625    4  regionprofile
#                                            3624234511    4  regionprofile
#                                            3802076064    4  regionprofile
#                                            4156779003    4  regionprofile
# {'name': 'comm_small', 'type': 'function'} 532154303     8  regionprofile
#                                            1672494934    8  regionprofile
#                                            1806604446    8  regionprofile
#                                            2709641341    8  regionprofile
#                                            3556469625    8  regionprofile
#                                            3624234511    8  regionprofile
#                                            3802076064    8  regionprofile
#                                            4156779003    8  regionprofile
# {'name': 'comp', 'type': 'function'}       532154303     5  regionprofile
#                                            1672494934    5  regionprofile
#                                            1806604446    5  regionprofile
#                                            2709641341    5  regionprofile
#                                            3556469625    5  regionprofile
#                                            3624234511    5  regionprofile
#                                            3802076064    5  regionprofile
#                                            4156779003    5  regionprofile
# {'name': 'comp_large', 'type': 'function'} 532154303     6  regionprofile
#                                            1672494934    6  regionprofile
#                                            1806604446    6  regionprofile
#                                            2709641341    6  regionprofile
#                                            3556469625    6  regionprofile
#                                            3624234511    6  regionprofile
#                                            3802076064    6  regionprofile
#                                            4156779003    6  regionprofile
# {'name': 'comp_small', 'type': 'function'} 532154303     7  regionprofile
#                                            1672494934    7  regionprofile
#                                            1806604446    7  regionprofile
#                                            2709641341    7  regionprofile
#                                            3556469625    7  regionprofile
#                                            3624234511    7  regionprofile
#                                            3802076064    7  regionprofile
#                                            4156779003    7  regionprofile
# {'name': 'data_init', 'type': 'function'}  532154303     2  regionprofile
#                                            1672494934    2  regionprofile
#                                            1806604446    2  regionprofile
#                                            2709641341    2  regionprofile
#                                            3556469625    2  regionprofile
#                                            3624234511    2  regionprofile
#                                            3802076064    2  regionprofile
#                                            4156779003    2  regionprofile
#
#                                                        Min time/rank  \
# node                                       profile
# {'name': 'main', 'type': 'function'}       532154303        3.664791
#                                            1672494934       1.088723
#                                            1806604446       0.548941
#                                            2709641341       7.402220
#                                            3556469625      13.173571
#                                            3624234511       1.791682
#                                            3802076064       0.355827
#                                            4156779003       6.326816
# {'name': 'comm', 'type': 'function'}       532154303        0.087195
#                                            1672494934       0.018377
#                                            1806604446       0.025245
#                                            2709641341       0.265984
#                                            3556469625       0.358263
#                                            3624234511       0.043145
#                                            3802076064       0.018788
#                                            4156779003       0.207809
# {'name': 'comm_large', 'type': 'function'} 532154303        0.087157
#                                            1672494934       0.018340
#                                            1806604446       0.025202
#                                            2709641341       0.265931
#                                            3556469625       0.358218
#                                            3624234511       0.043102
#                                            3802076064       0.018740
#                                            4156779003       0.147718
# {'name': 'comm_small', 'type': 'function'} 532154303        0.000004
#                                            1672494934       0.000005
#                                            1806604446       0.000005
#                                            2709641341       0.000004
#                                            3556469625       0.000004
#                                            3624234511       0.000004
#                                            3802076064       0.000005
#                                            4156779003       0.000004
# {'name': 'comp', 'type': 'function'}       532154303        0.000019
#                                            1672494934       0.000020
#                                            1806604446       0.000021
#                                            2709641341       0.000019
#                                            3556469625       0.000018
#                                            3624234511       0.000019
#                                            3802076064       0.000020
#                                            4156779003       0.000019
# {'name': 'comp_large', 'type': 'function'} 532154303        0.598811
#                                            1672494934       0.255201
#                                            1806604446       0.164163
#                                            2709641341       1.433524
#                                            3556469625       2.165870
#                                            3624234511       0.373545
#                                            3802076064       0.142988
#                                            4156779003       1.491331
# {'name': 'comp_small', 'type': 'function'} 532154303        0.000005
#                                            1672494934       0.000005
#                                            1806604446       0.000005
#                                            2709641341       0.000005
#                                            3556469625       0.000005
#                                            3624234511       0.000005
#                                            3802076064       0.000005
#                                            4156779003       0.000005
# {'name': 'data_init', 'type': 'function'}  532154303        0.839441
#                                            1672494934       0.210711
#                                            1806604446       0.108311
#                                            2709641341       1.491246
#                                            3556469625       3.078852
#                                            3624234511       0.396683
#                                            3802076064       0.047247
#                                            4156779003       1.553067
#
#                                                        Max time/rank  \
# node                                       profile
# {'name': 'main', 'type': 'function'}       532154303        4.274725
#                                            1672494934       1.353669
#                                            1806604446       0.747568
#                                            2709641341       9.143105
#                                            3556469625      15.474091
#                                            3624234511       2.189906
#                                            3802076064       0.511368
#                                            4156779003       7.957657
# {'name': 'comm', 'type': 'function'}       532154303        1.061422
#                                            1672494934       0.291226
#                                            1806604446       0.110456
#                                            2709641341       1.907697
#                                            3556469625       3.710365
#                                            3624234511       0.536446
#                                            3802076064       0.074769
#                                            4156779003       1.831382
# {'name': 'comm_large', 'type': 'function'} 532154303        1.061363
#                                            1672494934       0.291159
#                                            1806604446       0.110393
#                                            2709641341       1.907632
#                                            3556469625       3.698316
#                                            3624234511       0.536382
#                                            3802076064       0.074698
#                                            4156779003       1.831325
# {'name': 'comm_small', 'type': 'function'} 532154303        0.000005
#                                            1672494934       0.000005
#                                            1806604446       0.000005
#                                            2709641341       0.000012
#                                            3556469625       0.000011
#                                            3624234511       0.000005
#                                            3802076064       0.000005
#                                            4156779003       0.000005
# {'name': 'comp', 'type': 'function'}       532154303        0.598848
#                                            1672494934       0.255232
#                                            1806604446       0.164202
#                                            2709641341       1.433567
#                                            3556469625       2.165904
#                                            3624234511       0.373582
#                                            3802076064       0.143017
#                                            4156779003       1.491370
# {'name': 'comp_large', 'type': 'function'} 532154303        0.598811
#                                            1672494934       0.255201
#                                            1806604446       0.164163
#                                            2709641341       1.433524
#                                            3556469625       2.165870
#                                            3624234511       0.373545
#                                            3802076064       0.142988
#                                            4156779003       1.491331
# {'name': 'comp_small', 'type': 'function'} 532154303        0.000006
#                                            1672494934       0.000006
#                                            1806604446       0.000006
#                                            2709641341       0.000039
#                                            3556469625       0.049678
#                                            3624234511       0.000006
#                                            3802076064       0.000005
#                                            4156779003       0.000006
# {'name': 'data_init', 'type': 'function'}  532154303        0.839441
#                                            1672494934       0.210711
#                                            1806604446       0.108311
#                                            2709641341       1.491246
#                                            3556469625       3.078852
#                                            3624234511       0.396683
#                                            3802076064       0.047247
#                                            4156779003       1.553067
#
#                                                        Avg time/rank  \
# node                                       profile
# {'name': 'main', 'type': 'function'}       532154303        3.788112
#                                            1672494934       1.139176
#                                            1806604446       0.609539
#                                            2709641341       7.737533
#                                            3556469625      13.871407
#                                            3624234511       1.880991
#                                            3802076064       0.433598
#                                            4156779003       6.789845
# {'name': 'comm', 'type': 'function'}       532154303        0.925104
#                                            1672494934       0.217269
#                                            1806604446       0.086937
#                                            2709641341       1.663601
#                                            3556469625       3.408087
#                                            3624234511       0.453929
#                                            3802076064       0.046779
#                                            4156779003       1.657630
# {'name': 'comm_large', 'type': 'function'} 532154303        0.925047
#                                            1672494934       0.217209
#                                            1806604446       0.086876
#                                            2709641341       1.663467
#                                            3556469625       3.406599
#                                            3624234511       0.453871
#                                            3802076064       0.046719
#                                            4156779003       1.656635
# {'name': 'comm_small', 'type': 'function'} 532154303        0.000005
#                                            1672494934       0.000005
#                                            1806604446       0.000005
#                                            2709641341       0.000005
#                                            3556469625       0.000005
#                                            3624234511       0.000005
#                                            3802076064       0.000005
#                                            4156779003       0.000005
# {'name': 'comp', 'type': 'function'}       532154303        0.018733
#                                            1672494934       0.031922
#                                            1806604446       0.041067
#                                            2709641341       0.011220
#                                            3556469625       0.008692
#                                            3624234511       0.023368
#                                            3802076064       0.071519
#                                            4156779003       0.023323
# {'name': 'comp_large', 'type': 'function'} 532154303        0.598811
#                                            1672494934       0.255201
#                                            1806604446       0.164163
#                                            2709641341       1.433524
#                                            3556469625       2.165870
#                                            3624234511       0.373545
#                                            3802076064       0.142988
#                                            4156779003       1.491331
# {'name': 'comp_small', 'type': 'function'} 532154303        0.000006
#                                            1672494934       0.000006
#                                            1806604446       0.000005
#                                            2709641341       0.000006
#                                            3556469625       0.000201
#                                            3624234511       0.000006
#                                            3802076064       0.000005
#                                            4156779003       0.000006
# {'name': 'data_init', 'type': 'function'}  532154303        0.839441
#                                            1672494934       0.210711
#                                            1806604446       0.108311
#                                            2709641341       1.491246
#                                            3556469625       3.078852
#                                            3624234511       0.396683
#                                            3802076064       0.047247
#                                            4156779003       1.553067
#
#                                                         Total time  \
# node                                       profile
# {'name': 'main', 'type': 'function'}       532154303    121.219589
#                                            1672494934     9.113412
#                                            1806604446     2.438155
#                                            2709641341   990.404271
#                                            3556469625  3551.080090
#                                            3624234511    30.095864
#                                            3802076064     0.867195
#                                            4156779003   434.550052
# {'name': 'comm', 'type': 'function'}       532154303     29.603314
#                                            1672494934     1.738154
#                                            1806604446     0.347747
#                                            2709641341   212.940892
#                                            3556469625   872.470295
#                                            3624234511     7.262865
#                                            3802076064     0.093557
#                                            4156779003   106.088310
# {'name': 'comm_large', 'type': 'function'} 532154303     29.601499
#                                            1672494934     1.737674
#                                            1806604446     0.347504
#                                            2709641341   212.923815
#                                            3556469625   872.089252
#                                            3624234511     7.261941
#                                            3802076064     0.093438
#                                            4156779003   106.024621
# {'name': 'comm_small', 'type': 'function'} 532154303      0.000144
#                                            1672494934     0.000034
#                                            1806604446     0.000014
#                                            2709641341     0.000599
#                                            3556469625     0.001189
#                                            3624234511     0.000069
#                                            3802076064     0.000005
#                                            4156779003     0.000291
# {'name': 'comp', 'type': 'function'}       532154303      0.599469
#                                            1672494934     0.255377
#                                            1806604446     0.164267
#                                            2709641341     1.436196
#                                            3556469625     2.225183
#                                            3624234511     0.373889
#                                            3802076064     0.143037
#                                            4156779003     1.492642
# {'name': 'comp_large', 'type': 'function'} 532154303      0.598811
#                                            1672494934     0.255201
#                                            1806604446     0.164163
#                                            2709641341     1.433524
#                                            3556469625     2.165870
#                                            3624234511     0.373545
#                                            3802076064     0.142988
#                                            4156779003     1.491331
# {'name': 'comp_small', 'type': 'function'} 532154303      0.000174
#                                            1672494934     0.000039
#                                            1806604446     0.000016
#                                            2709641341     0.000762
#                                            3556469625     0.051171
#                                            3624234511     0.000085
#                                            3802076064     0.000005
#                                            4156779003     0.000352
# {'name': 'data_init', 'type': 'function'}  532154303      0.839441
#                                            1672494934     0.210711
#                                            1806604446     0.108311
#                                            2709641341     1.491246
#                                            3556469625     3.078852
#                                            3624234511     0.396683
#                                            3802076064     0.047247
#                                            4156779003     1.553067
#
#                                                        Variance time/rank  \
# node                                       profile
# {'name': 'main', 'type': 'function'}       532154303             0.008848
#                                            1672494934            0.006763
#                                            1806604446            0.006433
#                                            2709641341            0.063095
#                                            3556469625            0.037311
#                                            3624234511            0.006844
#                                            3802076064            0.006048
#                                            4156779003            0.028942
# {'name': 'comm', 'type': 'function'}       532154303             0.027399
#                                            1672494934            0.006286
#                                            1806604446            0.001274
#                                            2709641341            0.025407
#                                            3556469625            0.047852
#                                            3624234511            0.013081
#                                            3802076064            0.000783
#                                            4156779003            0.040119
# {'name': 'comm_large', 'type': 'function'} 532154303             0.027398
#                                            1672494934            0.006285
#                                            1806604446            0.001273
#                                            2709641341            0.025398
#                                            3556469625            0.047707
#                                            3624234511            0.013081
#                                            3802076064            0.000783
#                                            4156779003            0.042894
# {'name': 'comm_small', 'type': 'function'} 532154303             0.000000
#                                            1672494934            0.000000
#                                            1806604446            0.000000
#                                            2709641341            0.000000
#                                            3556469625            0.000000
#                                            3624234511            0.000000
#                                            3802076064            0.000000
#                                            4156779003            0.000000
# {'name': 'comp', 'type': 'function'}       532154303             0.010856
#                                            1672494934            0.007124
#                                            1806604446            0.005054
#                                            2709641341            0.015930
#                                            3556469625            0.018259
#                                            3624234511            0.008177
#                                            3802076064            0.005112
#                                            4156779003            0.034209
# {'name': 'comp_large', 'type': 'function'} 532154303             0.000000
#                                            1672494934            0.000000
#                                            1806604446            0.000000
#                                            2709641341            0.000000
#                                            3556469625            0.000000
#                                            3624234511            0.000000
#                                            3802076064            0.000000
#                                            4156779003            0.000000
# {'name': 'comp_small', 'type': 'function'} 532154303             0.000000
#                                            1672494934            0.000000
#                                            1806604446            0.000000
#                                            2709641341            0.000000
#                                            3556469625            0.000010
#                                            3624234511            0.000000
#                                            3802076064            0.000000
#                                            4156779003            0.000000
# {'name': 'data_init', 'type': 'function'}  532154303             0.000000
#                                            1672494934            0.000000
#                                            1806604446            0.000000
#                                            2709641341            0.000000
#                                            3556469625            0.000000
#                                            3624234511            0.000000
#                                            3802076064            0.000000
#                                            4156779003            0.000000
#
#                                                              name
# node                                       profile
# {'name': 'main', 'type': 'function'}       532154303         main
#                                            1672494934        main
#                                            1806604446        main
#                                            2709641341        main
#                                            3556469625        main
#                                            3624234511        main
#                                            3802076064        main
#                                            4156779003        main
# {'name': 'comm', 'type': 'function'}       532154303         comm
#                                            1672494934        comm
#                                            1806604446        comm
#                                            2709641341        comm
#                                            3556469625        comm
#                                            3624234511        comm
#                                            3802076064        comm
#                                            4156779003        comm
# {'name': 'comm_large', 'type': 'function'} 532154303   comm_large
#                                            1672494934  comm_large
#                                            1806604446  comm_large
#                                            2709641341  comm_large
#                                            3556469625  comm_large
#                                            3624234511  comm_large
#                                            3802076064  comm_large
#                                            4156779003  comm_large
# {'name': 'comm_small', 'type': 'function'} 532154303   comm_small
#                                            1672494934  comm_small
#                                            1806604446  comm_small
#                                            2709641341  comm_small
#                                            3556469625  comm_small
#                                            3624234511  comm_small
#                                            3802076064  comm_small
#                                            4156779003  comm_small
# {'name': 'comp', 'type': 'function'}       532154303         comp
#                                            1672494934        comp
#                                            1806604446        comp
#                                            2709641341        comp
#                                            3556469625        comp
#                                            3624234511        comp
#                                            3802076064        comp
#                                            4156779003        comp
# {'name': 'comp_large', 'type': 'function'} 532154303   comp_large
#                                            1672494934  comp_large
#                                            1806604446  comp_large
#                                            2709641341  comp_large
#                                            3556469625  comp_large
#                                            3624234511  comp_large
#                                            3802076064  comp_large
#                                            4156779003  comp_large
# {'name': 'comp_small', 'type': 'function'} 532154303   comp_small
#                                            1672494934  comp_small
#                                            1806604446  comp_small
#                                            2709641341  comp_small
#                                            3556469625  comp_small
#                                            3624234511  comp_small
#                                            3802076064  comp_small
#                                            4156779003  comp_small
# {'name': 'data_init', 'type': 'function'}  532154303    data_init
#                                            1672494934   data_init
#                                            1806604446   data_init
#                                            2709641341   data_init
#                                            3556469625   data_init
#                                            3624234511   data_init
#                                            3802076064   data_init
#                                            4156779003   data_init

# %%
for i in tks.values():
    i.statsframe.dataframe["time"] = 1

print(tks["mpi_strong_random"].tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  ├─ 1.000 comm_large
# │  └─ 1.000 comm_small
# ├─ 1.000 comp
# │  ├─ 1.000 comp_large
# │  └─ 1.000 comp_small
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tks["mpi_strong_random"].metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 532154303            2.11.0-dev              32
# 1672494934           2.11.0-dev               8
# 1806604446           2.11.0-dev               4
# 2709641341           2.11.0-dev             128
# 3556469625           2.11.0-dev             256
# 3624234511           2.11.0-dev              16
# 3802076064           2.11.0-dev               2
# 4156779003           2.11.0-dev              64
#
#                                                  spot.metrics  \
# profile
# 532154303   min#inclusive#sum#time.duration,max#inclusive#...
# 1672494934  min#inclusive#sum#time.duration,max#inclusive#...
# 1806604446  min#inclusive#sum#time.duration,max#inclusive#...
# 2709641341  min#inclusive#sum#time.duration,max#inclusive#...
# 3556469625  min#inclusive#sum#time.duration,max#inclusive#...
# 3624234511  min#inclusive#sum#time.duration,max#inclusive#...
# 3802076064  min#inclusive#sum#time.duration,max#inclusive#...
# 4156779003  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 532154303                                             2
# 1672494934                                            2
# 1806604446                                            2
# 2709641341                                            2
# 3556469625                                            2
# 3624234511                                            2
# 3802076064                                            2
# 4156779003                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 532154303   time.variance,node.order  regionprofile         spot
# 1672494934  time.variance,node.order  regionprofile         spot
# 1806604446  time.variance,node.order  regionprofile         spot
# 2709641341  time.variance,node.order  regionprofile         spot
# 3556469625  time.variance,node.order  regionprofile         spot
# 3624234511  time.variance,node.order  regionprofile         spot
# 3802076064  time.variance,node.order  regionprofile         spot
# 4156779003  time.variance,node.order  regionprofile         spot
#
#            spot:node.order                        spot:output  \
# profile
# 532154303             true               p32-a1048576-tp.cali
# 1672494934            true                p8-a1048576-tp.cali
# 1806604446            true                p4-a1048576-tp.cali
# 2709641341            true  cali_recent/p128-a1048576-tp.cali
# 3556469625            true  cali_recent/p256-a1048576-tp.cali
# 3624234511            true               p16-a1048576-tp.cali
# 3802076064            true  cali_recent_2/p2-a1048576-tp.cali
# 4156779003            true               p64-a1048576-tp.cali
#
#            spot:time.variance         user  launchdate  \
# profile
# 532154303                true  miguelgi347  1700065060
# 1672494934               true  miguelgi347  1700065012
# 1806604446               true  miguelgi347  1700065012
# 2709641341               true  miguelgi347  1700068085
# 3556469625               true  miguelgi347  1700079475
# 3624234511               true  miguelgi347  1700065036
# 3802076064               true  miguelgi347  1700081736
# 4156779003               true  miguelgi347  1700065055
#
#                                                     libraries  \
# profile
# 532154303   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1672494934  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1806604446  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2709641341  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3556469625  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3624234511  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3802076064  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4156779003  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                               cmdline cluster  num_procs  InputSize  \
# profile
# 532154303   [./merge_mpi, 1048576, p]       c         32    1048576
# 1672494934  [./merge_mpi, 1048576, p]       c          8    1048576
# 1806604446  [./merge_mpi, 1048576, p]       c          4    1048576
# 2709641341  [./merge_mpi, 1048576, p]       c        128    1048576
# 3556469625  [./merge_mpi, 1048576, p]       c        256    1048576
# 3624234511  [./merge_mpi, 1048576, p]       c         16    1048576
# 3802076064  [./merge_mpi, 1048576, p]       c          2    1048576
# 4156779003  [./merge_mpi, 1048576, p]       c         64    1048576
#
#              Algorithm Datatype  SizeOfDatatype     InputType  \
# profile
# 532154303   merge_sort    float               4  random_array
# 1672494934  merge_sort    float               4  random_array
# 1806604446  merge_sort    float               4  random_array
# 2709641341  merge_sort    float               4  random_array
# 3556469625  merge_sort    float               4  random_array
# 3624234511  merge_sort    float               4  random_array
# 3802076064  merge_sort    float               4  random_array
# 4156779003  merge_sort    float               4  random_array
#
#            ProgrammingModel MPI_Reduce-master_initialization_time  \
# profile
# 532154303               MPI                             data_init
# 1672494934              MPI                             data_init
# 1806604446              MPI                             data_init
# 2709641341              MPI                             data_init
# 3556469625              MPI                             data_init
# 3624234511              MPI                             data_init
# 3802076064              MPI                             data_init
# 4156779003              MPI                             data_init
#
#            MPI_Reduce-master_send_time MPI_Reduce-master_receive_time  \
# profile
# 532154303                         comm          comm_large_MPI_Gather
# 1672494934                        comm          comm_large_MPI_Gather
# 1806604446                        comm          comm_large_MPI_Gather
# 2709641341                        comm          comm_large_MPI_Gather
# 3556469625                        comm          comm_large_MPI_Gather
# 3624234511                        comm          comm_large_MPI_Gather
# 3802076064                        comm          comm_large_MPI_Gather
# 4156779003                        comm          comm_large_MPI_Gather
#
#             group_num num_threads num_blocks implementation_source  \
# profile
# 532154303           1         N/A        N/A             Online/AI
# 1672494934          1         N/A        N/A             Online/AI
# 1806604446          1         N/A        N/A             Online/AI
# 2709641341          1         N/A        N/A             Online/AI
# 3556469625          1         N/A        N/A             Online/AI
# 3624234511          1         N/A        N/A             Online/AI
# 3802076064          1         N/A        N/A             Online/AI
# 4156779003          1         N/A        N/A             Online/AI
#
#            MPI_Reduce-worker_comm_MPI_Barrier MPI_Reduce-worker_comp_large
# profile
# 532154303                    comm_MPI_Barrier                   comp_large
# 1672494934                   comm_MPI_Barrier                   comp_large
# 1806604446                   comm_MPI_Barrier                   comp_large
# 2709641341                   comm_MPI_Barrier                   comp_large
# 3556469625                   comm_MPI_Barrier                   comp_large
# 3624234511                   comm_MPI_Barrier                   comp_large
# 3802076064                   comm_MPI_Barrier                   comp_large
# 4156779003                   comm_MPI_Barrier                   comp_large

# %%
gbs = {}

for i in tks.keys():
    if "strong" in i:
        gbs[i] = tks[i].groupby("InputSize")
    else:
        if i.startswith("cuda"):
            gbs[i] = tks[i].groupby("num_threads")
        else:
            gbs[i] = tks[i].groupby("num_procs")
# Out:
# 1  thickets created...
# {1024: <thicket.thicket.Thicket object at 0x2b1e6d4fcbe0>}
# 1  thickets created...
# {1024: <thicket.thicket.Thicket object at 0x2b1e74c372b0>}
# 1  thickets created...
# {1024: <thicket.thicket.Thicket object at 0x2b1e74c41e50>}
# 1  thickets created...
# {1024: <thicket.thicket.Thicket object at 0x2b1e74c37820>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b1e74bfc6d0>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b1e74bf2940>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b1e74bf8790>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b1e74ac3ac0>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b1e74ad2e50>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b1e74bb67c0>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b1e74a779d0>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b1e7482a100>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b1e7498b6a0>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b1e74ad9760>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b1e74a4ee20>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b1e749eb700>}

# %%
print(gbs.keys())
# Out:
# dict_keys(['cuda_weak_sorted', 'cuda_weak_reverse', 'cuda_weak_random', 'cuda_weak_perturbed', 'cuda_strong_sorted', 'cuda_strong_reverse', 'cuda_strong_random', 'cuda_strong_perturbed', 'mpi_weak_sorted', 'mpi_weak_reverse', 'mpi_weak_random', 'mpi_weak_perturbed', 'mpi_strong_sorted', 'mpi_strong_reverse', 'mpi_strong_random', 'mpi_strong_perturbed'])

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
ctks = {}

for i in gbs.keys():
    if "strong" in i:
        if i.startswith("cuda"):
            ctks[i] = th.Thicket.concat_thickets(
                thickets=list(gbs[i].values()),
                headers=list(gbs[i].keys()),
                axis="columns",
                metadata_key="num_threads"
            )
        else:
            ctks[i] = th.Thicket.concat_thickets(
                thickets=list(gbs[i].values()),
                headers=list(gbs[i].keys()),
                axis="columns",
                metadata_key="num_procs"
            )
    else:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="InputSize"
        )

# %%
# mpi_strong_random_ctk.dataframe

ctks["cuda_strong_random"].dataframe
# Out:
#                                                               65536  \
#                                                                 nid
# node                                              num_threads
# {'name': 'comm', 'type': 'function'}              64              3
#                                                   128             3
#                                                   256             3
#                                                   512             3
#                                                   1024            3
# {'name': 'comm_large', 'type': 'function'}        64              4
#                                                   128             4
#                                                   256             4
#                                                   512             4
#                                                   1024            4
# {'name': 'comm_small', 'type': 'function'}        64              8
#                                                   128             8
#                                                   256             8
#                                                   512             8
#                                                   1024            8
# {'name': 'comp', 'type': 'function'}              64              6
#                                                   128             6
#                                                   256             6
#                                                   512             6
#                                                   1024            6
# {'name': 'comp_large', 'type': 'function'}        64              7
#                                                   128             7
#                                                   256             7
#                                                   512             7
#                                                   1024            7
# {'name': 'comp_small', 'type': 'function'}        64              9
#                                                   128             9
#                                                   256             9
#                                                   512             9
#                                                   1024            9
# {'name': 'correctness_check', 'type': 'function'} 64             11
#                                                   128            11
#                                                   256            11
#                                                   512            11
#                                                   1024           11
# {'name': 'data_init', 'type': 'function'}         64              1
#                                                   128             1
#                                                   256             1
#                                                   512             1
#                                                   1024            1
#
#                                                                               \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'comm', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_small', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp_small', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'correctness_check', 'type': 'function'} 64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'data_init', 'type': 'function'}         64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#
#                                                                              \
#                                                               Min time/rank
# node                                              num_threads
# {'name': 'comm', 'type': 'function'}              64               0.000276
#                                                   128              0.000274
#                                                   256              0.000276
#                                                   512              0.000301
#                                                   1024             0.000275
# {'name': 'comm_large', 'type': 'function'}        64               0.000196
#                                                   128              0.000193
#                                                   256              0.000197
#                                                   512              0.000215
#                                                   1024             0.000194
# {'name': 'comm_small', 'type': 'function'}        64               0.000007
#                                                   128              0.000007
#                                                   256              0.000007
#                                                   512              0.000008
#                                                   1024             0.000007
# {'name': 'comp', 'type': 'function'}              64               0.034866
#                                                   128              0.037748
#                                                   256              0.028848
#                                                   512              0.030122
#                                                   1024             0.029240
# {'name': 'comp_large', 'type': 'function'}        64               0.034835
#                                                   128              0.037715
#                                                   256              0.028816
#                                                   512              0.030088
#                                                   1024             0.029209
# {'name': 'comp_small', 'type': 'function'}        64               0.000005
#                                                   128              0.000006
#                                                   256              0.000005
#                                                   512              0.000006
#                                                   1024             0.000006
# {'name': 'correctness_check', 'type': 'function'} 64               0.000216
#                                                   128              0.000205
#                                                   256              0.000206
#                                                   512              0.000207
#                                                   1024             0.000208
# {'name': 'data_init', 'type': 'function'}         64               0.001542
#                                                   128              0.001547
#                                                   256              0.001543
#                                                   512              0.001542
#                                                   1024             0.001543
#
#                                                                              \
#                                                               Max time/rank
# node                                              num_threads
# {'name': 'comm', 'type': 'function'}              64               0.000276
#                                                   128              0.000274
#                                                   256              0.000276
#                                                   512              0.000301
#                                                   1024             0.000275
# {'name': 'comm_large', 'type': 'function'}        64               0.000196
#                                                   128              0.000193
#                                                   256              0.000197
#                                                   512              0.000215
#                                                   1024             0.000194
# {'name': 'comm_small', 'type': 'function'}        64               0.000007
#                                                   128              0.000007
#                                                   256              0.000007
#                                                   512              0.000008
#                                                   1024             0.000007
# {'name': 'comp', 'type': 'function'}              64               0.034866
#                                                   128              0.037748
#                                                   256              0.028848
#                                                   512              0.030122
#                                                   1024             0.029240
# {'name': 'comp_large', 'type': 'function'}        64               0.034835
#                                                   128              0.037715
#                                                   256              0.028816
#                                                   512              0.030088
#                                                   1024             0.029209
# {'name': 'comp_small', 'type': 'function'}        64               0.000005
#                                                   128              0.000006
#                                                   256              0.000005
#                                                   512              0.000006
#                                                   1024             0.000006
# {'name': 'correctness_check', 'type': 'function'} 64               0.000216
#                                                   128              0.000205
#                                                   256              0.000206
#                                                   512              0.000207
#                                                   1024             0.000208
# {'name': 'data_init', 'type': 'function'}         64               0.001542
#                                                   128              0.001547
#                                                   256              0.001543
#                                                   512              0.001542
#                                                   1024             0.001543
#
#                                                                              \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'comm', 'type': 'function'}              64               0.000276
#                                                   128              0.000274
#                                                   256              0.000276
#                                                   512              0.000301
#                                                   1024             0.000275
# {'name': 'comm_large', 'type': 'function'}        64               0.000196
#                                                   128              0.000193
#                                                   256              0.000197
#                                                   512              0.000215
#                                                   1024             0.000194
# {'name': 'comm_small', 'type': 'function'}        64               0.000007
#                                                   128              0.000007
#                                                   256              0.000007
#                                                   512              0.000008
#                                                   1024             0.000007
# {'name': 'comp', 'type': 'function'}              64               0.034866
#                                                   128              0.037748
#                                                   256              0.028848
#                                                   512              0.030122
#                                                   1024             0.029240
# {'name': 'comp_large', 'type': 'function'}        64               0.034835
#                                                   128              0.037715
#                                                   256              0.028816
#                                                   512              0.030088
#                                                   1024             0.029209
# {'name': 'comp_small', 'type': 'function'}        64               0.000005
#                                                   128              0.000006
#                                                   256              0.000005
#                                                   512              0.000006
#                                                   1024             0.000006
# {'name': 'correctness_check', 'type': 'function'} 64               0.000216
#                                                   128              0.000205
#                                                   256              0.000206
#                                                   512              0.000207
#                                                   1024             0.000208
# {'name': 'data_init', 'type': 'function'}         64               0.001542
#                                                   128              0.001547
#                                                   256              0.001543
#                                                   512              0.001542
#                                                   1024             0.001543
#
#                                                                           \
#                                                               Total time
# node                                              num_threads
# {'name': 'comm', 'type': 'function'}              64            0.000276
#                                                   128           0.000274
#                                                   256           0.000276
#                                                   512           0.000301
#                                                   1024          0.000275
# {'name': 'comm_large', 'type': 'function'}        64            0.000196
#                                                   128           0.000193
#                                                   256           0.000197
#                                                   512           0.000215
#                                                   1024          0.000194
# {'name': 'comm_small', 'type': 'function'}        64            0.000007
#                                                   128           0.000007
#                                                   256           0.000007
#                                                   512           0.000008
#                                                   1024          0.000007
# {'name': 'comp', 'type': 'function'}              64            0.034866
#                                                   128           0.037748
#                                                   256           0.028848
#                                                   512           0.030122
#                                                   1024          0.029240
# {'name': 'comp_large', 'type': 'function'}        64            0.034835
#                                                   128           0.037715
#                                                   256           0.028816
#                                                   512           0.030088
#                                                   1024          0.029209
# {'name': 'comp_small', 'type': 'function'}        64            0.000005
#                                                   128           0.000006
#                                                   256           0.000005
#                                                   512           0.000006
#                                                   1024          0.000006
# {'name': 'correctness_check', 'type': 'function'} 64            0.000216
#                                                   128           0.000205
#                                                   256           0.000206
#                                                   512           0.000207
#                                                   1024          0.000208
# {'name': 'data_init', 'type': 'function'}         64            0.001542
#                                                   128           0.001547
#                                                   256           0.001543
#                                                   512           0.001542
#                                                   1024          0.001543
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'comm', 'type': 'function'}              64                   0.000048
#                                                   128                  0.000048
#                                                   256                  0.000047
#                                                   512                  0.000047
#                                                   1024                 0.000047
# {'name': 'comm_large', 'type': 'function'}        64                   0.000048
#                                                   128                  0.000048
#                                                   256                  0.000047
#                                                   512                  0.000047
#                                                   1024                 0.000047
# {'name': 'comm_small', 'type': 'function'}        64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'comp', 'type': 'function'}              64                   0.034577
#                                                   128                  0.037462
#                                                   256                  0.028585
#                                                   512                  0.029825
#                                                   1024                 0.028970
# {'name': 'comp_large', 'type': 'function'}        64                   0.034577
#                                                   128                  0.037462
#                                                   256                  0.028585
#                                                   512                  0.029825
#                                                   1024                 0.028970
# {'name': 'comp_small', 'type': 'function'}        64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                                  \
#                                                               Min GPU time/rank
# node                                              num_threads
# {'name': 'comm', 'type': 'function'}              64                   0.000048
#                                                   128                  0.000048
#                                                   256                  0.000047
#                                                   512                  0.000047
#                                                   1024                 0.000047
# {'name': 'comm_large', 'type': 'function'}        64                   0.000048
#                                                   128                  0.000048
#                                                   256                  0.000047
#                                                   512                  0.000047
#                                                   1024                 0.000047
# {'name': 'comm_small', 'type': 'function'}        64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'comp', 'type': 'function'}              64                   0.034577
#                                                   128                  0.037462
#                                                   256                  0.028585
#                                                   512                  0.029825
#                                                   1024                 0.028970
# {'name': 'comp_large', 'type': 'function'}        64                   0.034577
#                                                   128                  0.037462
#                                                   256                  0.028585
#                                                   512                  0.029825
#                                                   1024                 0.028970
# {'name': 'comp_small', 'type': 'function'}        64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                                  \
#                                                               Max GPU time/rank
# node                                              num_threads
# {'name': 'comm', 'type': 'function'}              64                   0.000048
#                                                   128                  0.000048
#                                                   256                  0.000047
#                                                   512                  0.000047
#                                                   1024                 0.000047
# {'name': 'comm_large', 'type': 'function'}        64                   0.000048
#                                                   128                  0.000048
#                                                   256                  0.000047
#                                                   512                  0.000047
#                                                   1024                 0.000047
# {'name': 'comm_small', 'type': 'function'}        64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'comp', 'type': 'function'}              64                   0.034577
#                                                   128                  0.037462
#                                                   256                  0.028585
#                                                   512                  0.029825
#                                                   1024                 0.028970
# {'name': 'comp_large', 'type': 'function'}        64                   0.034577
#                                                   128                  0.037462
#                                                   256                  0.028585
#                                                   512                  0.029825
#                                                   1024                 0.028970
# {'name': 'comp_small', 'type': 'function'}        64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                               \
#                                                               Total GPU time
# node                                              num_threads
# {'name': 'comm', 'type': 'function'}              64                0.000048
#                                                   128               0.000048
#                                                   256               0.000047
#                                                   512               0.000047
#                                                   1024              0.000047
# {'name': 'comm_large', 'type': 'function'}        64                0.000048
#                                                   128               0.000048
#                                                   256               0.000047
#                                                   512               0.000047
#                                                   1024              0.000047
# {'name': 'comm_small', 'type': 'function'}        64                     NaN
#                                                   128                    NaN
#                                                   256                    NaN
#                                                   512                    NaN
#                                                   1024                   NaN
# {'name': 'comp', 'type': 'function'}              64                0.034577
#                                                   128               0.037462
#                                                   256               0.028585
#                                                   512               0.029825
#                                                   1024              0.028970
# {'name': 'comp_large', 'type': 'function'}        64                0.034577
#                                                   128               0.037462
#                                                   256               0.028585
#                                                   512               0.029825
#                                                   1024              0.028970
# {'name': 'comp_small', 'type': 'function'}        64                     NaN
#                                                   128                    NaN
#                                                   256                    NaN
#                                                   512                    NaN
#                                                   1024                   NaN
# {'name': 'correctness_check', 'type': 'function'} 64                     NaN
#                                                   128                    NaN
#                                                   256                    NaN
#                                                   512                    NaN
#                                                   1024                   NaN
# {'name': 'data_init', 'type': 'function'}         64                     NaN
#                                                   128                    NaN
#                                                   256                    NaN
#                                                   512                    NaN
#                                                   1024                   NaN
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'comm', 'type': 'function'}              64                        comm
#                                                   128                       comm
#                                                   256                       comm
#                                                   512                       comm
#                                                   1024                      comm
# {'name': 'comm_large', 'type': 'function'}        64                  comm_large
#                                                   128                 comm_large
#                                                   256                 comm_large
#                                                   512                 comm_large
#                                                   1024                comm_large
# {'name': 'comm_small', 'type': 'function'}        64                  comm_small
#                                                   128                 comm_small
#                                                   256                 comm_small
#                                                   512                 comm_small
#                                                   1024                comm_small
# {'name': 'comp', 'type': 'function'}              64                        comp
#                                                   128                       comp
#                                                   256                       comp
#                                                   512                       comp
#                                                   1024                      comp
# {'name': 'comp_large', 'type': 'function'}        64                  comp_large
#                                                   128                 comp_large
#                                                   256                 comp_large
#                                                   512                 comp_large
#                                                   1024                comp_large
# {'name': 'comp_small', 'type': 'function'}        64                  comp_small
#                                                   128                 comp_small
#                                                   256                 comp_small
#                                                   512                 comp_small
#                                                   1024                comp_small
# {'name': 'correctness_check', 'type': 'function'} 64           correctness_check
#                                                   128          correctness_check
#                                                   256          correctness_check
#                                                   512          correctness_check
#                                                   1024         correctness_check
# {'name': 'data_init', 'type': 'function'}         64                   data_init
#                                                   128                  data_init
#                                                   256                  data_init
#                                                   512                  data_init
#                                                   1024                 data_init

# %%
ctks["mpi_weak_random"].dataframe
# Out:
#                                                      128                 \
#                                                      nid   spot.channel
# node                                       InputSize
# {'name': 'main', 'type': 'function'}       65536       1  regionprofile
#                                            262144      1  regionprofile
#                                            1048576     1  regionprofile
#                                            4194304     1  regionprofile
#                                            16777216    1  regionprofile
#                                            67108864    1  regionprofile
# {'name': 'comm', 'type': 'function'}       65536       3  regionprofile
#                                            262144      3  regionprofile
#                                            1048576     3  regionprofile
#                                            4194304     3  regionprofile
#                                            16777216    3  regionprofile
#                                            67108864    3  regionprofile
# {'name': 'comm_large', 'type': 'function'} 65536       4  regionprofile
#                                            262144      4  regionprofile
#                                            1048576     4  regionprofile
#                                            4194304     4  regionprofile
#                                            16777216    4  regionprofile
#                                            67108864    4  regionprofile
# {'name': 'comm_small', 'type': 'function'} 65536       8  regionprofile
#                                            262144      8  regionprofile
#                                            1048576     8  regionprofile
#                                            4194304     8  regionprofile
#                                            16777216    8  regionprofile
#                                            67108864    8  regionprofile
# {'name': 'comp', 'type': 'function'}       65536       5  regionprofile
#                                            262144      5  regionprofile
#                                            1048576     5  regionprofile
#                                            4194304     5  regionprofile
#                                            16777216    5  regionprofile
#                                            67108864    5  regionprofile
# {'name': 'comp_large', 'type': 'function'} 65536       6  regionprofile
#                                            262144      6  regionprofile
#                                            1048576     6  regionprofile
#                                            4194304     6  regionprofile
#                                            16777216    6  regionprofile
#                                            67108864    6  regionprofile
# {'name': 'comp_small', 'type': 'function'} 65536       7  regionprofile
#                                            262144      7  regionprofile
#                                            1048576     7  regionprofile
#                                            4194304     7  regionprofile
#                                            16777216    7  regionprofile
#                                            67108864    7  regionprofile
# {'name': 'data_init', 'type': 'function'}  65536       2  regionprofile
#                                            262144      2  regionprofile
#                                            1048576     2  regionprofile
#                                            4194304     2  regionprofile
#                                            16777216    2  regionprofile
#                                            67108864    2  regionprofile
#
#                                                                     \
#                                                      Min time/rank
# node                                       InputSize
# {'name': 'main', 'type': 'function'}       65536          7.062517
#                                            262144         5.602555
#                                            1048576       16.152048
#                                            4194304       28.989653
#                                            16777216      31.566367
#                                            67108864     101.127413
# {'name': 'comm', 'type': 'function'}       65536          0.000113
#                                            262144         0.124839
#                                            1048576        0.567314
#                                            4194304        1.169396
#                                            16777216       0.943054
#                                            67108864       1.378580
# {'name': 'comm_large', 'type': 'function'} 65536          0.000071
#                                            262144         0.124797
#                                            1048576        0.567272
#                                            4194304        1.169355
#                                            16777216       0.943007
#                                            67108864       1.378529
# {'name': 'comm_small', 'type': 'function'} 65536          0.000004
#                                            262144         0.000004
#                                            1048576        0.000004
#                                            4194304        0.000004
#                                            16777216       0.000004
#                                            67108864       0.000004
# {'name': 'comp', 'type': 'function'}       65536          0.000014
#                                            262144         0.000019
#                                            1048576        0.000019
#                                            4194304        0.000019
#                                            16777216       0.000019
#                                            67108864       0.000023
# {'name': 'comp_large', 'type': 'function'} 65536          0.994332
#                                            262144         0.883425
#                                            1048576        2.203649
#                                            4194304        7.562573
#                                            16777216      15.388103
#                                            67108864      57.637769
# {'name': 'comp_small', 'type': 'function'} 65536          0.000005
#                                            262144         0.000005
#                                            1048576        0.000005
#                                            4194304        0.000005
#                                            16777216       0.000005
#                                            67108864       0.000006
# {'name': 'data_init', 'type': 'function'}  65536          0.002972
#                                            262144         0.437833
#                                            1048576        2.885793
#                                            4194304       11.776099
#                                            16777216      23.919875
#                                            67108864      95.298736
#
#                                                                     \
#                                                      Max time/rank
# node                                       InputSize
# {'name': 'main', 'type': 'function'}       65536          9.215727
#                                            262144         6.560101
#                                            1048576       19.247746
#                                            4194304       37.050559
#                                            16777216      47.654312
#                                            67108864     159.932116
# {'name': 'comm', 'type': 'function'}       65536          0.714327
#                                            262144         1.018712
#                                            1048576        3.791276
#                                            4194304       13.056879
#                                            16777216      24.875414
#                                            67108864      96.547597
# {'name': 'comm_large', 'type': 'function'} 65536          0.714271
#                                            262144         1.018648
#                                            1048576        3.791215
#                                            4194304       13.056822
#                                            16777216      24.875357
#                                            67108864      96.547534
# {'name': 'comm_small', 'type': 'function'} 65536          0.000005
#                                            262144         0.000009
#                                            1048576        0.000006
#                                            4194304        0.000005
#                                            16777216       0.000005
#                                            67108864       0.000005
# {'name': 'comp', 'type': 'function'}       65536          0.994373
#                                            262144         0.883468
#                                            1048576        2.203680
#                                            4194304        7.562611
#                                            16777216      15.388146
#                                            67108864      57.637815
# {'name': 'comp_large', 'type': 'function'} 65536          0.994332
#                                            262144         0.883425
#                                            1048576        2.203649
#                                            4194304        7.562573
#                                            16777216      15.388103
#                                            67108864      57.637769
# {'name': 'comp_small', 'type': 'function'} 65536          0.000027
#                                            262144         0.000010
#                                            1048576        0.000006
#                                            4194304        0.000006
#                                            16777216       0.000006
#                                            67108864       0.000007
# {'name': 'data_init', 'type': 'function'}  65536          0.002972
#                                            262144         0.437833
#                                            1048576        2.885793
#                                            4194304       11.776099
#                                            16777216      23.919875
#                                            67108864      95.298736
#
#                                                                     \
#                                                      Avg time/rank
# node                                       InputSize
# {'name': 'main', 'type': 'function'}       65536          7.659497
#                                            262144         6.232786
#                                            1048576       16.608642
#                                            4194304       29.714378
#                                            16777216      32.254854
#                                            67108864     102.406498
# {'name': 'comm', 'type': 'function'}       65536          0.385032
#                                            262144         0.682667
#                                            1048576        3.445550
#                                            4194304       12.498133
#                                            16777216      24.372540
#                                            67108864      95.483298
# {'name': 'comm_large', 'type': 'function'} 65536          0.384114
#                                            262144         0.682609
#                                            1048576        3.445493
#                                            4194304       12.498077
#                                            16777216      24.372483
#                                            67108864      95.483234
# {'name': 'comm_small', 'type': 'function'} 65536          0.000005
#                                            262144         0.000005
#                                            1048576        0.000005
#                                            4194304        0.000005
#                                            16777216       0.000005
#                                            67108864       0.000005
# {'name': 'comp', 'type': 'function'}       65536          0.007789
#                                            262144         0.006922
#                                            1048576        0.017236
#                                            4194304        0.059103
#                                            16777216       0.120240
#                                            67108864       0.450320
# {'name': 'comp_large', 'type': 'function'} 65536          0.994332
#                                            262144         0.883425
#                                            1048576        2.203649
#                                            4194304        7.562573
#                                            16777216      15.388103
#                                            67108864      57.637769
# {'name': 'comp_small', 'type': 'function'} 65536          0.000006
#                                            262144         0.000006
#                                            1048576        0.000006
#                                            4194304        0.000006
#                                            16777216       0.000006
#                                            67108864       0.000006
# {'name': 'data_init', 'type': 'function'}  65536          0.002972
#                                            262144         0.437833
#                                            1048576        2.885793
#                                            4194304       11.776099
#                                            16777216      23.919875
#                                            67108864      95.298736
#
#                                                                     \
#                                                         Total time
# node                                       InputSize
# {'name': 'main', 'type': 'function'}       65536        980.415605
#                                            262144       797.796587
#                                            1048576     2125.906151
#                                            4194304     3803.440393
#                                            16777216    4128.621269
#                                            67108864   13108.031759
# {'name': 'comm', 'type': 'function'}       65536         49.284151
#                                            262144        87.381390
#                                            1048576      441.030362
#                                            4194304     1599.761043
#                                            16777216    3119.685066
#                                            67108864   12221.862152
# {'name': 'comm_large', 'type': 'function'} 65536         49.166623
#                                            262144        87.373904
#                                            1048576      441.023110
#                                            4194304     1599.753794
#                                            16777216    3119.677814
#                                            67108864   12221.853929
# {'name': 'comm_small', 'type': 'function'} 65536          0.000587
#                                            262144         0.000594
#                                            1048576        0.000588
#                                            4194304        0.000587
#                                            16777216       0.000590
#                                            67108864       0.000591
# {'name': 'comp', 'type': 'function'}       65536          0.996960
#                                            262144         0.886027
#                                            1048576        2.206234
#                                            4194304        7.565145
#                                            16777216      15.390680
#                                            67108864      57.640912
# {'name': 'comp_large', 'type': 'function'} 65536          0.994332
#                                            262144         0.883425
#                                            1048576        2.203649
#                                            4194304        7.562573
#                                            16777216      15.388103
#                                            67108864      57.637769
# {'name': 'comp_small', 'type': 'function'} 65536          0.000747
#                                            262144         0.000727
#                                            1048576        0.000723
#                                            4194304        0.000729
#                                            16777216       0.000725
#                                            67108864       0.000748
# {'name': 'data_init', 'type': 'function'}  65536          0.002972
#                                            262144         0.437833
#                                            1048576        2.885793
#                                            4194304       11.776099
#                                            16777216      23.919875
#                                            67108864      95.298736
#
#                                                                          \
#                                                      Variance time/rank
# node                                       InputSize
# {'name': 'main', 'type': 'function'}       65536               0.065220
#                                            262144              0.021535
#                                            1048576             0.145994
#                                            4194304             0.492632
#                                            16777216            1.909813
#                                            67108864           26.157127
# {'name': 'comm', 'type': 'function'}       65536               0.033057
#                                            262144              0.017274
#                                            1048576             0.091493
#                                            4194304             1.102606
#                                            16777216            4.363284
#                                            67108864           69.776186
# {'name': 'comm_large', 'type': 'function'} 65536               0.033314
#                                            262144              0.017274
#                                            1048576             0.091493
#                                            4194304             1.102604
#                                            16777216            4.363281
#                                            67108864           69.776165
# {'name': 'comm_small', 'type': 'function'} 65536               0.000000
#                                            262144              0.000000
#                                            1048576             0.000000
#                                            4194304             0.000000
#                                            16777216            0.000000
#                                            67108864            0.000000
# {'name': 'comp', 'type': 'function'}       65536               0.007664
#                                            262144              0.006050
#                                            1048576             0.037642
#                                            4194304             0.443328
#                                            16777216            1.835504
#                                            67108864           25.751257
# {'name': 'comp_large', 'type': 'function'} 65536               0.000000
#                                            262144              0.000000
#                                            1048576             0.000000
#                                            4194304             0.000000
#                                            16777216            0.000000
#                                            67108864            0.000000
# {'name': 'comp_small', 'type': 'function'} 65536               0.000000
#                                            262144              0.000000
#                                            1048576             0.000000
#                                            4194304             0.000000
#                                            16777216            0.000000
#                                            67108864            0.000000
# {'name': 'data_init', 'type': 'function'}  65536               0.000000
#                                            262144              0.000000
#                                            1048576             0.000000
#                                            4194304             0.000000
#                                            16777216            0.000000
#                                            67108864            0.000000
#
#                                                             name
#
# node                                       InputSize
# {'name': 'main', 'type': 'function'}       65536            main
#                                            262144           main
#                                            1048576          main
#                                            4194304          main
#                                            16777216         main
#                                            67108864         main
# {'name': 'comm', 'type': 'function'}       65536            comm
#                                            262144           comm
#                                            1048576          comm
#                                            4194304          comm
#                                            16777216         comm
#                                            67108864         comm
# {'name': 'comm_large', 'type': 'function'} 65536      comm_large
#                                            262144     comm_large
#                                            1048576    comm_large
#                                            4194304    comm_large
#                                            16777216   comm_large
#                                            67108864   comm_large
# {'name': 'comm_small', 'type': 'function'} 65536      comm_small
#                                            262144     comm_small
#                                            1048576    comm_small
#                                            4194304    comm_small
#                                            16777216   comm_small
#                                            67108864   comm_small
# {'name': 'comp', 'type': 'function'}       65536            comp
#                                            262144           comp
#                                            1048576          comp
#                                            4194304          comp
#                                            16777216         comp
#                                            67108864         comp
# {'name': 'comp_large', 'type': 'function'} 65536      comp_large
#                                            262144     comp_large
#                                            1048576    comp_large
#                                            4194304    comp_large
#                                            16777216   comp_large
#                                            67108864   comp_large
# {'name': 'comp_small', 'type': 'function'} 65536      comp_small
#                                            262144     comp_small
#                                            1048576    comp_small
#                                            4194304    comp_small
#                                            16777216   comp_small
#                                            67108864   comp_small
# {'name': 'data_init', 'type': 'function'}  65536       data_init
#                                            262144      data_init
#                                            1048576     data_init
#                                            4194304     data_init
#                                            16777216    data_init
#                                            67108864    data_init

# %% [markdown]
# # STOPPED HERE, EVERYTHING BELOW IS NOT UPDATED

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
for i in ctks.keys():
    if "strong" in i:
        if "cuda" in i:
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", ""), (65536, "nid"), (65536, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
            #ctks[i].dataframe.columns = ctks[i].dataframe.columns.droplevel(1)
        else: 
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", ""), (1048576, "nid"), (1048576, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
            #ctks[i].dataframe.columns = ctks[i].dataframe.columns.droplevel(1)
    else:
        if "cuda" in i:
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", ""), (1024, "nid"), (1024, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("InputSize", ""): "InputSize"}).set_index(["name", "InputSize"])
        else:
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", ""), (128, "nid"), (128, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("InputSize", ""): "InputSize"}).set_index(["name", "InputSize"])

# %%
ctks["mpi_weak_reverse"].dataframe.loc["comp_large"]
# Out:
#                     128                                         \
#           Min time/rank Max time/rank Avg time/rank Total time
# InputSize
# 65536          0.980823      0.980823      0.980823   0.980823
# 262144         1.046472      1.046472      1.046472   1.046472
# 1048576        2.065539      2.065539      2.065539   2.065539
# 4194304        7.839892      7.839892      7.839892   7.839892
# 16777216      15.224531     15.224531     15.224531  15.224531
# 67108864      57.854486     57.854486     57.854486  57.854486
#
#
#           Variance time/rank
# InputSize
# 65536                    0.0
# 262144                   0.0
# 1048576                  0.0
# 4194304                  0.0
# 16777216                 0.0
# 67108864                 0.0

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_random"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 

masterDF
# Out:
#      comm_small  comm_large      comm      comp  data_init  comp_small  \
# 2      0.000005    0.046719  0.046779  0.071519   0.047247    0.000005
# 4      0.000005    0.086876  0.086937  0.041067   0.108311    0.000005
# 8      0.000005    0.217209  0.217269  0.031922   0.210711    0.000006
# 16     0.000005    0.453871  0.453929  0.023368   0.396683    0.000006
# 32     0.000005    0.925047  0.925104  0.018733   0.839441    0.000006
# 64     0.000005    1.656635  1.657630  0.023323   1.553067    0.000006
# 128    0.000005    1.663467  1.663601  0.011220   1.491246    0.000006
# 256    0.000005    3.406599  3.408087  0.008692   3.078852    0.000201
#
#           main  comp_large
# 2     0.433598    0.142988
# 4     0.609539    0.164163
# 8     1.139176    0.255201
# 16    1.880991    0.373545
# 32    3.788112    0.598811
# 64    6.789845    1.491331
# 128   7.737533    1.433524
# 256  13.871407    2.165870

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_random"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI Random Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI Random Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_sorted"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI Sorted Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI Sorted Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_perturbed"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="Merge MPI 1%Perturbed Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'Merge MPI 1%Perturbed Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_reverse"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI Reverse Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI Reverse Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_random"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI Random Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI Random Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_sorted"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="MergeSort MPI Sorted Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'MergeSort MPI Sorted Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_reverse"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="SampleSort MPI Reverse Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'SampleSort MPI Reverse Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_perturbed"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="SampleSort MPI 1%Perturbed Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'SampleSort MPI 1%Perturbed Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %% [markdown]
# ## CUDA GRAPHS

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %% [markdown]
# ### Option 2
# Use `matplotlib.pyplot` directly for more fine-grained control. Specifically for our case we can change the x axis scaling from base 10 to base 2.

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(matrix_sizes)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %% [markdown]
# # Examples

# %% [markdown]
# ## time

# %%
ctk.dataframe.loc["main"]
# Out:
#               128      1024      4096
# threads
# 1        0.000270  0.000257  0.000367
# 2        0.000247  0.000284  0.000406
# 4        0.000256  0.000260  0.000374
# 8        0.000241  0.000278  0.000357
# 16       0.000262  0.000284  0.000356
# 32       0.000264  0.000264  0.000373
# 64       0.000256  0.000284  0.000453
# 96       0.000253  0.000305  0.000417
# 128      0.000287  0.000284  0.000414
# 256      0.000297  0.000317  0.000447
# 512      0.000277  0.000297  0.000446

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Threads",
        ylabel="Time (seconds)",
        loglog=True
    )

# %%
for name in function_names:
    plot_mpl(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Threads",
        ylabel="Time (seconds)",
    )

# %% [markdown]
# ## Speedup

# %%
speedup_df = ctk.dataframe.loc[(slice(None),1), :].reset_index().drop("threads", axis=1).set_index("name")/ctk.dataframe

for name in function_names:
    plot_pandas(
        df=speedup_df.loc[name],
        title=f"{name}: thread-1/thread-N",
        xlabel="Threads",
        ylabel="Speedup",
        loglog=False
    )
