# %% [markdown]
# # FINAL PROJECT THICKET

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

print("done")
# Out:
# done

# %% [markdown]
# Read in all the files

# %% [markdown]
# # MPI Thicket Variables

# %%
mpi_strong_random_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/mpi/strong/random/*.cali"))
mpi_strong_reverse_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/mpi/strong/reverse/*.cali"))
mpi_strong_perturbed_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/mpi/strong/perturbed/*.cali"))
mpi_strong_sorted_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/mpi/strong/sorted/*.cali"))
mpi_weak_random_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/mpi/weak/random/*.cali"))
mpi_weak_reverse_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/mpi/weak/reverse/*.cali"))
mpi_weak_perturbed_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/mpi/weak/perturbed/*.cali"))
mpi_weak_sorted_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/mpi/weak/sorted/*.cali"))

# %% [markdown]
# # CUDA Thicket Variables

# %%
# cuda_strong_random_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/cuda/strong/random/*.cali"))
# cuda_strong_reverse_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/cuda/strong/reverse/*.cali"))
# cuda_strong_perturbed_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/cuda/strong/perturbed/*.cali"))
# cuda_strong_sorted_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/cuda/strong/sorted/*.cali"))
# cuda_weak_random_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/cuda/weak/random/*.cali"))
# cuda_weak_reverse_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/cuda/weak/reverse/*.cali"))
# cuda_weak_perturbed_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/cuda/weak/perturbed/*.cali"))
# cuda_weak_sorted_tk = th.Thicket.from_caliperreader(glob("bitonic_ProjectOuts/cuda/weak/sorted/*.cali"))

# %%
tks = {}

# tks["cuda_weak_sorted"] = cuda_weak_sorted_tk
# tks["cuda_weak_reverse"] = cuda_weak_reverse_tk
# tks["cuda_weak_random"] = cuda_weak_random_tk
# tks["cuda_weak_perturbed"] = cuda_weak_perturbed_tk

# tks["cuda_strong_sorted"] = cuda_strong_sorted_tk
# tks["cuda_strong_reverse"] = cuda_strong_reverse_tk
# tks["cuda_strong_random"] = cuda_strong_random_tk
# tks["cuda_strong_perturbed"] = cuda_strong_perturbed_tk

tks["mpi_weak_sorted"] = mpi_weak_sorted_tk
tks["mpi_weak_reverse"] = mpi_weak_reverse_tk
tks["mpi_weak_random"] = mpi_weak_random_tk
tks["mpi_weak_perturbed"] = mpi_weak_perturbed_tk

tks["mpi_strong_sorted"] = mpi_strong_sorted_tk
tks["mpi_strong_reverse"] = mpi_strong_reverse_tk
tks["mpi_strong_random"] = mpi_strong_random_tk
tks["mpi_strong_perturbed"] = mpi_strong_perturbed_tk

# %%
# Performance data
tks["mpi_strong_random"].dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              407315106     1
#                                                   682169215     1
#                                                   1094926583    1
#                                                   1403954364    1
#                                                   1920087777    1
#                                                   1982376986    1
#                                                   3390726365    1
# {'name': 'comm', 'type': 'function'}              407315106     5
#                                                   682169215     5
#                                                   1094926583    5
#                                                   1403954364    5
#                                                   1920087777    5
# ...

# %%
for i in tks.values():
    i.statsframe.dataframe["time"] = 1

print(tks["mpi_weak_random"].tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# │     ├─ 1.000 MPI_Gather
# │     ├─ 1.000 MPI_Recv
# │     └─ 1.000 MPI_Send
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tks["mpi_strong_random"].metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 407315106            2.11.0-dev               2
# 682169215            2.11.0-dev             128
# 1094926583           2.11.0-dev               8
# 1403954364           2.11.0-dev              32
# 1920087777           2.11.0-dev              64
# 1982376986           2.11.0-dev              16
# 3390726365           2.11.0-dev               4
#
#                                                  spot.metrics  \
# profile
# 407315106   min#inclusive#sum#time.duration,max#inclusive#...
# 682169215   min#inclusive#sum#time.duration,max#inclusive#...
# 1094926583  min#inclusive#sum#time.duration,max#inclusive#...
# 1403954364  min#inclusive#sum#time.duration,max#inclusive#...
# 1920087777  min#inclusive#sum#time.duration,max#inclusive#...
# 1982376986  min#inclusive#sum#time.duration,max#inclusive#...
# 3390726365  min#inclusive#sum#time.duration,max#inclusive#...
#
# ...

# %%
gbs = {}

for i in tks.keys():
    if "strong" in i:
        gbs[i] = tks[i].groupby("InputSize")
    else:
        if i.startswith("cuda"):
            gbs[i] = tks[i].groupby("num_threads")
        else:
            gbs[i] = tks[i].groupby("num_procs")
# Out:
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b1e1c340df0>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b1e1c258100>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b1e1c349400>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b1e1c294190>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b1e1c1e40d0>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b1e1c29aaf0>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b1e1c252040>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b1e1c545370>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
print(gbs.keys())
# Out:
# dict_keys(['mpi_weak_sorted', 'mpi_weak_reverse', 'mpi_weak_random', 'mpi_weak_perturbed', 'mpi_strong_sorted', 'mpi_strong_reverse', 'mpi_strong_random', 'mpi_strong_perturbed'])

# %%
ctks = {}

for i in gbs.keys():
    if "strong" in i:
        if i.startswith("cuda"):
            ctks[i] = th.Thicket.concat_thickets(
                thickets=list(gbs[i].values()),
                headers=list(gbs[i].keys()),
                axis="columns",
                metadata_key="num_threads"
            )
        else:
            ctks[i] = th.Thicket.concat_thickets(
                thickets=list(gbs[i].values()),
                headers=list(gbs[i].keys()),
                axis="columns",
                metadata_key="num_procs"
            )
    else:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="InputSize"
        )

# %%
# mpi_strong_random_ctk.dataframe

ctks["mpi_strong_random"].dataframe
# Out:
#                                                             1048576  \
#                                                                 nid
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2               1
#                                                   4               1
#                                                   8               1
#                                                   16              1
#                                                   32              1
#                                                   64              1
#                                                   128             1
# {'name': 'comm', 'type': 'function'}              2               5
#                                                   4               5
#                                                   8               5
#                                                   16              5
# ...

# %%
ctks["mpi_weak_random"].dataframe
# Out:
#                                                             128  \
#                                                             nid
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              65536       1
#                                                   262144      1
#                                                   1048576     1
# {'name': 'comm', 'type': 'function'}              65536       5
#                                                   262144      5
#                                                   1048576     5
# {'name': 'comm_large', 'type': 'function'}        65536       6
#                                                   262144      6
#                                                   1048576     6
# {'name': 'MPI_Gather', 'type': 'function'}        65536       9
#                                                   262144      9
#                                                   1048576     9
# ...

# %%
for i in ctks.keys():
    if "strong" in i:
        if "cuda" in i:
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", ""), (65536, "nid"), (65536, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
            #ctks[i].dataframe.columns = ctks[i].dataframe.columns.droplevel(1)
        else: 
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", ""), (1048576, "nid"), (1048576, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
            #ctks[i].dataframe.columns = ctks[i].dataframe.columns.droplevel(1)
    else:
        if "cuda" in i:
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", ""), (2048, "nid"), (2048, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("InputSize", ""): "InputSize"}).set_index(["name", "InputSize"])
        else:
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", ""), (128, "nid"), (128, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("InputSize", ""): "InputSize"}).set_index(["name", "InputSize"])

# %%
ctks["mpi_weak_reverse"].dataframe
# Out:
#                                       128                              \
#                             Min time/rank Max time/rank Avg time/rank
# name              InputSize
# main              65536          3.119962      3.738044      3.473279
#                   262144         2.549131      6.117956      5.641632
#                   1048576        2.148986      2.473740      2.262717
# comm              65536          0.775534      0.970676      0.867266
#                   262144         0.753699      0.975690      0.863075
#                   1048576        0.727137      0.925549      0.831572
# comm_large        65536          0.775109      0.970245      0.866837
#                   262144         0.753267      0.975258      0.862408
#                   1048576        0.726709      0.925115      0.831140
# MPI_Gather        65536          0.000053      0.114688      0.016090
#                   262144         0.000046      0.077574      0.000894
# ...

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
function_names = set(ctks["cuda_strong_reverse"].dataframe.index.get_level_values("name"))
if "strong" in "cuda_strong_reverse":
    if "cuda_strong_reverse".startswith("cuda"):
        threads = sorted(list(set(ctks["cuda_strong_reverse"].dataframe.index.get_level_values("num_threads"))))
    else:
        threads = sorted(list(set(ctks["cuda_strong_reverse"].dataframe.index.get_level_values("num_procs"))))
else:
    threads = sorted(list(set(ctks["cuda_strong_reverse"].dataframe.index.get_level_values("InputSize"))))
matrix_sizes = sorted(ctks["cuda_strong_reverse"].dataframe.columns.tolist())
print(function_names)
for name in function_names:
    plot_pandas(
        df=ctks["cuda_strong_reverse"].dataframe.loc[name],
        title=name,
        xlabel="Threads",
        ylabel="Time (seconds)",
        loglog=False
    )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-938d972cdadf> in <module>
# ----> 1 function_names = set(ctks["cuda_strong_reverse"].dataframe.index.get_level_values("name"))
#       2 if "strong" in "cuda_strong_reverse":
#       3     if "cuda_strong_reverse".startswith("cuda"):
#       4         threads = sorted(list(set(ctks["cuda_strong_reverse"].dataframe.index.get_level_values("num_threads"))))
#       5     else:
#
# KeyError: 'cuda_strong_reverse'

# %% [markdown]
# ### Option 2
# Use `matplotlib.pyplot` directly for more fine-grained control. Specifically for our case we can change the x axis scaling from base 10 to base 2.

# %% [markdown]
# # Examples

# %%
ctks["cuda_weak_random"].dataframe.loc["main"]
# Out:
#                    2048                                         \
#           Min time/rank Max time/rank Avg time/rank Total time
# InputSize
# 65536          0.440550      0.440550      0.440550   0.440550
# 262144         0.428625      0.428625      0.428625   0.428625
# 1048576        0.448709      0.448709      0.448709   0.448709
# 4194304        0.551724      0.551724      0.551724   0.551724
# 16777216       1.271019      1.271019      1.271019   1.271019
# 67108864       2.093767      2.093767      2.093767   2.093767
# 268435456      7.457988      7.457988      7.457988   7.457988
#
#
#           Avg GPU time/rank Min GPU time/rank Max GPU time/rank Total GPU time
# InputSize
# 65536              0.000025          0.000025          0.000025       0.000025
# 262144             0.000085          0.000085          0.000085       0.000085
# 1048576            0.000570          0.000570          0.000570       0.000570
# ...

# %%
ctks["mpi_strong_reverse"].dataframe.loc["comp_large"]
# Out:
#                 1048576                                          \
#           Min time/rank Max time/rank Avg time/rank  Total time
# num_procs
# 2              0.204447      0.208275      0.206361    0.412722
# 4              0.380803      0.797674      0.592777    2.371107
# 8              0.672085      1.483650      1.227293    9.818347
# 16             1.236777      2.678884      2.384100   38.145602
# 32             1.750150      4.743199      3.832324  122.634379
# 64             0.645847      7.644905      2.216923  141.883058
# 128            0.076142      1.456085      0.800299  102.438253
# 256            0.098092      0.810502      0.473256  121.153573
# 512            0.068122      0.601787      0.321103  164.404960
# 1024           0.086983      0.401302      0.228485  233.968845
#
#
#           Variance time/rank
# num_procs
# 2                   0.000004
# 4                   0.040512
# 8                   0.100937
# 16                  0.192428
# ...

# %%
ctks["mpi_weak_reverse"].dataframe.loc["comp_large"]
# Out:
#                     128                                            \
#           Min time/rank Max time/rank Avg time/rank    Total time
# InputSize
# 65536          0.003785      0.030318      0.010445      1.336982
# 262144         0.016909      0.190206      0.080973     10.364494
# 1048576        0.076142      1.456085      0.800299    102.438253
# 4194304       12.447394     33.430897     30.745836   3935.467045
# 16777216      80.021047    188.631225    182.447741  23353.310796
#
#
#           Variance time/rank
# InputSize
# 65536               0.000019
# 262144              0.000846
# 1048576             0.055398
# 4194304             6.028020
# 16777216          170.569521

# %%
function_names = ("main", "comp", "comm", "comm_large", "comp_large")

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %% [markdown]
# # MPI GRAPHS

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_random"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 

masterDF
# Out:
#          main      comp      comm  comm_large  comp_large
# 2    0.367374  0.066455  0.019730    0.019698    0.066412
# 4    0.386083  0.085806  0.015609    0.015546    0.085733
# 8    0.403061  0.079889  0.024792    0.024685    0.079769
# 16   0.386944  0.062291  0.022332    0.022168    0.062102
# 32   0.824445  0.072356  0.221737    0.221491    0.072056
# 64   1.222102  0.057447  0.384479    0.383187    0.056634
# 128  2.927645  0.036105  0.918926    0.918259    0.035392

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_random"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BitonicSort MPI Random Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BitonicSort MPI Random Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_sorted"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BitonicSort MPI Sorted Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BitonicSort MPI Sorted Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_perturbed"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="Bitonic MPI 1%Perturbed Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'Bitonic MPI 1%Perturbed Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_reverse"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="Bitonic MPI Reverse Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'Bitonic MPI Reverse Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_random"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="Bitonic MPI Random Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'Bitonic MPI Random Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_sorted"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="Bitonic MPI Sorted Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'Bitonic MPI Sorted Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_reverse"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="Bitonic MPI Reverse Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'Bitonic MPI Reverse Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_perturbed"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="Bitonic MPI 1%Perturbed Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'Bitonic MPI 1%Perturbed Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %% [markdown]
# # CUDA GRAPHS

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_random"].dataframe.loc[name][(65536, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Random Input, Sorting 65536 Values, Total GPU time",
    xlabel="Num_threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Random Input, Sorting 65536 Values, Total GPU time'}, xlabel='Num_threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_sorted"].dataframe.loc[name][(65536, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Sorted Input, Sorting 65536 Values, Total GPU time",
    xlabel="Num_threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Sorted Input, Sorting 65536 Values, Total GPU time'}, xlabel='Num_threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_perturbed"].dataframe.loc[name][(65536, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA 1%Perturbed Input, Sorting 65536 Values, Total GPU time",
    xlabel="Num_threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA 1%Perturbed Input, Sorting 65536 Values, Total GPU time'}, xlabel='Num_threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_reverse"].dataframe.loc[name][(65536, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Reverse Input, Sorting 65536 Values, Total GPU time",
    xlabel="Num_threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Reverse Input, Sorting 65536 Values, Total GPU time'}, xlabel='Num_threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_random"].dataframe.loc[name][(2048, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Random Input, with 2048 Threads, Total GPU time",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Random Input, with 2048 Threads, Total GPU time'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_sorted"].dataframe.loc[name][(2048, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Sorted Input, with 2048 Threads, Total GPU time",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Sorted Input, with 2048 Threads, Total GPU time'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_perturbed"].dataframe.loc[name][(2048, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA 1%Perturbed Input, with 2048 Threads, Total GPU time",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA 1%Perturbed Input, with 2048 Threads, Total GPU time'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_reverse"].dataframe.loc[name][(2048, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Reverse Input, with 2048 Threads, Total GPU time",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Reverse Input, with 2048 Threads, Total GPU time'}, xlabel='Input Size', ylabel='Time (seconds)'>
