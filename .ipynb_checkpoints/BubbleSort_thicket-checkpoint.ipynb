# %% [markdown]
# # FINAL PROJECT THICKET

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

print("done")
# Out:
# done

# %% [markdown]
# Read in all the files

# %% [markdown]
# # MPI Thicket Variables

# %%
mpi_strong_random_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/mpi/strong/random/*.cali"))
mpi_strong_reverse_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/mpi/strong/reverse/*.cali"))
mpi_strong_perturbed_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/mpi/strong/perturbed/*.cali"))
mpi_strong_sorted_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/mpi/strong/sorted/*.cali"))
mpi_weak_random_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/mpi/weak/random/*.cali"))
mpi_weak_reverse_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/mpi/weak/reverse/*.cali"))
mpi_weak_perturbed_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/mpi/weak/perturbed/*.cali"))
mpi_weak_sorted_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/mpi/weak/sorted/*.cali"))

# %% [markdown]
# # CUDA Thicket Variables

# %%
cuda_strong_random_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/cuda/strong/random/*.cali"))
cuda_strong_reverse_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/cuda/strong/reverse/*.cali"))
cuda_strong_perturbed_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/cuda/strong/perturbed/*.cali"))
cuda_strong_sorted_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/cuda/strong/sorted/*.cali"))
cuda_weak_random_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/cuda/weak/random/*.cali"))
cuda_weak_reverse_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/cuda/weak/reverse/*.cali"))
cuda_weak_perturbed_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/cuda/weak/perturbed/*.cali"))
cuda_weak_sorted_tk = th.Thicket.from_caliperreader(glob("BubbleProjectOuts/cuda/weak/sorted/*.cali"))

# %%
tks = {}

tks["cuda_weak_sorted"] = cuda_weak_sorted_tk
tks["cuda_weak_reverse"] = cuda_weak_reverse_tk
tks["cuda_weak_random"] = cuda_weak_random_tk
tks["cuda_weak_perturbed"] = cuda_weak_perturbed_tk

tks["cuda_strong_sorted"] = cuda_strong_sorted_tk
tks["cuda_strong_reverse"] = cuda_strong_reverse_tk
tks["cuda_strong_random"] = cuda_strong_random_tk
tks["cuda_strong_perturbed"] = cuda_strong_perturbed_tk

tks["mpi_weak_sorted"] = mpi_weak_sorted_tk
tks["mpi_weak_reverse"] = mpi_weak_reverse_tk
tks["mpi_weak_random"] = mpi_weak_random_tk
tks["mpi_weak_perturbed"] = mpi_weak_perturbed_tk

tks["mpi_strong_sorted"] = mpi_strong_sorted_tk
tks["mpi_strong_reverse"] = mpi_strong_reverse_tk
tks["mpi_strong_random"] = mpi_strong_random_tk
tks["mpi_strong_perturbed"] = mpi_strong_perturbed_tk

# %%
# Performance data
tks["mpi_strong_random"].dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              64191534      1
#                                                   627229148     1
#                                                   825729823     1
#                                                   1034285532    1
#                                                   1266349550    1
#                                                   1325118773    1
#                                                   1725098072    1
#                                                   2935305844    1
#                                                   3115198448    1
#                                                   3889328052    1
# {'name': 'comm', 'type': 'function'}              64191534      3
#                                                   627229148     3
#                                                   825729823     3
#                                                   1034285532    3
#                                                   1266349550    3
#                                                   1325118773    3
#                                                   1725098072    3
#                                                   2935305844    3
#                                                   3115198448    3
#                                                   3889328052    3
# {'name': 'MPI_Barrier', 'type': 'function'}       64191534      4
#                                                   627229148     4
#                                                   825729823     4
#                                                   1034285532    4
#                                                   1266349550    4
#                                                   1325118773    4
#                                                   1725098072    4
#                                                   2935305844    4
#                                                   3115198448    4
#                                                   3889328052    4
# {'name': 'comm_large', 'type': 'function'}        64191534      5
#                                                   627229148     5
#                                                   825729823     5
#                                                   1034285532    5
#                                                   1266349550    5
#                                                   1325118773    5
#                                                   1725098072    5
#                                                   2935305844    5
#                                                   3115198448    5
#                                                   3889328052    5
# {'name': 'MPI_Recv', 'type': 'function'}          64191534      7
#                                                   627229148     7
#                                                   825729823     7
#                                                   1034285532    7
#                                                   1266349550    7
#                                                   1325118773    7
#                                                   1725098072    7
#                                                   2935305844    7
#                                                   3115198448    7
#                                                   3889328052    7
# {'name': 'MPI_Send', 'type': 'function'}          64191534      6
#                                                   627229148     6
#                                                   825729823     6
#                                                   1034285532    6
#                                                   1266349550    6
#                                                   1325118773    6
#                                                   1725098072    6
#                                                   2935305844    6
#                                                   3115198448    6
#                                                   3889328052    6
# {'name': 'comm_small', 'type': 'function'}        64191534     10
#                                                   627229148    10
#                                                   825729823    10
#                                                   1034285532   10
#                                                   1266349550   10
#                                                   1325118773   10
#                                                   1725098072   10
#                                                   2935305844   10
#                                                   3115198448   10
#                                                   3889328052   10
# {'name': 'MPI_Gather', 'type': 'function'}        64191534     11
#                                                   627229148    11
#                                                   825729823    11
#                                                   1034285532   11
#                                                   1266349550   11
#                                                   1325118773   11
#                                                   1725098072   11
#                                                   2935305844   11
#                                                   3115198448   11
#                                                   3889328052   11
# {'name': 'comp', 'type': 'function'}              64191534      8
#                                                   627229148     8
#                                                   825729823     8
#                                                   1034285532    8
#                                                   1266349550    8
#                                                   1325118773    8
#                                                   1725098072    8
#                                                   2935305844    8
#                                                   3115198448    8
#                                                   3889328052    8
# {'name': 'comp_large', 'type': 'function'}        64191534      9
#                                                   627229148     9
#                                                   825729823     9
#                                                   1034285532    9
#                                                   1266349550    9
#                                                   1325118773    9
#                                                   1725098072    9
#                                                   2935305844    9
#                                                   3115198448    9
#                                                   3889328052    9
# {'name': 'correctness_check', 'type': 'function'} 64191534     12
#                                                   627229148    12
#                                                   825729823    12
#                                                   1034285532   12
#                                                   1266349550   12
#                                                   1325118773   12
#                                                   1725098072   12
#                                                   2935305844   12
#                                                   3115198448   12
#                                                   3889328052   12
# {'name': 'data_init', 'type': 'function'}         64191534      2
#                                                   627229148     2
#                                                   825729823     2
#                                                   1034285532    2
#                                                   1266349550    2
#                                                   1325118773    2
#                                                   1725098072    2
#                                                   2935305844    2
#                                                   3115198448    2
#                                                   3889328052    2
#
#                                                                spot.channel  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
# {'name': 'comm', 'type': 'function'}              64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
# {'name': 'MPI_Barrier', 'type': 'function'}       64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
# {'name': 'comm_large', 'type': 'function'}        64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
# {'name': 'MPI_Recv', 'type': 'function'}          64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
# {'name': 'MPI_Send', 'type': 'function'}          64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
# {'name': 'comm_small', 'type': 'function'}        64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
# {'name': 'MPI_Gather', 'type': 'function'}        64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
# {'name': 'comp', 'type': 'function'}              64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
# {'name': 'comp_large', 'type': 'function'}        64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
# {'name': 'correctness_check', 'type': 'function'} 64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
# {'name': 'data_init', 'type': 'function'}         64191534    regionprofile
#                                                   627229148   regionprofile
#                                                   825729823   regionprofile
#                                                   1034285532  regionprofile
#                                                   1266349550  regionprofile
#                                                   1325118773  regionprofile
#                                                   1725098072  regionprofile
#                                                   2935305844  regionprofile
#                                                   3115198448  regionprofile
#                                                   3889328052  regionprofile
#
#                                                               Min time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              64191534         2.474227
#                                                   627229148       24.166913
#                                                   825729823       26.351911
#                                                   1034285532      21.038272
#                                                   1266349550      14.020606
#                                                   1325118773       3.197389
#                                                   1725098072      39.216372
#                                                   2935305844      20.018770
#                                                   3115198448       1.783743
#                                                   3889328052       8.766759
# {'name': 'comm', 'type': 'function'}              64191534         0.025958
#                                                   627229148       10.592285
#                                                   825729823       11.354272
#                                                   1034285532       9.502511
#                                                   1266349550       3.430648
#                                                   1325118773       0.348239
#                                                   1725098072      12.888901
#                                                   2935305844       3.318112
#                                                   3115198448       0.182790
#                                                   3889328052       0.947052
# {'name': 'MPI_Barrier', 'type': 'function'}       64191
#                                                   627229148             0.016783
#                                                   825729823             0.005697
#                                                   1034285532            0.047189
#                                                   1266349550            0.411066
#                                                   1325118773            0.097615
#                                                   1725098072            0.002164
#                                                   2935305844            1.742678
#                                                   3115198448            0.042044
#                                                   3889328052            0.190640
# {'name': 'comp_large', 'type': 'function'}        64191534              0.000032
#                                                   627229148             0.016678
#                                                   825729823             0.005478
#                                                   1034285532            0.046885
#                                                   1266349550            0.427384
#                                                   1325118773            0.095702
#                                                   1725098072            0.002025
#                                                   2935305844            1.736717
#                                                   3115198448            0.042034
#                                                   3889328052            0.194115
# {'name': 'correctness_check', 'type': 'function'} 64191534              0.000000
#                                                   627229148             0.000000
#                                                   825729823             0.000000
#                                                   1034285532            0.000000
#                                                   1266349550            0.000000
#                                                   1325118773            0.000000
#                                                   1725098072            0.000000
#                                                   2935305844            0.000000
#                                                   3115198448            0.000000
#                                                   3889328052            0.000000
# {'name': 'data_init', 'type': 'function'}         64191534              0.000084
#                                                   627229148             0.000315
#                                                   825729823             0.000142
#                                                   1034285532            0.002576
#                                                   1266349550            0.007761
#                                                   1325118773            0.000040
#                                                   1725098072            0.000006
#                                                   2935305844            0.004174
#                                                   3115198448            0.000212
#                                                   3889328052            0.001483
#
#                                                                            name
# node                                              profile
# {'name': 'main', 'type': 'function'}              64191534                 main
#                                                   627229148                main
#                                                   825729823                main
#                                                   1034285532               main
#                                                   1266349550               main
#                                                   1325118773               main
#                                                   1725098072               main
#                                                   2935305844               main
#                                                   3115198448               main
#                                                   3889328052               main
# {'name': 'comm', 'type': 'function'}              64191534                 comm
#                                                   627229148                comm
#                                                   825729823                comm
#                                                   1034285532               comm
#                                                   1266349550               comm
#                                                   1325118773               comm
#                                                   1725098072               comm
#                                                   2935305844               comm
#                                                   3115198448               comm
#                                                   3889328052               comm
# {'name': 'MPI_Barrier', 'type': 'function'}       64191534          MPI_Barrier
#                                                   627229148         MPI_Barrier
#                                                   825729823         MPI_Barrier
#                                                   1034285532        MPI_Barrier
#                                                   1266349550        MPI_Barrier
#                                                   1325118773        MPI_Barrier
#                                                   1725098072        MPI_Barrier
#                                                   2935305844        MPI_Barrier
#                                                   3115198448        MPI_Barrier
#                                                   3889328052        MPI_Barrier
# {'name': 'comm_large', 'type': 'function'}        64191534           comm_large
#                                                   627229148          comm_large
#                                                   825729823          comm_large
#                                                   1034285532         comm_large
#                                                   1266349550         comm_large
#                                                   1325118773         comm_large
#                                                   1725098072         comm_large
#                                                   2935305844         comm_large
#                                                   3115198448         comm_large
#                                                   3889328052         comm_large
# {'name': 'MPI_Recv', 'type': 'function'}          64191534             MPI_Recv
#                                                   627229148            MPI_Recv
#                                                   825729823            MPI_Recv
#                                                   1034285532           MPI_Recv
#                                                   1266349550           MPI_Recv
#                                                   1325118773           MPI_Recv
#                                                   1725098072           MPI_Recv
#                                                   2935305844           MPI_Recv
#                                                   3115198448           MPI_Recv
#                                                   3889328052           MPI_Recv
# {'name': 'MPI_Send', 'type': 'function'}          64191534             MPI_Send
#                                                   627229148            MPI_Send
#                                                   825729823            MPI_Send
#                                                   1034285532           MPI_Send
#                                                   1266349550           MPI_Send
#                                                   1325118773           MPI_Send
#                                                   1725098072           MPI_Send
#                                                   2935305844           MPI_Send
#                                                   3115198448           MPI_Send
#                                                   3889328052           MPI_Send
# {'name': 'comm_small', 'type': 'function'}        64191534           comm_small
#                                                   627229148          comm_small
#                                                   825729823          comm_small
#                                                   1034285532         comm_small
#                                                   1266349550         comm_small
#                                                   1325118773         comm_small
#                                                   1725098072         comm_small
#                                                   2935305844         comm_small
#                                                   3115198448         comm_small
#                                                   3889328052         comm_small
# {'name': 'MPI_Gather', 'type': 'function'}        64191534           MPI_Gather
#                                                   627229148          MPI_Gather
#                                                   825729823          MPI_Gather
#                                                   1034285532         MPI_Gather
#                                                   1266349550         MPI_Gather
#                                                   1325118773         MPI_Gather
#                                                   1725098072         MPI_Gather
#                                                   2935305844         MPI_Gather
#                                                   3115198448         MPI_Gather
#                                                   3889328052         MPI_Gather
# {'name': 'comp', 'type': 'function'}              64191534                 comp
#                                                   627229148                comp
#                                                   825729823                comp
#                                                   1034285532               comp
#                                                   1266349550               comp
#                                                   1325118773               comp
#                                                   1725098072               comp
#                                                   2935305844               comp
#                                                   3115198448               comp
#                                                   3889328052               comp
# {'name': 'comp_large', 'type': 'function'}        64191534           comp_large
#                                                   627229148          comp_large
#                                                   825729823          comp_large
#                                                   1034285532         comp_large
#                                                   1266349550         comp_large
#                                                   1325118773         comp_large
#                                                   1725098072         comp_large
#                                                   2935305844         comp_large
#                                                   3115198448         comp_large
#                                                   3889328052         comp_large
# {'name': 'correctness_check', 'type': 'function'} 64191534    correctness_check
#                                                   627229148   correctness_check
#                                                   825729823   correctness_check
#                                                   1034285532  correctness_check
#                                                   1266349550  correctness_check
#                                                   1325118773  correctness_check
#                                                   1725098072  correctness_check
#                                                   2935305844  correctness_check
#                                                   3115198448  correctness_check
#                                                   3889328052  correctness_check
# {'name': 'data_init', 'type': 'function'}         64191534            data_init
#                                                   627229148           data_init
#                                                   825729823           data_init
#                                                   1034285532          data_init
#                                                   1266349550          data_init
#                                                   1325118773          data_init
#                                                   1725098072          data_init
#                                                   2935305844          data_init
#                                                   3115198448          data_init
#                                                   3889328052          data_init

# %%
for i in tks.values():
    i.statsframe.dataframe["time"] = 1

print(tks["mpi_strong_random"].tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  ├─ 1.000 MPI_Barrier
# │  ├─ 1.000 comm_large
# │  │  ├─ 1.000 MPI_Recv
# │  │  └─ 1.000 MPI_Send
# │  └─ 1.000 comm_small
# │     └─ 1.000 MPI_Gather
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tks["mpi_strong_random"].metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 64191534             2.11.0-dev               2
# 627229148            2.11.0-dev             256
# 825729823            2.11.0-dev             512
# 1034285532           2.11.0-dev             128
# 1266349550           2.11.0-dev              32
# 1325118773           2.11.0-dev               8
# 1725098072           2.11.0-dev            1024
# 2935305844           2.11.0-dev              64
# 3115198448           2.11.0-dev               4
# 3889328052           2.11.0-dev              16
#
#                                                  spot.metrics  \
# profile
# 64191534    min#inclusive#sum#time.duration,max#inclusive#...
# 627229148   min#inclusive#sum#time.duration,max#inclusive#...
# 825729823   min#inclusive#sum#time.duration,max#inclusive#...
# 1034285532  min#inclusive#sum#time.duration,max#inclusive#...
# 1266349550  min#inclusive#sum#time.duration,max#inclusive#...
# 1325118773  min#inclusive#sum#time.duration,max#inclusive#...
# 1725098072  min#inclusive#sum#time.duration,max#inclusive#...
# 2935305844  min#inclusive#sum#time.duration,max#inclusive#...
# 3115198448  min#inclusive#sum#time.duration,max#inclusive#...
# 3889328052  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 64191534                                              2
# 627229148                                             2
# 825729823                                             2
# 1034285532                                            2
# 1266349550                                            2
# 1325118773                                            2
# 1725098072                                            2
# 2935305844                                            2
# 3115198448                                            2
# 3889328052                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 64191534    time.variance,node.order  regionprofile         spot
# 627229148   time.variance,node.order  regionprofile         spot
# 825729823   time.variance,node.order  regionprofile         spot
# 1034285532  time.variance,node.order  regionprofile         spot
# 1266349550  time.variance,node.order  regionprofile         spot
# 1325118773  time.variance,node.order  regionprofile         spot
# 1725098072  time.variance,node.order  regionprofile         spot
# 2935305844  time.variance,node.order  regionprofile         spot
# 3115198448  time.variance,node.order  regionprofile         spot
# 3889328052  time.variance,node.order  regionprofile         spot
#
#            spot:node.order                                        spot:output  \
# profile
# 64191534              true  outs/Random/p2/bubble_mpi_p2-a1048576-Random.cali
# 627229148             true  outs/Random/p256/bubble_mpi_p256-a1048576-Rand...
# 825729823             true  outs/Random/p512/bubble_mpi_p512-a1048576-Rand...
# 1034285532            true  outs/Random/p128/bubble_mpi_p128-a1048576-Rand...
# 1266349550            true  outs/Random/p32/bubble_mpi_p32-a1048576-Random...
# 1325118773            true  outs/Random/p8/bubble_mpi_p8-a1048576-Random.cali
# 1725098072            true  outs/Random/p1024/bubble_mpi_p1024-a1048576-Ra...
# 2935305844            true  outs/Random/p64/bubble_mpi_p64-a1048576-Random...
# 3115198448            true  outs/Random/p4/bubble_mpi_p4-a1048576-Random.cali
# 3889328052            true  outs/Random/p16/bubble_mpi_p16-a1048576-Random...
#
#            spot:time.variance  launchdate  \
# profile
# 64191534                 true  1700067465
# 627229148                true  1700070463
# 825729823                true  1700070546
# 1034285532               true  1700070095
# 1266349550               true  1700067537
# 1325118773               true  1700067510
# 1725098072               true  1700070606
# 2935305844               true  1700067574
# 3115198448               true  1700067488
# 3889328052               true  1700067516
#
#                                                     libraries  \
# profile
# 64191534    [/scratch/group/csce435-f23/Caliper/caliper/li...
# 627229148   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 825729823   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1034285532  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1266349550  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1325118773  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1725098072  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2935305844  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3115198448  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3889328052  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                     cmdline cluster   Algorithm  \
# profile
# 64191534    [./bubble_mpi, 1048576, Random]       c  BubbleSort
# 627229148   [./bubble_mpi, 1048576, Random]       c  BubbleSort
# 825729823   [./bubble_mpi, 1048576, Random]       c  BubbleSort
# 1034285532  [./bubble_mpi, 1048576, Random]       c  BubbleSort
# 1266349550  [./bubble_mpi, 1048576, Random]       c  BubbleSort
# 1325118773  [./bubble_mpi, 1048576, Random]       c  BubbleSort
# 1725098072  [./bubble_mpi, 1048576, Random]       c  BubbleSort
# 2935305844  [./bubble_mpi, 1048576, Random]       c  BubbleSort
# 3115198448  [./bubble_mpi, 1048576, Random]       c  BubbleSort
# 3889328052  [./bubble_mpi, 1048576, Random]       c  BubbleSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 64191534                MPI    float               4    1048576    Random
# 627229148               MPI    float               4    1048576    Random
# 825729823               MPI    float               4    1048576    Random
# 1034285532              MPI    float               4    1048576    Random
# 1266349550              MPI    float               4    1048576    Random
# 1325118773              MPI    float               4    1048576    Random
# 1725098072              MPI    float               4    1048576    Random
# 2935305844              MPI    float               4    1048576    Random
# 3115198448              MPI    float               4    1048576    Random
# 3889328052              MPI    float               4    1048576    Random
#
#             num_procs num_threads num_blocks  group_num implementation_source
# profile
# 64191534            2         N/A        N/A          1             Online/AI
# 627229148         256         N/A        N/A          1             Online/AI
# 825729823         512         N/A        N/A          1             Online/AI
# 1034285532        128         N/A        N/A          1             Online/AI
# 1266349550         32         N/A        N/A          1             Online/AI
# 1325118773          8         N/A        N/A          1             Online/AI
# 1725098072       1024         N/A        N/A          1             Online/AI
# 2935305844         64         N/A        N/A          1             Online/AI
# 3115198448          4         N/A        N/A          1             Online/AI
# 3889328052         16         N/A        N/A          1             Online/AI

# %%
gbs = {}

for i in tks.keys():
    if "strong" in i:
        gbs[i] = tks[i].groupby("InputSize")
    else:
        if i.startswith("cuda"):
            gbs[i] = tks[i].groupby("num_threads")
        else:
            gbs[i] = tks[i].groupby("num_procs")
# Out:
# 1  thickets created...
# {2048: <thicket.thicket.Thicket object at 0x2b15bfff7280>}
# 1  thickets created...
# {2048: <thicket.thicket.Thicket object at 0x2b15bfcaff10>}
# 1  thickets created...
# {2048: <thicket.thicket.Thicket object at 0x2b15bfe9fac0>}
# 1  thickets created...
# {2048: <thicket.thicket.Thicket object at 0x2b15c0753c40>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b15bfd656d0>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b15bfef5cd0>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b15bff1e670>}
# 1  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b15c081c8b0>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b15bfa58fd0>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b15bfb28850>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b15bfb29a00>}
# 1  thickets created...
# {128: <thicket.thicket.Thicket object at 0x2b15bfd57b50>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b15c0809e80>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b15c0822fd0>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b15bfe686d0>}
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2b15c0da4610>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
print(gbs.keys())
# Out:
# dict_keys(['cuda_weak_sorted', 'cuda_weak_reverse', 'cuda_weak_random', 'cuda_weak_perturbed', 'cuda_strong_sorted', 'cuda_strong_reverse', 'cuda_strong_random', 'cuda_strong_perturbed', 'mpi_weak_sorted', 'mpi_weak_reverse', 'mpi_weak_random', 'mpi_weak_perturbed', 'mpi_strong_sorted', 'mpi_strong_reverse', 'mpi_strong_random', 'mpi_strong_perturbed'])

# %%
ctks = {}

for i in gbs.keys():
    if "strong" in i:
        if i.startswith("cuda"):
            ctks[i] = th.Thicket.concat_thickets(
                thickets=list(gbs[i].values()),
                headers=list(gbs[i].keys()),
                axis="columns",
                metadata_key="num_threads"
            )
        else:
            ctks[i] = th.Thicket.concat_thickets(
                thickets=list(gbs[i].values()),
                headers=list(gbs[i].keys()),
                axis="columns",
                metadata_key="num_procs"
            )
    else:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="InputSize"
        )

# %%
# mpi_strong_random_ctk.dataframe

ctks["cuda_strong_random"].dataframe
# Out:
#                                                               65536  \
#                                                                 nid
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64              1
#                                                   128             1
#                                                   256             1
#                                                   512             1
#                                                   1024            1
#                                                   2048            1
#                                                   4096            1
# {'name': 'comm', 'type': 'function'}              64              5
#                                                   128             5
#                                                   256             5
#                                                   512             5
#                                                   1024            5
#                                                   2048            5
#                                                   4096            5
# {'name': 'comm_large', 'type': 'function'}        64              6
#                                                   128             6
#                                                   256             6
#                                                   512             6
#                                                   1024            6
#                                                   2048            6
#                                                   4096            6
# {'name': 'cudaMemcpy', 'type': 'function'}        64              7
#                                                   128             7
#                                                   256             7
#                                                   512             7
#                                                   1024            7
#                                                   2048            7
#                                                   4096            7
# {'name': 'comp', 'type': 'function'}              64              3
#                                                   128             3
#                                                   256             3
#                                                   512             3
#                                                   1024            3
#                                                   2048            3
#                                                   4096            3
# {'name': 'comp_large', 'type': 'function'}        64              4
#                                                   128             4
#                                                   256             4
#                                                   512             4
#                                                   1024            4
#                                                   2048            4
#                                                   4096            4
# {'name': 'correctness_check', 'type': 'function'} 64              8
#                                                   128             8
#                                                   256             8
#                                                   512             8
#                                                   1024            8
#                                                   2048            8
#                                                   4096            8
# {'name': 'data_init', 'type': 'function'}         64              2
#                                                   128             2
#                                                   256             2
#                                                   512             2
#                                                   1024            2
#                                                   2048            2
#                                                   4096            2
#
#                                                                               \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#                                                   2048         regionprofile
#                                                   4096         regionprofile
# {'name': 'comm', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#                                                   2048         regionprofile
#                                                   4096         regionprofile
# {'name': 'comm_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#                                                   2048         regionprofile
#                                                   4096         regionprofile
# {'name': 'cudaMemcpy', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#                                                   2048         regionprofile
#                                                   4096         regionprofile
# {'name': 'comp', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#                                                   2048         regionprofile
#                                                   4096         regionprofile
# {'name': 'comp_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#                                                   2048         regionprofile
#                                                   4096         regionprofile
# {'name': 'correctness_check', 'type': 'function'} 64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#                                                   2048         regionprofile
#                                                   4096         regionprofile
# {'name': 'data_init', 'type': 'function'}         64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#                                                   2048         regionprofile
#                                                   4096         regionprofile
#
#                                                                              \
#                                                               Min time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.782116
#                                                   128              0.466984
#                                                   256              0.473547
#                                                   512              0.464268
#                                                   1024             0.450281
#                                                   2048             0.440550
#                                                   4096             0.435769
# {'name': 'comm', 'type': 'function'}              64               0.000185
#                                                   128              0.000214
#                                                   256              0.000178
#                                                   512              0.000178
#                                                   1024             0.000136
#                                                   2048             0.000162
#                                                   4096             0.000153
# {'name': 'comm_large', 'type': 'function'}        64               0.000173
#                                                   128              0.000194
#                                                   256              0.000164
#                                                   512              0.000165
#                                                   1024             0.000126
#                                                   2048             0.000150
#                                                   4096             0.000142
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000157
#                                                   128              0.000177
#                                                   256              0.000149
#                                                   512              0.000150
#                                                   1024             0.000114
#                                                   2048             0.000135
#                                                   4096             0.000129
# {'name': 'comp', 'type': 'function'}              64               0.005239
#                                                   128              0.005981
#                                                   256              0.006049
#                                                   512              0.005327
#                                                   1024             0.009601
#                                                   2048             0.000047
#                                                   4096             0.000046
# {'name': 'comp_large', 'type': 'function'}        64               0.005204
#                                                   128              0.005957
#                                                   256              0.006024
#                                                   512              0.005304
#                                                   1024             0.009583
#                                                   2048             0.000030
#                                                   4096             0.000028
# {'name': 'correctness_check', 'type': 'function'} 64               0.000471
#                                                   128              0.000496
#                                                   256              0.000428
#                                                   512              0.000405
#                                                   1024             0.000385
#                                                   2048             0.000378
#                                                   4096             0.000400
# {'name': 'data_init', 'type': 'function'}         64               0.003757
#                                                   128              0.001728
#                                                   256              0.001718
#                                                   512              0.001765
#                                                   1024             0.001572
#                                                   2048             0.001575
#                                                   4096             0.001620
#
#                                                                              \
#                                                               Max time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.782116
#                                                   128              0.466984
#                                                   256              0.473547
#                                                   512              0.464268
#                                                   1024             0.450281
#                                                   2048             0.440550
#                                                   4096             0.435769
# {'name': 'comm', 'type': 'function'}              64               0.000185
#                                                   128              0.000214
#                                                   256              0.000178
#                                                   512              0.000178
#                                                   1024             0.000136
#                                                   2048             0.000162
#                                                   4096             0.000153
# {'name': 'comm_large', 'type': 'function'}        64               0.000173
#                                                   128              0.000194
#                                                   256              0.000164
#                                                   512              0.000165
#                                                   1024             0.000126
#                                                   2048             0.000150
#                                                   4096             0.000142
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000157
#                                                   128              0.000177
#                                                   256              0.000149
#                                                   512              0.000150
#                                                   1024             0.000114
#                                                   2048             0.000135
#                                                   4096             0.000129
# {'name': 'comp', 'type': 'function'}              64               0.005239
#                                                   128              0.005981
#                                                   256              0.006049
#                                                   512              0.005327
#                                                   1024             0.009601
#                                                   2048             0.000047
#                                                   4096             0.000046
# {'name': 'comp_large', 'type': 'function'}        64               0.005204
#                                                   128              0.005957
#                                                   256              0.006024
#                                                   512              0.005304
#                                                   1024             0.009583
#                                                   2048             0.000030
#                                                   4096             0.000028
# {'name': 'correctness_check', 'type': 'function'} 64               0.000471
#                                                   128              0.000496
#                                                   256              0.000428
#                                                   512              0.000405
#                                                   1024             0.000385
#                                                   2048             0.000378
#                                                   4096             0.000400
# {'name': 'data_init', 'type': 'function'}         64               0.003757
#                                                   128              0.001728
#                                                   256              0.001718
#                                                   512              0.001765
#                                                   1024             0.001572
#                                                   2048             0.001575
#                                                   4096             0.001620
#
#                                                                              \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.782116
#                                                   128              0.466984
#                                                   256              0.473547
#                                                   512              0.464268
#                                                   1024             0.450281
#                                                   2048             0.440550
#                                                   4096             0.435769
# {'name': 'comm', 'type': 'function'}              64               0.000185
#                                                   128              0.000214
#                                                   256              0.000178
#                                                   512              0.000178
#                                                   1024             0.000136
#                                                   2048             0.000162
#                                                   4096             0.000153
# {'name': 'comm_large', 'type': 'function'}        64               0.000173
#                                                   128              0.000194
#                                                   256              0.000164
#                                                   512              0.000165
#                                                   1024             0.000126
#                                                   2048             0.000150
#                                                   4096             0.000142
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000157
#                                                   128              0.000177
#                                                   256              0.000149
#                                                   512              0.000150
#                                                   1024             0.000114
#                                                   2048             0.000135
#                                                   4096             0.000129
# {'name': 'comp', 'type': 'function'}              64               0.005239
#                                                   128              0.005981
#                                                   256              0.006049
#                                                   512              0.005327
#                                                   1024             0.009601
#                                                   2048             0.000047
#                                                   4096             0.000046
# {'name': 'comp_large', 'type': 'function'}        64               0.005204
#                                                   128              0.005957
#                                                   256              0.006024
#                                                   512              0.005304
#                                                   1024             0.009583
#                                                   2048             0.000030
#                                                   4096             0.000028
# {'name': 'correctness_check', 'type': 'function'} 64               0.000471
#                                                   128              0.000496
#                                                   256              0.000428
#                                                   512              0.000405
#                                                   1024             0.000385
#                                                   2048             0.000378
#                                                   4096             0.000400
# {'name': 'data_init', 'type': 'function'}         64               0.003757
#                                                   128              0.001728
#                                                   256              0.001718
#                                                   512              0.001765
#                                                   1024             0.001572
#                                                   2048             0.001575
#                                                   4096             0.001620
#
#                                                                           \
#                                                               Total time
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64            0.782116
#                                                   128           0.466984
#                                                   256           0.473547
#                                                   512           0.464268
#                                                   1024          0.450281
#                                                   2048          0.440550
#                                                   4096          0.435769
# {'name': 'comm', 'type': 'function'}              64            0.000185
#                                                   128           0.000214
#                                                   256           0.000178
#                                                   512           0.000178
#                                                   1024          0.000136
#                                                   2048          0.000162
#                                                   4096          0.000153
# {'name': 'comm_large', 'type': 'function'}        64            0.000173
#                                                   128           0.000194
#                                                   256           0.000164
#                                                   512           0.000165
#                                                   1024          0.000126
#                                                   2048          0.000150
#                                                   4096          0.000142
# {'name': 'cudaMemcpy', 'type': 'function'}        64            0.000157
#                                                   128           0.000177
#                                                   256           0.000149
#                                                   512           0.000150
#                                                   1024          0.000114
#                                                   2048          0.000135
#                                                   4096          0.000129
# {'name': 'comp', 'type': 'function'}              64            0.005239
#                                                   128           0.005981
#                                                   256           0.006049
#                                                   512           0.005327
#                                                   1024          0.009601
#                                                   2048          0.000047
#                                                   4096          0.000046
# {'name': 'comp_large', 'type': 'function'}        64            0.005204
#                                                   128           0.005957
#                                                   256           0.006024
#                                                   512           0.005304
#                                                   1024          0.009583
#                                                   2048          0.000030
#                                                   4096          0.000028
# {'name': 'correctness_check', 'type': 'function'} 64            0.000471
#                                                   128           0.000496
#                                                   256           0.000428
#                                                   512           0.000405
#                                                   1024          0.000385
#                                                   2048          0.000378
#                                                   4096          0.000400
# {'name': 'data_init', 'type': 'function'}         64            0.003757
#                                                   128           0.001728
#                                                   256           0.001718
#                                                   512           0.001765
#                                                   1024          0.001572
#                                                   2048          0.001575
#                                                   4096          0.001620
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.004963
#                                                   128                  0.005812
#                                                   256                  0.005940
#                                                   512                  0.005181
#                                                   1024                 0.009529
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'comm', 'type': 'function'}              64                   0.000024
#                                                   128                  0.000024
#                                                   256                  0.000025
#                                                   512                  0.000024
#                                                   1024                 0.000024
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'comm_large', 'type': 'function'}        64                   0.000024
#                                                   128                  0.000024
#                                                   256                  0.000025
#                                                   512                  0.000024
#                                                   1024                 0.000024
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000024
#                                                   128                  0.000024
#                                                   256                  0.000025
#                                                   512                  0.000024
#                                                   1024                 0.000024
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'comp', 'type': 'function'}              64                   0.004939
#                                                   128                  0.005788
#                                                   256                  0.005915
#                                                   512                  0.005157
#                                                   1024                 0.009505
#                                                   2048                      NaN
#                                                   4096                      NaN
# {'name': 'comp_large', 'type': 'function'}        64                   0.004939
#                                                   128                  0.005788
#                                                   256                  0.005915
#                                                   512                  0.005157
#                                                   1024                 0.009505
#                                                   2048                      NaN
#                                                   4096                      NaN
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#                                                   2048                      NaN
#                                                   4096                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#                                                   2048                      NaN
#                                                   4096                      NaN
#
#                                                                                  \
#                                                               Min GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.004963
#                                                   128                  0.005812
#                                                   256                  0.005940
#                                                   512                  0.005181
#                                                   1024                 0.009529
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'comm', 'type': 'function'}              64                   0.000024
#                                                   128                  0.000024
#                                                   256                  0.000025
#                                                   512                  0.000024
#                                                   1024                 0.000024
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'comm_large', 'type': 'function'}        64                   0.000024
#                                                   128                  0.000024
#                                                   256                  0.000025
#                                                   512                  0.000024
#                                                   1024                 0.000024
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000024
#                                                   128                  0.000024
#                                                   256                  0.000025
#                                                   512                  0.000024
#                                                   1024                 0.000024
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'comp', 'type': 'function'}              64                   0.004939
#                                                   128                  0.005788
#                                                   256                  0.005915
#                                                   512                  0.005157
#                                                   1024                 0.009505
#                                                   2048                      NaN
#                                                   4096                      NaN
# {'name': 'comp_large', 'type': 'function'}        64                   0.004939
#                                                   128                  0.005788
#                                                   256                  0.005915
#                                                   512                  0.005157
#                                                   1024                 0.009505
#                                                   2048                      NaN
#                                                   4096                      NaN
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#                                                   2048                      NaN
#                                                   4096                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#                                                   2048                      NaN
#                                                   4096                      NaN
#
#                                                                                  \
#                                                               Max GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.004963
#                                                   128                  0.005812
#                                                   256                  0.005940
#                                                   512                  0.005181
#                                                   1024                 0.009529
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'comm', 'type': 'function'}              64                   0.000024
#                                                   128                  0.000024
#                                                   256                  0.000025
#                                                   512                  0.000024
#                                                   1024                 0.000024
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'comm_large', 'type': 'function'}        64                   0.000024
#                                                   128                  0.000024
#                                                   256                  0.000025
#                                                   512                  0.000024
#                                                   1024                 0.000024
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000024
#                                                   128                  0.000024
#                                                   256                  0.000025
#                                                   512                  0.000024
#                                                   1024                 0.000024
#                                                   2048                 0.000025
#                                                   4096                 0.000025
# {'name': 'comp', 'type': 'function'}              64                   0.004939
#                                                   128                  0.005788
#                                                   256                  0.005915
#                                                   512                  0.005157
#                                                   1024                 0.009505
#                                                   2048                      NaN
#                                                   4096                      NaN
# {'name': 'comp_large', 'type': 'function'}        64                   0.004939
#                                                   128                  0.005788
#                                                   256                  0.005915
#                                                   512                  0.005157
#                                                   1024                 0.009505
#                                                   2048                      NaN
#                                                   4096                      NaN
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#                                                   2048                      NaN
#                                                   4096                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#                                                   2048                      NaN
#                                                   4096                      NaN
#
#                                                                               \
#                                                               Total GPU time
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                0.004963
#                                                   128               0.005812
#                                                   256               0.005940
#                                                   512               0.005181
#                                                   1024              0.009529
#                                                   2048              0.000025
#                                                   4096              0.000025
# {'name': 'comm', 'type': 'function'}              64                0.000024
#                                                   128               0.000024
#                                                   256               0.000025
#                                                   512               0.000024
#                                                   1024              0.000024
#                                                   2048              0.000025
#                                                   4096              0.000025
# {'name': 'comm_large', 'type': 'function'}        64                0.000024
#                                                   128               0.000024
#                                                   256               0.000025
#                                                   512               0.000024
#                                                   1024              0.000024
#                                                   2048              0.000025
#                                                   4096              0.000025
# {'name': 'cudaMemcpy', 'type': 'function'}        64                0.000024
#                                                   128               0.000024
#                                                   256               0.000025
#                                                   512               0.000024
#                                                   1024              0.000024
#                                                   2048              0.000025
#                                                   4096              0.000025
# {'name': 'comp', 'type': 'function'}              64                0.004939
#                                                   128               0.005788
#                                                   256               0.005915
#                                                   512               0.005157
#                                                   1024              0.009505
#                                                   2048                   NaN
#                                                   4096                   NaN
# {'name': 'comp_large', 'type': 'function'}        64                0.004939
#                                                   128               0.005788
#                                                   256               0.005915
#                                                   512               0.005157
#                                                   1024              0.009505
#                                                   2048                   NaN
#                                                   4096                   NaN
# {'name': 'correctness_check', 'type': 'function'} 64                     NaN
#                                                   128                    NaN
#                                                   256                    NaN
#                                                   512                    NaN
#                                                   1024                   NaN
#                                                   2048                   NaN
#                                                   4096                   NaN
# {'name': 'data_init', 'type': 'function'}         64                     NaN
#                                                   128                    NaN
#                                                   256                    NaN
#                                                   512                    NaN
#                                                   1024                   NaN
#                                                   2048                   NaN
#                                                   4096                   NaN
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                        main
#                                                   128                       main
#                                                   256                       main
#                                                   512                       main
#                                                   1024                      main
#                                                   2048                      main
#                                                   4096                      main
# {'name': 'comm', 'type': 'function'}              64                        comm
#                                                   128                       comm
#                                                   256                       comm
#                                                   512                       comm
#                                                   1024                      comm
#                                                   2048                      comm
#                                                   4096                      comm
# {'name': 'comm_large', 'type': 'function'}        64                  comm_large
#                                                   128                 comm_large
#                                                   256                 comm_large
#                                                   512                 comm_large
#                                                   1024                comm_large
#                                                   2048                comm_large
#                                                   4096                comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}        64                  cudaMemcpy
#                                                   128                 cudaMemcpy
#                                                   256                 cudaMemcpy
#                                                   512                 cudaMemcpy
#                                                   1024                cudaMemcpy
#                                                   2048                cudaMemcpy
#                                                   4096                cudaMemcpy
# {'name': 'comp', 'type': 'function'}              64                        comp
#                                                   128                       comp
#                                                   256                       comp
#                                                   512                       comp
#                                                   1024                      comp
#                                                   2048                      comp
#                                                   4096                      comp
# {'name': 'comp_large', 'type': 'function'}        64                  comp_large
#                                                   128                 comp_large
#                                                   256                 comp_large
#                                                   512                 comp_large
#                                                   1024                comp_large
#                                                   2048                comp_large
#                                                   4096                comp_large
# {'name': 'correctness_check', 'type': 'function'} 64           correctness_check
#                                                   128          correctness_check
#                                                   256          correctness_check
#                                                   512          correctness_check
#                                                   1024         correctness_check
#                                                   2048         correctness_check
#                                                   4096         correctness_check
# {'name': 'data_init', 'type': 'function'}         64                   data_init
#                                                   128                  data_init
#                                                   256                  data_init
#                                                   512                  data_init
#                                                   1024                 data_init
#                                                   2048                 data_init
#                                                   4096                 data_init

# %%
ctks["mpi_weak_random"].dataframe
# Out:
#                                       128                              \
#                             Min time/rank Max time/rank Avg time/rank
# name              InputSize
# main              65536         10.329253     11.306416     11.083260
#                   262144        11.975050     12.911569     12.606915
#                   1048576       21.038272     22.223940     21.887077
#                   4194304       61.817407     63.426418     62.352624
#                   16777216     213.893662    219.411709    216.001633
# comm              65536          1.596722      2.055720      1.824923
# comp_large        65536          1.336982           0.000019
#                   262144        10.364494           0.000846
#                   1048576      102.438253           0.055398
#                   4194304     3935.467045           6.028020
#                   16777216   23353.310796         170.569521
# correctness_check 65536          0.000571           0.000000
#                   262144         0.001120           0.000000
#                   1048576        0.003338           0.000000
#                   4194304        0.720155           0.000000
#                   16777216       3.037737           0.000000
# data_init         65536          0.003919           0.000000
#                   262144         0.113630           0.000093
#                   1048576        0.050655           0.000014
#                   4194304        0.544540           0.000468
#                   16777216       2.975438           0.003369

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
function_names = set(ctks["cuda_strong_reverse"].dataframe.index.get_level_values("name"))
if "strong" in "cuda_strong_reverse":
    if "cuda_strong_reverse".startswith("cuda"):
        threads = sorted(list(set(ctks["cuda_strong_reverse"].dataframe.index.get_level_values("num_threads"))))
    else:
        threads = sorted(list(set(ctks["cuda_strong_reverse"].dataframe.index.get_level_values("num_procs"))))
else:
    threads = sorted(list(set(ctks["cuda_strong_reverse"].dataframe.index.get_level_values("InputSize"))))
matrix_sizes = sorted(ctks["cuda_strong_reverse"].dataframe.columns.tolist())
print(function_names)
for name in function_names:
    plot_pandas(
        df=ctks["cuda_strong_reverse"].dataframe.loc[name],
        title=name,
        xlabel="Threads",
        ylabel="Time (seconds)",
        loglog=False
    )
# Out:
# {'cudaMemcpy', 'correctness_check', 'comp_large', 'comp', 'comm', 'data_init', 'comm_large', 'main'}

# %% [markdown]
# ### Option 2
# Use `matplotlib.pyplot` directly for more fine-grained control. Specifically for our case we can change the x axis scaling from base 10 to base 2.

# %% [markdown]
# # Examples

# %%
ctks["cuda_weak_random"].dataframe.loc["main"]
# Out:
#                    2048                                         \
#           Min time/rank Max time/rank Avg time/rank Total time
# InputSize
# 65536          0.440550      0.440550      0.440550   0.440550
# 262144         0.428625      0.428625      0.428625   0.428625
# 1048576        0.448709      0.448709      0.448709   0.448709
# 4194304        0.551724      0.551724      0.551724   0.551724
# 16777216       1.271019      1.271019      1.271019   1.271019
# 67108864       2.093767      2.093767      2.093767   2.093767
# 268435456      7.457988      7.457988      7.457988   7.457988
#
#
#           Avg GPU time/rank Min GPU time/rank Max GPU time/rank Total GPU time
# InputSize
# 65536              0.000025          0.000025          0.000025       0.000025
# 262144             0.000085          0.000085          0.000085       0.000085
# 1048576            0.000570          0.000570          0.000570       0.000570
# 4194304            0.002578          0.002578          0.002578       0.002578
# 16777216           0.012813          0.012813          0.012813       0.012813
# 67108864           0.054476          0.054476          0.054476       0.054476
# 268435456          0.236908          0.236908          0.236908       0.236908

# %%
ctks["mpi_strong_reverse"].dataframe.loc["comp_large"]
# Out:
#                 1048576                                          \
#           Min time/rank Max time/rank Avg time/rank  Total time
# num_procs
# 2              0.204447      0.208275      0.206361    0.412722
# 4              0.380803      0.797674      0.592777    2.371107
# 8              0.672085      1.483650      1.227293    9.818347
# 16             1.236777      2.678884      2.384100   38.145602
# 32             1.750150      4.743199      3.832324  122.634379
# 64             0.645847      7.644905      2.216923  141.883058
# 128            0.076142      1.456085      0.800299  102.438253
# 256            0.098092      0.810502      0.473256  121.153573
# 512            0.068122      0.601787      0.321103  164.404960
# 1024           0.086983      0.401302      0.228485  233.968845
#
#
#           Variance time/rank
# num_procs
# 2                   0.000004
# 4                   0.040512
# 8                   0.100937
# 16                  0.192428
# 32                  0.441150
# 64                  1.277503
# 128                 0.055398
# 256                 0.010842
# 512                 0.005686
# 1024                0.001698

# %%
ctks["mpi_weak_reverse"].dataframe.loc["comp_large"]
# Out:
#                     128                                            \
#           Min time/rank Max time/rank Avg time/rank    Total time
# InputSize
# 65536          0.003785      0.030318      0.010445      1.336982
# 262144         0.016909      0.190206      0.080973     10.364494
# 1048576        0.076142      1.456085      0.800299    102.438253
# 4194304       12.447394     33.430897     30.745836   3935.467045
# 16777216      80.021047    188.631225    182.447741  23353.310796
#
#
#           Variance time/rank
# InputSize
# 65536               0.000019
# 262144              0.000846
# 1048576             0.055398
# 4194304             6.028020
# 16777216          170.569521

# %%
function_names = ("main", "comp", "comm", "comm_large", "comp_large")

# %% [markdown]
# # MPI GRAPHS

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_random"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 

masterDF
# Out:
#            main      comp       comm  comm_large  comp_large
# 2      2.476106  0.224524   0.042615    0.005634    0.224488
# 4      1.969934  0.631056   0.316358    0.192640    0.630984
# 8      3.418054  1.300775   0.576701    0.440124    1.296868
# 16     8.930260  2.434686   1.348274    1.186449    2.430618
# 32    15.934537  3.818562   4.682603    3.981167    3.814001
# 64    20.391390  2.905734   8.357751    8.022363    2.898566
# 128   21.887077  0.806899  10.757232   10.364901    0.802460
# 256   24.782684  0.540258  11.440306   10.832604    0.531229
# 512   29.461634  0.331744  11.960640   11.290033    0.321910
# 1024  42.057792  0.249141  14.704419   12.750991    0.234351

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_random"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort MPI Random Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort MPI Random Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_sorted"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort MPI Sorted Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort MPI Sorted Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_perturbed"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort MPI 1%Perturbed Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort MPI 1%Perturbed Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_strong_reverse"].dataframe.loc[name][(1048576, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort MPI Reverse Input, Sorting 1048576 Values, Avg time/rank",
    xlabel="Num_Procs",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort MPI Reverse Input, Sorting 1048576 Values, Avg time/rank'}, xlabel='Num_Procs', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_random"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort MPI Random Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort MPI Random Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_sorted"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort MPI Sorted Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort MPI Sorted Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_reverse"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort MPI Reverse Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort MPI Reverse Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["mpi_weak_perturbed"].dataframe.loc[name][(128, "Avg time/rank")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="SampleSort MPI 1%Perturbed Input, with 128 Processes, Avg time/rank",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'SampleSort MPI 1%Perturbed Input, with 128 Processes, Avg time/rank'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %% [markdown]
# # CUDA GRAPHS

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_random"].dataframe.loc[name][(65536, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Random Input, Sorting 65536 Values, Total GPU time",
    xlabel="Num_threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Random Input, Sorting 65536 Values, Total GPU time'}, xlabel='Num_threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_sorted"].dataframe.loc[name][(65536, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Sorted Input, Sorting 65536 Values, Total GPU time",
    xlabel="Num_threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Sorted Input, Sorting 65536 Values, Total GPU time'}, xlabel='Num_threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_perturbed"].dataframe.loc[name][(65536, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA 1%Perturbed Input, Sorting 65536 Values, Total GPU time",
    xlabel="Num_threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA 1%Perturbed Input, Sorting 65536 Values, Total GPU time'}, xlabel='Num_threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_strong_reverse"].dataframe.loc[name][(65536, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Reverse Input, Sorting 65536 Values, Total GPU time",
    xlabel="Num_threads",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Reverse Input, Sorting 65536 Values, Total GPU time'}, xlabel='Num_threads', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_random"].dataframe.loc[name][(2048, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Random Input, with 2048 Threads, Total GPU time",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Random Input, with 2048 Threads, Total GPU time'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_sorted"].dataframe.loc[name][(2048, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Sorted Input, with 2048 Threads, Total GPU time",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Sorted Input, with 2048 Threads, Total GPU time'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_perturbed"].dataframe.loc[name][(2048, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA 1%Perturbed Input, with 2048 Threads, Total GPU time",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Random Input, with 2048 Threads, Total GPU time'}, xlabel='Input Size', ylabel='Time (seconds)'>

# %%
masterDF = pd.DataFrame()
for name in function_names:
    tempDF = ctks["cuda_weak_reverse"].dataframe.loc[name][(2048, "Total GPU time")]
    tempDF = tempDF.rename(name)    
    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
plot_pandas(
    df=masterDF,
    title="BubbleSort CUDA Reverse Input, with 2048 Threads, Total GPU time",
    xlabel="Input Size",
    ylabel="Time (seconds)",
    loglog=True
)
# Out:
# <Axes: title={'center': 'BubbleSort CUDA Random Input, with 2048 Threads, Total GPU time'}, xlabel='Input Size', ylabel='Time (seconds)'>
