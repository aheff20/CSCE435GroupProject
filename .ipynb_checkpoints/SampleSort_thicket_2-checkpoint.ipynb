# %% [markdown]
# # FINAL PROJECT THICKET

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
plt.rcParams.update({'figure.max_open_warning': 0})
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

print("done")
# Out:
# done

# %% [markdown]
# Read in all the files

# %% [markdown]
# # MPI Thicket Variables

# %%
mpi_random_tk = th.Thicket.from_caliperreader(glob("sample_ProjectOuts/mpi/random/*.cali"))
mpi_perturbed_tk = th.Thicket.from_caliperreader(glob("sample_ProjectOuts/mpi/perturbed/*.cali"))
mpi_sorted_tk = th.Thicket.from_caliperreader(glob("sample_ProjectOuts/mpi/sorted/*.cali"))
mpi_reverse_tk = th.Thicket.from_caliperreader(glob("sample_ProjectOuts/mpi/reverse/*.cali"))

# %% [markdown]
# # CUDA Thicket Variables

# %%
cuda_random_tk = th.Thicket.from_caliperreader(glob("sample_ProjectOuts/cuda/random/*.cali"))
cuda_perturbed_tk = th.Thicket.from_caliperreader(glob("sample_ProjectOuts/cuda/perturbed/*.cali"))
cuda_sorted_tk = th.Thicket.from_caliperreader(glob("sample_ProjectOuts/cuda/sorted/*.cali"))
cuda_reverse_tk = th.Thicket.from_caliperreader(glob("sample_ProjectOuts/cuda/reverse/*.cali"))

# %%
tks = {}

tks["mpi_sorted"] = mpi_sorted_tk
tks["mpi_reverse"] = mpi_reverse_tk
tks["mpi_random"] = mpi_random_tk
tks["mpi_perturbed"] = mpi_perturbed_tk

tks["cuda_sorted"] = cuda_sorted_tk
tks["cuda_reverse"] = cuda_reverse_tk
tks["cuda_random"] = cuda_random_tk
tks["cuda_perturbed"] = cuda_perturbed_tk

# %%
for i in tks.values():
    i.statsframe.dataframe["time"] = 1

print(tks["cuda_random"].tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  ├─ 1.000 comm_large
# │  │  └─ 1.000 cudaMemcpy
# │  └─ 1.000 comm_small
# │     └─ 1.000 cudaMemcpy
# ├─ 1.000 comp
# │  ├─ 1.000 comp_large
# │  └─ 1.000 comp_small
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
# Performance data
for inputType in tks.keys():
    if "mpi" in inputType:
        tks[inputType].metadata["values_per_proc"] = tks[inputType].metadata["InputSize"] // tks[inputType].metadata["num_procs"]
        
tks["mpi_random"].metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 22361798             2.11.0-dev             128
# 116293393            2.11.0-dev             512
# 134818634            2.11.0-dev               8
# 146744629            2.11.0-dev             128
# 253356140            2.11.0-dev             512
# 580301485            2.11.0-dev              64
# 711363963            2.11.0-dev            1024
# 796617537            2.11.0-dev               8
# 810973511            2.11.0-dev              32
# 941793176            2.11.0-dev               8
# 951418867            2.11.0-dev             256
# 1033541349           2.11.0-dev             128
# 1075687522           2.11.0-dev             128
# 1362906779           2.11.0-dev               4
# 1403911938           2.11.0-dev            1024
# 1435201546           2.11.0-dev              16
# 1496506446           2.11.0-dev               4
# 1520814698           2.11.0-dev             512
# 1648651909           2.11.0-dev              32
# 1697589512           2.11.0-dev             256
# 1881801213           2.11.0-dev              16
# 1885136986           2.11.0-dev             512
# 2019179125           2.11.0-dev              16
# 2152020772           2.11.0-dev              16
# 2160855856           2.11.0-dev              32
# 2200215911           2.11.0-dev              16
# 2203361165           2.11.0-dev               2
# 2232519014           2.11.0-dev               4
# 2239690746           2.11.0-dev               8
# 2358279917           2.11.0-dev             128
# 2441435745           2.11.0-dev              64
# 2462135126           2.11.0-dev            1024
# 2503756247           2.11.0-dev               4
# 2523424627           2.11.0-dev            1024
# 2536232340           2.11.0-dev              64
# 2634403804           2.11.0-dev             128
# 2761994045           2.11.0-dev              16
# 2763097266           2.11.0-dev             256
# 2808852794           2.11.0-dev               8
# 2822370982           2.11.0-dev              64
# 2991430386           2.11.0-dev               8
# 3003539304           2.11.0-dev               8
# 3034853663           2.11.0-dev               2
# 3086508677           2.11.0-dev               2
# 3252180464           2.11.0-dev               2
# 3306545231           2.11.0-dev            1024
# 3347448399           2.11.0-dev             128
# 3374329485           2.11.0-dev              64
# 3447244011           2.11.0-dev              32
# 3472221710           2.11.0-dev             256
# 3507915738           2.11.0-dev               2
# 3516945613           2.11.0-dev             256
# 3559501564           2.11.0-dev              16
# 3646086970           2.11.0-dev              64
# 3661965729           2.11.0-dev              32
# 3680149479           2.11.0-dev              32
# 3788723603           2.11.0-dev             256
# 3890394956           2.11.0-dev               4
# 3893476762           2.11.0-dev               4
# 3975596795           2.11.0-dev              32
# 4036566109           2.11.0-dev               4
# 4059388576           2.11.0-dev             512
# 4114365992           2.11.0-dev              64
# 4133963583           2.11.0-dev               2
# 4259933312           2.11.0-dev               2
# 4263644136           2.11.0-dev             512
# 4284286604           2.11.0-dev             256
#
#                                                  spot.metrics  \
# profile
# 22361798    min#inclusive#sum#time.duration,max#inclusive#...
# 116293393   min#inclusive#sum#time.duration,max#inclusive#...
# 134818634   min#inclusive#sum#time.duration,max#inclusive#...
# 146744629   min#inclusive#sum#time.duration,max#inclusive#...
# 253356140   min#inclusive#sum#time.duration,max#inclusive#...
# 580301485   min#inclusive#sum#time.duration,max#inclusive#...
# 711363963   min#inclusive#sum#time.duration,max#inclusive#...
# 796617537   min#inclusive#sum#time.duration,max#inclusive#...
# 810973511   min#inclusive#sum#time.duration,max#inclusive#...
# 941793176   min#inclusive#sum#time.duration,max#inclusive#...
# 951418867   min#inclusive#sum#time.duration,max#inclusive#...
# 1033541349  min#inclusive#sum#time.duration,max#inclusive#...
# 1075687522  min#inclusive#sum#time.duration,max#inclusive#...
# 1362906779  min#inclusive#sum#time.duration,max#inclusive#...
# 1403911938  min#inclusive#sum#time.duration,max#inclusive#...
# 1435201546  min#inclusive#sum#time.duration,max#inclusive#...
# 1496506446  min#inclusive#sum#time.duration,max#inclusive#...
# 1520814698  min#inclusive#sum#time.duration,max#inclusive#...
# 1648651909  min#inclusive#sum#time.duration,max#inclusive#...
# 1697589512  min#inclusive#sum#time.duration,max#inclusive#...
# 1881801213  min#inclusive#sum#time.duration,max#inclusive#...
# 1885136986  min#inclusive#sum#time.duration,max#inclusive#...
# 2019179125  min#inclusive#sum#time.duration,max#inclusive#...
# 2152020772  min#inclusive#sum#time.duration,max#inclusive#...
# 2160855856  min#inclusive#sum#time.duration,max#inclusive#...
# 2200215911  min#inclusive#sum#time.duration,max#inclusive#...
# 2203361165  min#inclusive#sum#time.duration,max#inclusive#...
# 2232519014  min#inclusive#sum#time.duration,max#inclusive#...
# 2239690746  min#inclusive#sum#time.duration,max#inclusive#...
# 2358279917  min#inclusive#sum#time.duration,max#inclusive#...
# 2441435745  min#inclusive#sum#time.duration,max#inclusive#...
# 2462135126  min#inclusive#sum#time.duration,max#inclusive#...
# 2503756247  min#inclusive#sum#time.duration,max#inclusive#...
# 2523424627  min#inclusive#sum#time.duration,max#inclusive#...
# 2536232340  min#inclusive#sum#time.duration,max#inclusive#...
# 2634403804  min#inclusive#sum#time.duration,max#inclusive#...
# 2761994045  min#inclusive#sum#time.duration,max#inclusive#...
# 2763097266  min#inclusive#sum#time.duration,max#inclusive#...
# 2808852794  min#inclusive#sum#time.duration,max#inclusive#...
# 2822370982  min#inclusive#sum#time.duration,max#inclusive#...
# 2991430386  min#inclusive#sum#time.duration,max#inclusive#...
# 3003539304  min#inclusive#sum#time.duration,max#inclusive#...
# 3034853663  min#inclusive#sum#time.duration,max#inclusive#...
# 3086508677  min#inclusive#sum#time.duration,max#inclusive#...
# 3252180464  min#inclusive#sum#time.duration,max#inclusive#...
# 3306545231  min#inclusive#sum#time.duration,max#inclusive#...
# 3347448399  min#inclusive#sum#time.duration,max#inclusive#...
# 3374329485  min#inclusive#sum#time.duration,max#inclusive#...
# 3447244011  min#inclusive#sum#time.duration,max#inclusive#...
# 3472221710  min#inclusive#sum#time.duration,max#inclusive#...
# 3507915738  min#inclusive#sum#time.duration,max#inclusive#...
# 3516945613  min#inclusive#sum#time.duration,max#inclusive#...
# 3559501564  min#inclusive#sum#time.duration,max#inclusive#...
# 3646086970  min#inclusive#sum#time.duration,max#inclusive#...
# 3661965729  min#inclusive#sum#time.duration,max#inclusive#...
# 3680149479  min#inclusive#sum#time.duration,max#inclusive#...
# 3788723603  min#inclusive#sum#time.duration,max#inclusive#...
# 3890394956  min#inclusive#sum#time.duration,max#inclusive#...
# 3893476762  min#inclusive#sum#time.duration,max#inclusive#...
# 3975596795  min#inclusive#sum#time.duration,max#inclusive#...
# 4036566109  min#inclusive#sum#time.duration,max#inclusive#...
# 4059388576  min#inclusive#sum#time.duration,max#inclusive#...
# 4114365992  min#inclusive#sum#time.duration,max#inclusive#...
# 4133963583  min#inclusive#sum#time.duration,max#inclusive#...
# 4259933312  min#inclusive#sum#time.duration,max#inclusive#...
# 4263644136  min#inclusive#sum#time.duration,max#inclusive#...
# 4284286604  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 22361798                                              2
# 116293393                                             2
# 134818634                                             2
# 146744629                                             2
# 253356140                                             2
# 580301485                                             2
# 711363963                                             2
# 796617537                                             2
# 810973511                                             2
# 941793176                                             2
# 951418867                                             2
# 1033541349                                            2
# 1075687522                                            2
# 1362906779                                            2
# 1403911938                                            2
# 1435201546                                            2
# 1496506446                                            2
# 1520814698                                            2
# 1648651909                                            2
# 1697589512                                            2
# 1881801213                                            2
# 1885136986                                            2
# 2019179125                                            2
# 2152020772                                            2
# 2160855856                                            2
# 2200215911                                            2
# 2203361165                                            2
# 2232519014                                            2
# 2239690746                                            2
# 2358279917                                            2
# 2441435745                                            2
# 2462135126                                            2
# 2503756247                                            2
# 2523424627                                            2
# 2536232340                                            2
# 2634403804                                            2
# 2761994045                                            2
# 2763097266                                            2
# 2808852794                                            2
# 2822370982                                            2
# 2991430386                                            2
# 3003539304                                            2
# 3034853663                                            2
# 3086508677                                            2
# 3252180464                                            2
# 3306545231                                            2
# 3347448399                                            2
# 3374329485                                            2
# 3447244011                                            2
# 3472221710                                            2
# 3507915738                                            2
# 3516945613                                            2
# 3559501564                                            2
# 3646086970                                            2
# 3661965729                                            2
# 3680149479                                            2
# 3788723603                                            2
# 3890394956                                            2
# 3893476762                                            2
# 3975596795                                            2
# 4036566109                                            2
# 4059388576                                            2
# 4114365992                                            2
# 4133963583                                            2
# 4259933312                                            2
# 4263644136                                            2
# 4284286604                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 22361798    time.variance,node.order  regionprofile         spot
# 116293393   time.variance,node.order  regionprofile         spot
# 134818634   time.variance,node.order  regionprofile         spot
# 146744629   time.variance,node.order  regionprofile         spot
# 253356140   time.variance,node.order  regionprofile         spot
# 580301485   time.variance,node.order  regionprofile         spot
# 711363963   time.variance,node.order  regionprofile         spot
# 796617537   time.variance,node.order  regionprofile         spot
# 810973511   time.variance,node.order  regionprofile         spot
# 941793176   time.variance,node.order  regionprofile         spot
# 951418867   time.variance,node.order  regionprofile         spot
# 1033541349  time.variance,node.order  regionprofile         spot
# 1075687522  time.variance,node.order  regionprofile         spot
# 1362906779  time.variance,node.order  regionprofile         spot
# 1403911938  time.variance,node.order  regionprofile         spot
# 1435201546  time.variance,node.order  regionprofile         spot
# 1496506446  time.variance,node.order  regionprofile         spot
# 1520814698  time.variance,node.order  regionprofile         spot
# 1648651909  time.variance,node.order  regionprofile         spot
# 1697589512  time.variance,node.order  regionprofile         spot
# 1881801213  time.variance,node.order  regionprofile         spot
# 1885136986  time.variance,node.order  regionprofile         spot
# 2019179125  time.variance,node.order  regionprofile         spot
# 2152020772  time.variance,node.order  regionprofile         spot
# 2160855856  time.variance,node.order  regionprofile         spot
# 2200215911  time.variance,node.order  regionprofile         spot
# 2203361165  time.variance,node.order  regionprofile         spot
# 2232519014  time.variance,node.order  regionprofile         spot
# 2239690746  time.variance,node.order  regionprofile         spot
# 2358279917  time.variance,node.order  regionprofile         spot
# 2441435745  time.variance,node.order  regionprofile         spot
# 2462135126  time.variance,node.order  regionprofile         spot
# 2503756247  time.variance,node.order  regionprofile         spot
# 2523424627  time.variance,node.order  regionprofile         spot
# 2536232340  time.variance,node.order  regionprofile         spot
# 2634403804  time.variance,node.order  regionprofile         spot
# 2761994045  time.variance,node.order  regionprofile         spot
# 2763097266  time.variance,node.order  regionprofile         spot
# 2808852794  time.variance,node.order  regionprofile         spot
# 2822370982  time.variance,node.order  regionprofile         spot
# 2991430386  time.variance,node.order  regionprofile         spot
# 3003539304  time.variance,node.order  regionprofile         spot
# 3034853663  time.variance,node.order  regionprofile         spot
# 3086508677  time.variance,node.order  regionprofile         spot
# 3252180464  time.variance,node.order  regionprofile         spot
# 3306545231  time.variance,node.order  regionprofile         spot
# 3347448399  time.variance,node.order  regionprofile         spot
# 3374329485  time.variance,node.order  regionprofile         spot
# 3447244011  time.variance,node.order  regionprofile         spot
# 3472221710  time.variance,node.order  regionprofile         spot
# 3507915738  time.variance,node.order  regionprofile         spot
# 3516945613  time.variance,node.order  regionprofile         spot
# 3559501564  time.variance,node.order  regionprofile         spot
# 3646086970  time.variance,node.order  regionprofile         spot
# 3661965729  time.variance,node.order  regionprofile         spot
# 3680149479  time.variance,node.order  regionprofile         spot
# 3788723603  time.variance,node.order  regionprofile         spot
# 3890394956  time.variance,node.order  regionprofile         spot
# 3893476762  time.variance,node.order  regionprofile         spot
# 3975596795  time.variance,node.order  regionprofile         spot
# 4036566109  time.variance,node.order  regionprofile         spot
# 4059388576  time.variance,node.order  regionprofile         spot
# 4114365992  time.variance,node.order  regionprofile         spot
# 4133963583  time.variance,node.order  regionprofile         spot
# 4259933312  time.variance,node.order  regionprofile         spot
# 4263644136  time.variance,node.order  regionprofile         spot
# 4284286604  time.variance,node.order  regionprofile         spot
#
#            spot:node.order                                        spot:output  \
# profile
# 22361798              true   outs/random/p128/sample_mpi_p128-a1048576_0.cali
# 116293393             true   outs/random/p512/sample_mpi_p512-a1048576_0.cali
# 134818634             true       outs/random/p8/sample_mpi_p8-a1048576_0.cali
# 146744629             true  outs/random/p128/sample_mpi_p128-a67108864_0.cali
# 253356140             true  outs/random/p512/sample_mpi_p512-a268435456_0....
# 580301485             true     outs/random/p64/sample_mpi_p64-a4194304_0.cali
# 711363963             true  outs/random/p1024/sample_mpi_p1024-a268435456_...
# 796617537             true      outs/random/p8/sample_mpi_p8-a67108864_0.cali
# 810973511             true    outs/random/p32/sample_mpi_p32-a16777216_0.cali
# 941793176             true        outs/random/p8/sample_mpi_p8-a262144_0.cali
# 951418867             true   outs/random/p256/sample_mpi_p256-a1048576_0.cali
# 1033541349            true   outs/random/p128/sample_mpi_p128-a4194304_0.cali
# 1075687522            true     outs/random/p128/sample_mpi_p128-a65536_0.cali
# 1362906779            true      outs/random/p4/sample_mpi_p4-a16777216_0.cali
# 1403911938            true  outs/random/p1024/sample_mpi_p1024-a4194304_0....
# 1435201546            true     outs/random/p16/sample_mpi_p16-a1048576_0.cali
# 1496506446            true     outs/random/p4/sample_mpi_p4-a268435456_0.cali
# 1520814698            true   outs/random/p512/sample_mpi_p512-a4194304_0.cali
# 1648651909            true   outs/random/p32/sample_mpi_p32-a268435456_0.cali
# 1697589512            true   outs/random/p256/sample_mpi_p256-a4194304_0.cali
# 1881801213            true    outs/random/p16/sample_mpi_p16-a16777216_0.cali
# 1885136986            true  outs/random/p512/sample_mpi_p512-a67108864_0.cali
# 2019179125            true       outs/random/p16/sample_mpi_p16-a65536_0.cali
# 2152020772            true      outs/random/p16/sample_mpi_p16-a262144_0.cali
# 2160855856            true    outs/random/p32/sample_mpi_p32-a67108864_0.cali
# 2200215911            true     outs/random/p16/sample_mpi_p16-a4194304_0.cali
# 2203361165            true     outs/random/p2/sample_mpi_p2-a268435456_0.cali
# 2232519014            true       outs/random/p4/sample_mpi_p4-a4194304_0.cali
# 2239690746            true     outs/random/p8/sample_mpi_p8-a268435456_0.cali
# 2358279917            true    outs/random/p128/sample_mpi_p128-a262144_0.cali
# 2441435745            true      outs/random/p64/sample_mpi_p64-a262144_0.cali
# 2462135126            true  outs/random/p1024/sample_mpi_p1024-a16777216_0...
# 2503756247            true        outs/random/p4/sample_mpi_p4-a262144_0.cali
# 2523424627            true  outs/random/p1024/sample_mpi_p1024-a67108864_0...
# 2536232340            true    outs/random/p64/sample_mpi_p64-a16777216_0.cali
# 2634403804            true  outs/random/p128/sample_mpi_p128-a268435456_0....
# 2761994045            true   outs/random/p16/sample_mpi_p16-a268435456_0.cali
# 2763097266            true  outs/random/p256/sample_mpi_p256-a16777216_0.cali
# 2808852794            true         outs/random/p8/sample_mpi_p8-a65536_0.cali
# 2822370982            true   outs/random/p64/sample_mpi_p64-a268435456_0.cali
# 2991430386            true      outs/random/p8/sample_mpi_p8-a16777216_0.cali
# 3003539304            true       outs/random/p8/sample_mpi_p8-a4194304_0.cali
# 3034853663            true       outs/random/p2/sample_mpi_p2-a1048576_0.cali
# 3086508677            true      outs/random/p2/sample_mpi_p2-a16777216_0.cali
# 3252180464            true      outs/random/p2/sample_mpi_p2-a67108864_0.cali
# 3306545231            true  outs/random/p1024/sample_mpi_p1024-a1048576_0....
# 3347448399            true  outs/random/p128/sample_mpi_p128-a16777216_0.cali
# 3374329485            true       outs/random/p64/sample_mpi_p64-a65536_0.cali
# 3447244011            true      outs/random/p32/sample_mpi_p32-a262144_0.cali
# 3472221710            true  outs/random/p256/sample_mpi_p256-a268435456_0....
# 3507915738            true       outs/random/p2/sample_mpi_p2-a4194304_0.cali
# 3516945613            true  outs/random/p256/sample_mpi_p256-a67108864_0.cali
# 3559501564            true    outs/random/p16/sample_mpi_p16-a67108864_0.cali
# 3646086970            true     outs/random/p64/sample_mpi_p64-a1048576_0.cali
# 3661965729            true       outs/random/p32/sample_mpi_p32-a65536_0.cali
# 3680149479            true     outs/random/p32/sample_mpi_p32-a4194304_0.cali
# 3788723603            true    outs/random/p256/sample_mpi_p256-a262144_0.cali
# 3890394956            true         outs/random/p4/sample_mpi_p4-a65536_0.cali
# 3893476762            true       outs/random/p4/sample_mpi_p4-a1048576_0.cali
# 3975596795            true     outs/random/p32/sample_mpi_p32-a1048576_0.cali
# 4036566109            true      outs/random/p4/sample_mpi_p4-a67108864_0.cali
# 4059388576            true  outs/random/p512/sample_mpi_p512-a16777216_0.cali
# 4114365992            true    outs/random/p64/sample_mpi_p64-a67108864_0.cali
# 4133963583            true         outs/random/p2/sample_mpi_p2-a65536_0.cali
# 4259933312            true        outs/random/p2/sample_mpi_p2-a262144_0.cali
# 4263644136            true    outs/random/p512/sample_mpi_p512-a262144_0.cali
# 4284286604            true     outs/random/p256/sample_mpi_p256-a65536_0.cali
#
#            spot:time.variance  launchdate  \
# profile
# 22361798                 true  1701150161
# 116293393                true  1701150752
# 134818634                true  1701149038
# 146744629                true  1701150182
# 253356140                true  1701150767
# 580301485                true  1701149901
# 711363963                true  1701150891
# 796617537                true  1701149038
# 810973511                true  1701149691
# 941793176                true  1701149038
# 951418867                true  1701150346
# 1033541349               true  1701150182
# 1075687522               true  1701150161
# 1362906779               true  1701148958
# 1403911938               true  1701150873
# 1435201546               true  1701149309
# 1496506446               true  1701148958
# 1520814698               true  1701150752
# 1648651909               true  1701149691
# 1697589512               true  1701150346
# 1881801213               true  1701149309
# 1885136986               true  1701150767
# 2019179125               true  1701149295
# 2152020772               true  1701149295
# 2160855856               true  1701149691
# 2200215911               true  1701149309
# 2203361165               true  1701148832
# 2232519014               true  1701148957
# 2239690746               true  1701149038
# 2358279917               true  1701150161
# 2441435745               true  1701149901
# 134818634           1           Handwritten           131072
# 146744629           1           Handwritten           524288
# 253356140           1           Handwritten           524288
# 580301485           1           Handwritten            65536
# 711363963           1           Handwritten           262144
# 796617537           1           Handwritten          8388608
# 810973511           1           Handwritten           524288
# 941793176           1           Handwritten            32768
# 951418867           1           Handwritten             4096
# 1033541349          1           Handwritten            32768
# 1075687522          1           Handwritten              512
# 1362906779          1           Handwritten          4194304
# 1403911938          1           Handwritten             4096
# 1435201546          1           Handwritten            65536
# 1496506446          1           Handwritten         67108864
# 1520814698          1           Handwritten             8192
# 1648651909          1           Handwritten          8388608
# 1697589512          1           Handwritten            16384
# 1881801213          1           Handwritten          1048576
# 1885136986          1           Handwritten           131072
# 2019179125          1           Handwritten             4096
# 2152020772          1           Handwritten            16384
# 2160855856          1           Handwritten          2097152
# 2200215911          1           Handwritten           262144
# 2203361165          1           Handwritten        134217728
# 2232519014          1           Handwritten          1048576
# 2239690746          1           Handwritten         33554432
# 2358279917          1           Handwritten             2048
# 2441435745          1           Handwritten             4096
# 2462135126          1           Handwritten            16384
# 2503756247          1           Handwritten            65536
# 2523424627          1           Handwritten            65536
# 2536232340          1           Handwritten           262144
# 2634403804          1           Handwritten          2097152
# 2761994045          1           Handwritten         16777216
# 2763097266          1           Handwritten            65536
# 2808852794          1           Handwritten             8192
# 2822370982          1           Handwritten          4194304
# 2991430386          1           Handwritten          2097152
# 3003539304          1           Handwritten           524288
# 3034853663          1           Handwritten           524288
# 3086508677          1           Handwritten          8388608
# 3252180464          1           Handwritten         33554432
# 3306545231          1           Handwritten             1024
# 3347448399          1           Handwritten           131072
# 3374329485          1           Handwritten             1024
# 3447244011          1           Handwritten             8192
# 3472221710          1           Handwritten          1048576
# 3507915738          1           Handwritten          2097152
# 3516945613          1           Handwritten           262144
# 3559501564          1           Handwritten          4194304
# 3646086970          1           Handwritten            16384
# 3661965729          1           Handwritten             2048
# 3680149479          1           Handwritten           131072
# 3788723603          1           Handwritten             1024
# 3890394956          1           Handwritten            16384
# 3893476762          1           Handwritten           262144
# 3975596795          1           Handwritten            32768
# 4036566109          1           Handwritten         16777216
# 4059388576          1           Handwritten            32768
# 4114365992          1           Handwritten          1048576
# 4133963583          1           Handwritten            32768
# 4259933312          1           Handwritten           131072
# 4263644136          1           Handwritten              512
# 4284286604          1           Handwritten              256

# %%
tks.keys()
# Out:
# dict_keys(['mpi_sorted', 'mpi_reverse', 'mpi_random', 'mpi_perturbed', 'cuda_sorted', 'cuda_reverse', 'cuda_random', 'cuda_perturbed'])

# %%
gbs = {}

for i in tks.keys():
    if "mpi" in i:
        gbs[i + "_strong"] = tks[i].groupby("InputSize")
        gbs[i + "_weak"] = tks[i].groupby("values_per_proc")
    else:
        gbs[i + "_strong"] = tks[i].groupby("InputSize")
        gbs[i + "_weak"] = tks[i].groupby("num_blocks")
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b8b72c5e0d0>, 262144: <thicket.thicket.Thicket object at 0x2b8b7304d640>, 1048576: <thicket.thicket.Thicket object at 0x2b8b727d7790>, 4194304: <thicket.thicket.Thicket object at 0x2b8b72bbd280>, 16777216: <thicket.thicket.Thicket object at 0x2b8b7307d640>, 67108864: <thicket.thicket.Thicket object at 0x2b8b
thickets created...
# {32768: <thicket.thicket.Thicket object at 0x2b8b738db310>, 65536: <thicket.thicket.Thicket object at 0x2b8b738db850>, 131072: <thicket.thicket.Thicket object at 0x2b8b738f2670>, 262144: <thicket.thicket.Thicket object at 0x2b8b738ff070>, 524288: <thicket.thicket.Thicket object at 0x2b8b739069d0>, 1048576: <thicket.thicket.Thicket object at 0x2b8b73913400>, 2097152: <thicket.thicket.Thicket object at 0x2b8b73919d00>}
# 11  thickets created...
# {32: <thicket.thicket.Thicket object at 0x2b8b73927970>, 64: <thicket.thicket.Thicket object at 0x2b8b739322b0>, 128: <thicket.thicket.Thicket object at 0x2b8b7393ad30>, 256: <thicket.thicket.Thicket object at 0x2b8b73944640>, 512: <thicket.thicket.Thicket object at 0x2b8b739544c0>, 1024: <thicket.thicket.Thicket object at 0x2b8b73959a00>, 2048: <thicket.thicket.Thicket object at 0x2b8b73968220>, 4096: <thicket.thicket.Thicket object at 0x2b8b73968190>, 8192: <thicket.thicket.Thicket object at 0x2b8b7397c4f0>, 16384: <thicket.thicket.Thicket object at 0x2b8b73986520>, 32768: <thicket.thicket.Thicket object at 0x2b8b7398e880>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
print(gbs.keys())
# Out:
# dict_keys(['mpi_sorted_strong', 'mpi_sorted_weak', 'mpi_reverse_strong', 'mpi_reverse_weak', 'mpi_random_strong', 'mpi_random_weak', 'mpi_perturbed_strong', 'mpi_perturbed_weak', 'cuda_sorted_strong', 'cuda_sorted_weak', 'cuda_reverse_strong', 'cuda_reverse_weak', 'cuda_random_strong', 'cuda_random_weak', 'cuda_perturbed_strong', 'cuda_perturbed_weak'])

# %%
ctks = {}

for i in gbs.keys():
#     if "strong" in i:
    if "mpi" in i:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="num_procs"
        )
    else:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="num_threads"
        )

# %%
valsPerProcList = ctks["mpi_random_weak"].dataframe.columns.get_level_values(0).unique().drop("name")

# %%
valsPerBlockList = ctks["cuda_random_weak"].dataframe.columns.get_level_values(0).unique().drop("name")

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
for i in ctks.keys():
    if "cuda" in i:
        if "strong" in i:
            for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(inputSize, "nid"), (inputSize, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

        else:
            for valPerBlock in valsPerBlockList: #[32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(valPerBlock, "nid"), (valPerBlock, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

    else:
        if "strong" in i:
            for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(inputSize, "nid"), (inputSize, "spot.channel")], axis=1)

            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
            
        else: 
            for valPerProc in valsPerProcList: #[65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(valPerProc, "nid"), (valPerProc, "spot.channel")], axis=1)

            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

# %%
ctks["cuda_sorted_weak"].dataframe
# Out:
#                                          32                              \
#                               Min time/rank Max time/rank Avg time/rank
# name              num_threads
# main              64                    NaN           NaN           NaN
#                   128                   NaN           NaN           NaN
#                   256                   NaN           NaN           NaN
#                   512                   NaN           NaN           NaN
#                   1024             0.550978      0.550978      0.550978
# comm              64                    NaN           NaN           NaN
#                   128                   NaN           NaN           NaN
#                   256                   NaN           NaN           NaN
#                   512                   NaN           NaN           NaN
#                   1024             0.000418      0.000418      0.000418
# comm_large        64                    NaN           NaN           NaN
#                   128                   NaN           NaN           NaN
#                   256                   NaN           NaN           NaN
#                   512                   NaN           NaN           NaN
#                   1024             0.000170      0.000170      0.000170
# cudaMemcpy        64                    NaN           NaN           NaN
#                   128                   NaN           NaN           NaN
#                   256                   NaN           NaN           NaN
#                   512                   NaN           NaN           NaN
#                   1024             0.000137      0.000137      0.000137
# comm_small        64                    NaN           NaN           NaN
#                   128                   NaN           NaN           NaN
#                   256                   NaN           NaN           NaN
#                   512                   NaN           NaN           NaN
#                   1024             0.000141      0.000141      0.000141
# cudaMemcpy        64                    NaN           NaN           NaN
#                   128                   NaN           NaN           NaN
#                   256                   NaN           NaN           NaN
#                   512                   NaN           NaN           NaN
#                   1024             0.000094      0.000094      0.000094
# comp              64                    NaN           NaN           NaN
#                   128                   NaN           NaN           NaN
#                   256                   NaN           NaN           NaN
#                   512                   NaN           NaN           NaN
#                   1024             0.000267      0.000267      0.000267
# comp_large        64                    NaN           NaN           NaN
#                   128                   NaN           NaN           NaN
#                   256                   NaN           NaN           NaN
#                   512                   NaN           NaN           NaN
#                   1024             0.000140      0.000140      0.000140
# comp_small        64                    NaN           NaN           NaN
#                   128                   NaN           NaN           NaN
#                   256                   NaN           NaN           NaN
#                   512                   NaN           NaN           NaN
#                   1024             0.000053      0.000053      0.000053
# correctness_check 64                    NaN           NaN           NaN
#                   128                   NaN           NaN           NaN
#                   256                   NaN           NaN           NaN
#                   512                   NaN           NaN           NaN
#                   1024             0.000121      0.000121      0.000121
# data_init         64                    NaN           NaN           NaN
#                   128                   NaN           NaN           NaN
#                   256                   NaN           NaN           NaN
#                   512                   NaN           NaN           NaN
#                   1024             0.000145      0.000145      0.000145
#
#                                                                               \
#                               Total time Avg GPU time/rank Min GPU time/rank
# name              num_threads
# main              64                 NaN               NaN               NaN
#                   128                NaN               NaN               NaN
#                   256                NaN               NaN               NaN
#                   512                NaN               NaN               NaN
#                   1024          0.550978          0.201611          0.201611
# comm              64                 NaN               NaN               NaN
#                   128                NaN               NaN               NaN
#                   256                NaN               NaN               NaN
#                   512                NaN               NaN               NaN
#                   1024          0.000418          0.000035          0.000035
# comm_large        64                 NaN               NaN               NaN
#                   128                NaN               NaN               NaN
#                   256                NaN               NaN               NaN
#                   512                NaN               NaN               NaN
#                   1024          0.000170          0.000026          0.000026
# cudaMemcpy        64                 NaN               NaN               NaN
#                   128                NaN               NaN               NaN
#                   256                NaN               NaN               NaN
#                   512                NaN               NaN               NaN
#                   1024          0.000137          0.000026          0.000026
# comm_small        64                 NaN               NaN               NaN
#                   128                NaN               NaN               NaN
#                   256                NaN               NaN               NaN
#                   512                NaN               NaN               NaN
#                   1024          0.000141          0.000009          0.000009
# cudaMemcpy        64                 NaN               NaN               NaN
#                   128                NaN               NaN               NaN
#                   256                NaN               NaN               NaN
#                   512                NaN               NaN               NaN
#                   1024          0.000094          0.000009          0.000009
# comp              64                 NaN               NaN               NaN
#                   128                NaN               NaN               NaN
#                   256                NaN               NaN               NaN
#                   512                NaN               NaN               NaN
#                   1024          0.000267          0.201576          0.201576
# comp_large        64                 NaN               NaN               NaN
#                   128                NaN               NaN               NaN
#                   256                NaN               NaN               NaN
#                   512                NaN               NaN               NaN
#                   1024          0.000140          0.201576          0.201576
# comp_small        64                 NaN               NaN               NaN
#                   128                NaN               NaN               NaN
#                   256                NaN               NaN               NaN
#                   512                NaN               NaN               NaN
#                   1024          0.000053               NaN               NaN
# correctness_check 64                 NaN               NaN               NaN
#                   128                NaN               NaN               NaN
#                   256                NaN               NaN               NaN
#                   512                NaN               NaN               NaN
#                   1024          0.000121               NaN               NaN
# data_init         64                 NaN               NaN               NaN
#                   128                NaN               NaN               NaN
#                   256                NaN               NaN               NaN
#                   512                NaN               NaN               NaN
#                   1024          0.000145               NaN               NaN
#
#                                                                           64  \
#                               Max GPU time/rank Total GPU time Min time/rank
# name              num_threads
# main              64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN      0.433502
#                   1024                 0.201611       0.201611      0.542293
# comm              64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN      0.000386
#                   1024                 0.000035       0.000035      0.000498
# comm_large        64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN      0.000157
#                   1024                 0.000026       0.000026      0.000240
# cudaMemcpy        64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN      0.000127
#                   1024                 0.000026       0.000026      0.000207
# comm_small        64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN      0.000132
#                   1024                 0.000009       0.000009      0.000150
# cudaMemcpy        64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN      0.000090
#                   1024                 0.000009       0.000009      0.000102
# comp              64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN      0.000353
#                   1024                 0.201576       0.201576      0.000383
# comp_large        64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN      0.000117
#                   1024                 0.201576       0.201576      0.000135
# comp_small        64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN      0.000171
#                   1024                      NaN            NaN      0.000172
# correctness_check 64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN      0.000112
#                   1024                      NaN            NaN      0.000204
# data_init         64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN      0.000123
#                   1024                      NaN            NaN      0.000246
#
#                                                                       \
#                               Max time/rank Avg time/rank Total time
# name              num_threads
# main              64                    NaN           NaN        NaN
#                   128                   NaN           NaN        NaN
#                   256                   NaN           NaN        NaN
#                   512              0.433502      0.433502   0.433502
#                   1024             0.542293      0.542293   0.542293
# comm              64                    NaN           NaN        NaN
#                   128                   NaN           NaN        NaN
#                   256                   NaN           NaN        NaN
#                   512              0.000386      0.000386   0.000386
#                   1024             0.000498      0.000498   0.000498
# comm_large        64                    NaN           NaN        NaN
#                   128                   NaN           NaN        NaN
#                   256                   NaN           NaN        NaN
#                   512              0.000157      0.000157   0.000157
#                   1024             0.000240      0.000240   0.000240
# cudaMemcpy        64                    NaN           NaN        NaN
#                   128                   NaN           NaN        NaN
#                   256                   NaN           NaN        NaN
#                   512              0.000127      0.000127   0.000127
#                   1024             0.000207      0.000207   0.000207
# comm_small        64                    NaN           NaN        NaN
#                   128                   NaN           NaN        NaN
#                   256                   NaN           NaN        NaN
#                   512              0.000132      0.000132   0.000132
#                   1024             0.000150      0.000150   0.000150
# cudaMemcpy        64                    NaN           NaN        NaN
#                   128                   NaN           NaN        NaN
#                   256                   NaN           NaN        NaN
#                   512              0.000090      0.000090   0.000090
#                   1024             0.000102      0.000102   0.000102
# comp              64                    NaN           NaN        NaN
#                   128                   NaN           NaN        NaN
#                   256                   NaN           NaN        NaN
#                   512              0.000353      0.000353   0.000353
#                   1024             0.000383      0.000383   0.000383
# comp_large        64                    NaN           NaN        NaN
#                   128                   NaN           NaN        NaN
#                   256                   NaN           NaN        NaN
#                   512              0.000117      0.000117   0.000117
#                   1024             0.000135      0.000135   0.000135
# comp_small        64                    NaN           NaN        NaN
#                   128                   NaN           NaN        NaN
#                   256                   NaN           NaN        NaN
#                   512              0.000171      0.000171   0.000171
#                   1024             0.000172      0.000172   0.000172
# correctness_check 64                    NaN           NaN        NaN
#                   128                   NaN           NaN        NaN
#                   256                   NaN           NaN        NaN
#                   512              0.000112      0.000112   0.000112
#                   1024             0.000204      0.000204   0.000204
# data_init         64                    NaN           NaN        NaN
#                   128                   NaN           NaN        NaN
#                   256                   NaN           NaN        NaN
#                   512              0.000123      0.000123   0.000123
#                   1024             0.000246      0.000246   0.000246
#
#                                                                    \
#                               Avg GPU time/rank Min GPU time/rank
# name              num_threads
# main              64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                  0.082198          0.082198
#                   1024                 0.203626          0.203626
# comm              64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                  0.000038          0.000038
#                   1024                 0.000057          0.000057
# comm_large        64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                  0.000027          0.000027
#                   1024                 0.000046          0.000046
# cudaMemcpy        64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                  0.000027          0.000027
#                   1024                 0.000046          0.000046
# comm_small        64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                  0.000011          0.000011
#                   1024                 0.000010          0.000010
# cudaMemcpy        64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                  0.000011          0.000011
#                   1024                 0.000010          0.000010
# comp              64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                  0.082160          0.082160
#                   1024                 0.203570          0.203570
# comp_large        64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                  0.082160          0.082160
#                   1024                 0.203570          0.203570
# comp_small        64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# correctness_check 64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# data_init         64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
#
#                                                                          128  \
#                               Max GPU time/rank Total GPU time Min time/rank
# name              num_threads
# main              64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN      0.392088
#                   512                  0.082198       0.082198      0.468375
#                   1024                 0.203626       0.203626      0.598581
# comm              64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN      0.000420
#                   512                  0.000038       0.000038      0.000477
#                   1024                 0.000057       0.000057      0.000666
# comm_large        64                        NaN            NaN           NaN
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN      0.
64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                  0.044643          0.044643
#                   512                  0.122441          0.122441
#                   1024                 0.260255          0.260255
# comp_small        64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# correctness_check 64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# data_init         64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
#
#                                                                          256  \
#                               Max GPU time/rank Total GPU time Min time/rank
# name              num_threads
# main              64                        NaN            NaN           NaN
#                   128                       NaN            NaN      0.396784
#                   256                  0.044689       0.044689      0.453382
#                   512                  0.122509       0.122509      0.535059
#                   1024                 0.260361       0.260361      1.145802
# comm              64                        NaN            NaN           NaN
#                   128                       NaN            NaN      0.000543
#                   256                  0.000046       0.000046      0.000664
#                   512                  0.000068       0.000068      0.000905
#                   1024                 0.000105       0.000105      0.001413
# comm_large        64                        NaN            NaN           NaN
#                   128                       NaN            NaN      0.000166
#                   256                  0.000027       0.000027      0.000228
#                   512                  0.000048       0.000048      0.000373
#                   1024                 0.000087       0.000087      0.000921
# cudaMemcpy        64                        NaN            NaN           NaN
#                   128                       NaN            NaN      0.000132
#                   256                  0.000027       0.000027      0.000198
#                   512                  0.000048       0.000048      0.000337
#                   1024                 0.000087       0.000087      0.000882
# comm_small        64                        NaN            NaN           NaN
#                   128                       NaN            NaN      0.000270
#                   256                  0.000019       0.000019      0.000337
#                   512                  0.000020       0.000020      0.000409
#                   1024                 0.000018       0.000018      0.000383
# cudaMemcpy        64                        NaN            NaN           NaN
#                   128                       NaN            NaN      0.000221
#                   256                  0.000019       0.000019      0.000296
#                   512                  0.000020       0.000020      0.000359
#                   1024                 0.000018       0.000018      0.000339
# comp              64                        NaN            NaN           NaN
#                   128                       NaN            NaN      0.001073
#                   256                  0.044643       0.044643      0.001770
#                   512                  0.122441       0.122441      0.003354
#                   1024                 0.260255       0.260255      0.003316
# comp_large        64                        NaN            NaN           NaN
#                   128                       NaN            NaN      0.000140
#                   256                  0.044643       0.044643      0.000123
#                   512                  0.122441       0.122441      0.000158
#                   1024                 0.260255       0.260255      0.000137
# comp_small        64                        NaN            NaN           NaN
#                   128                       NaN            NaN      0.000858
#                   256                       NaN            NaN      0.001584
#                   512                       NaN            NaN      0.003111
#                   1024                      NaN            NaN      0.003106
# correctness_check 64                        NaN            NaN           NaN
#                   128                       NaN            NaN      0.000112
#                   256                       NaN            NaN      0.000204
#                   512                       NaN            NaN      0.000402
#                   1024                      NaN            NaN      0.000774
# data_init         64                        NaN            NaN           NaN
#                   128                       NaN            NaN      0.000124
#                   256                       NaN            NaN      0.000228
#                   512                       NaN            NaN      0.000458
#                   1024                      NaN            NaN      0.000948
#
#                                                                       \
#                               Max time/rank Avg time/rank Total time
# name              num_threads
# main              64                    NaN           NaN        NaN
#                   128              0.396784      0.396784   0.396784
#                   256              0.453382      0.453382   0.453382
#                   512              0.535059      0.535059   0.535059
#                   1024             1.145802      1.145802   1.145802
# comm              64                    NaN           NaN        NaN
#                   128              0.000543      0.000543   0.000543
#                   256              0.000664      0.000664   0.000664
#                   512              0.000905      0.000905   0.000905
#                   1024             0.001413      0.001413   0.001413
# comm_large        64                    NaN           NaN        NaN
#                   128              0.000166      0.000166   0.000166
#                   256              0.000228      0.000228   0.000228
#                   512              0.000373      0.000373   0.000373
#                   1024             0.000921      0.000921   0.000921
# cudaMemcpy        64                    NaN           NaN        NaN
#                   128              0.000132      0.000132   0.000132
#                   256              0.000198      0.000198   0.000198
#                   512              0.000337      0.000337   0.000337
#                   1024             0.000882      0.000882   0.000882
# comm_small        64                    NaN           NaN        NaN
#                   128              0.000270      0.000270   0.000270
#                   256              0.000337      0.000337   0.000337
#                   512              0.000409      0.000409   0.000409
#                   1024             0.000383      0.000383   0.000383
# cudaMemcpy        64                    NaN           NaN        NaN
#                   128              0.000221      0.000221   0.000221
#                   256              0.000296      0.000296   0.000296
#                   512              0.000359      0.000359   0.000359
#                   1024             0.000339      0.000339   0.000339
# comp              64                    NaN           NaN        NaN
#                   128              0.001073      0.001073   0.001073
#                   256              0.001770      0.001770   0.001770
#                   512              0.003354      0.003354   0.003354
#                   1024             0.003316      0.003316   0.003316
# comp_large        64                    NaN           NaN        NaN
#                   128              0.000140      0.000140   0.000140
#                   256              0.000123      0.000123   0.000123
#                   512              0.000158      0.000158   0.000158
#                   1024             0.000137      0.000137   0.000137
# comp_small        64                    NaN           NaN        NaN
#                   128              0.000858      0.000858   0.000858
#                   256              0.001584      0.001584   0.001584
#                   512              0.003111      0.003111   0.003111
#                   1024             0.003106      0.003106   0.003106
# correctness_check 64                    NaN           NaN        NaN
#                   128              0.000112      0.000112   0.000112
#                   256              0.000204      0.000204   0.000204
#                   512              0.000402      0.000402   0.000402
#                   1024             0.000774      0.000774   0.000774
# data_init         64                    NaN           NaN        NaN
#                   128              0.000124      0.000124   0.000124
#                   256              0.000228      0.000228   0.000228
#                   512              0.000458      0.000458   0.000458
#                   1024             0.000948      0.000948   0.000948
#
#                                                                    \
#                               Avg GPU time/rank Min GPU time/rank
# name              num_threads
# main              64                        NaN               NaN
#                   128                  0.048771          0.048771
#                   256                  0.098021          0.098021
#                   512                  0.191271          0.191271
#                   1024                 0.542873          0.542873
# comm              64                        NaN               NaN
#                   128                  0.000061          0.000061
#                   256                  0.000086          0.000086
#                   512                  0.000137          0.000137
#                   1024                 0.000218          0.000218
# comm_large        64                        NaN               NaN
#                   128                  0.000026          0.000026
#                   256                  0.000046          0.000046
#                   512                  0.000087          0.000087
#                   1024                 0.000171          0.000171
# cudaMemcpy        64                        NaN               NaN
#                   128                  0.000026          0.000026
#                   256                  0.000046          0.000046
#                   512                  0.000087          0.000087
#                   1024                 0.000171          0.000171
# comm_small        64                        NaN               NaN
#                   128                  0.000035          0.000035
#                   256                  0.000040          0.000040
#                   512                  0.000049          0.000049
#                   1024                 0.000047          0.000047
# cudaMemcpy        64                        NaN               NaN
#                   128                  0.000035          0.000035
#                   256                  0.000040          0.000040
#                   512                  0.000049          0.000049
#                   1024                 0.000047          0.000047
# comp              64                        NaN               NaN
#                   128                  0.048710          0.048710
#                   256                  0.097935          0.097935
#                   512                  0.191134          0.191134
#                   1024                 0.542655          0.542655
# comp_large        64                        NaN               NaN
#                   128                  0.048710          0.048710
#                   256                  0.097935          0.097935
#                   512                  0.191134          0.191134
#                   1024                 0.542655          0.542655
# comp_small        64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# correctness_check 64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# data_init         64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
#
#                                                                          512  \
#                               Max GPU time/rank Total GPU time Min time/rank
# name              num_threads
# main              64                        NaN            NaN      0.418699
#                   128                  0.048771       0.048771      0.473075
#                   256                  0.098021       0.098021      0.669295
# ...
#                   128                  0.424709       0.424709           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN           NaN
#                   1024                      NaN            NaN           NaN
# comm_large        64                   0.001779       0.001779      0.004324
#                   128                  0.003327       0.003327           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN           NaN
#                   1024                      NaN            NaN           NaN
# cudaMemcpy        64                   0.001779       0.001779      0.004278
#                   128                  0.003327       0.003327           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN           NaN
#                   1024                      NaN            NaN           NaN
# comm_small        64                   0.419257       0.419257      1.586612
#                   128                  0.421381       0.421381           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN           NaN
#                   1024                      NaN            NaN           NaN
# cudaMemcpy        64                   0.419257       0.419257      1.586540
#                   128                  0.421381       0.421381           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN           NaN
#                   1024                      NaN            NaN           NaN
# comp              64                  27.639417      27.639417     14.827511
#                   128                 30.767906      30.767906           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN           NaN
#                   1024                      NaN            NaN           NaN
# comp_large        64                  27.639417      27.639417      0.000206
#                   128                 30.767906      30.767906           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN           NaN
#                   1024                      NaN            NaN           NaN
# comp_small        64                        NaN            NaN     14.827181
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN           NaN
#                   1024                      NaN            NaN           NaN
# correctness_check 64                        NaN            NaN      0.006054
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN           NaN
#                   1024                      NaN            NaN           NaN
# data_init         64                        NaN            NaN      0.007534
#                   128                       NaN            NaN           NaN
#                   256                       NaN            NaN           NaN
#                   512                       NaN            NaN           NaN
#                   1024                      NaN            NaN           NaN
#
#                                                                        \
#                               Max time/rank Avg time/rank  Total time
# name              num_threads
# main              64             171.515349    171.515349  171.515349
#                   128                   NaN           NaN         NaN
#                   256                   NaN           NaN         NaN
#                   512                   NaN           NaN         NaN
#                   1024                  NaN           NaN         NaN
# comm              64               1.591059      1.591059    1.591059
#                   128                   NaN           NaN         NaN
#                   256                   NaN           NaN         NaN
#                   512                   NaN           NaN         NaN
#                   1024                  NaN           NaN         NaN
# comm_large        64               0.004324      0.004324    0.004324
#                   128                   NaN           NaN         NaN
#                   256                   NaN           NaN         NaN
#                   512                   NaN           NaN         NaN
#                   1024                  NaN           NaN         NaN
# cudaMemcpy        64               0.004278      0.004278    0.004278
#                   128                   NaN           NaN         NaN
#                   256                   NaN           NaN         NaN
#                   512                   NaN           NaN         NaN
#                   1024                  NaN           NaN         NaN
# comm_small        64               1.586612      1.586612    1.586612
#                   128                   NaN           NaN         NaN
#                   256                   NaN           NaN         NaN
#                   512                   NaN           NaN         NaN
#                   1024                  NaN           NaN         NaN
# cudaMemcpy        64               1.586540      1.586540    1.586540
#                   128                   NaN           NaN         NaN
#                   256                   NaN           NaN         NaN
#                   512                   NaN           NaN         NaN
#                   1024                  NaN           NaN         NaN
# comp              64              14.827511     14.827511   14.827511
#                   128                   NaN           NaN         NaN
#                   256                   NaN           NaN         NaN
#                   512                   NaN           NaN         NaN
#                   1024                  NaN           NaN         NaN
# comp_large        64               0.000206      0.000206    0.000206
#                   128                   NaN           NaN         NaN
#                   256                   NaN           NaN         NaN
#                   512                   NaN           NaN         NaN
#                   1024                  NaN           NaN         NaN
# comp_small        64              14.827181     14.827181   14.827181
#                   128                   NaN           NaN         NaN
#                   256                   NaN           NaN         NaN
#                   512                   NaN           NaN         NaN
#                   1024                  NaN           NaN         NaN
# correctness_check 64               0.006054      0.006054    0.006054
#                   128                   NaN           NaN         NaN
#                   256                   NaN           NaN         NaN
#                   512                   NaN           NaN         NaN
#                   1024                  NaN           NaN         NaN
# data_init         64               0.007534      0.007534    0.007534
#                   128                   NaN           NaN         NaN
#                   256                   NaN           NaN         NaN
#                   512                   NaN           NaN         NaN
#                   1024                  NaN           NaN         NaN
#
#                                                                    \
#                               Avg GPU time/rank Min GPU time/rank
# name              num_threads
# main              64                 156.027924        156.027924
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# comm              64                   1.588230          1.588230
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# comm_large        64                   0.003238          0.003238
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# cudaMemcpy        64                   0.003238          0.003238
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# comm_small        64                   1.584991          1.584991
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# cudaMemcpy        64                   1.584991          1.584991
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# comp              64                 154.439694        154.439694
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# comp_large        64                 154.439694        154.439694
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# comp_small        64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# correctness_check 64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
# data_init         64                        NaN               NaN
#                   128                       NaN               NaN
#                   256                       NaN               NaN
#                   512                       NaN               NaN
#                   1024                      NaN               NaN
#
#
#                               Max GPU time/rank Total GPU time
# name              num_threads
# main              64                 156.027924     156.027924
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# comm              64                   1.588230       1.588230
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# comm_large        64                   0.003238       0.003238
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# cudaMemcpy        64                   0.003238       0.003238
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# comm_small        64                   1.584991       1.584991
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# cudaMemcpy        64                   1.584991       1.584991
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# comp              64                 154.439694     154.439694
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# comp_large        64                 154.439694     154.439694
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# comp_small        64                        NaN            NaN
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# correctness_check 64                        NaN            NaN
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN
# data_init         64                        NaN            NaN
#                   128                       NaN            NaN
#                   256                       NaN            NaN
#                   512                       NaN            NaN
#                   1024                      NaN            NaN

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %% [markdown]
# # Examples

# %%
ctks["mpi_random_strong"].dataframe.loc["main"][262144]
# Out:
#            Min time/rank  Max time/rank  Avg time/rank   Total time  \
# num_procs
# 2               0.329483       0.330581       0.330032     0.660063
# 4               0.490914       0.496598       0.493044     1.972178
# 8               0.799785       0.807662       0.804979     6.439832
# 16              0.656338       0.660717       0.658608    10.537731
# 32              1.431100       1.440347       1.435205    45.926544
# 64              1.370681       1.386167       1.377728    88.174613
# 128             1.585454       1.608739       1.595120   204.175372
# 256             1.858605       1.908185       1.885634   482.722228
# 512             2.545665       2.603312       2.576150  1318.988894
# 1024                 NaN            NaN            NaN          NaN
#
#            Variance time/rank
# num_procs
# 2                    0.000000
# 4                    0.000005
# 8                    0.000008
# 16                   0.000001
# 32                   0.000008
# 64                   0.000012
# 128                  0.000020
# 256                  0.000130
# 512                  0.000141
# 1024                      NaN

# %%
ctks.keys()
# Out:
# dict_keys(['mpi_sorted_strong', 'mpi_sorted_weak', 'mpi_reverse_strong', 'mpi_reverse_weak', 'mpi_random_strong', 'mpi_random_weak', 'mpi_perturbed_strong', 'mpi_perturbed_weak', 'cuda_sorted_strong', 'cuda_sorted_weak', 'cuda_reverse_strong', 'cuda_reverse_weak', 'cuda_random_strong', 'cuda_random_weak', 'cuda_perturbed_strong', 'cuda_perturbed_weak'])

# %%
function_names = ("main", "comm", "comp_large")

# %% [markdown]
# # MPI STRONG SCALING TIME PLOTS

# %%
for name in function_names:
    for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
        masterDF = pd.DataFrame()
        for inputType in ctks.keys():
            if("strong" in inputType and "mpi" in inputType):
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                tempDF = tempDF.rename(inputType.split('_')[1])    
                masterDF = pd.concat([masterDF, tempDF], axis=1) 
              
        if(inputSize == 16777216 and name == "comp_large"):
            print(list(masterDF["perturbed"].values))
                

        plot_pandas(
            df=masterDF,
            title="SampleSort MPI, " + str(name) + ", Sorting " + str(inputSize) + " Values, Avg time/rank",
            xlabel="Num_Procs",
            ylabel="Time (seconds)",
            loglog=True
        )
# Out:
# [1.061654, 0.511894, 0.260626, 0.134379, 0.077273, 0.050522, 0.036478, 0.02893, 0.025145, 0.024661]

# %% [markdown]
# # MPI WEAK SCALING TIME PLOTS

# %%
def count_nan(arr):
    count = 0
    for k in arr:
        if k >= 0:
            count += 1
    return count

for name in function_names:
    for inputType in ctks.keys():
        if "weak" in inputType and "mpi" in inputType:
            masterDF = pd.DataFrame()
            for inputSize in valsPerProcList: #[65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]: #[262144.0, 524288.0, 1048576.0, 2097152.0, 4194304.0]: #[256.0, 512.0, 1024.0, 2048.0, 4096.0, 8192.0, 16384.0, 32768.0, 65536.0, 131072.0, 262144.0, 524288.0, 1048576.0, 2097152.0, 4194304.0, 8388608.0, 16777216.0, 33554432.0, 67108864.0, 134217728.0]: # for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                    
                if(count_nan(tempDF.values) > 4):
                    tempDF = tempDF.rename(inputSize)    
                    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
            masterDF = masterDF.apply(lambda x: x.fillna((x.shift() + x.shift(-1)) / 2))
            
            if(name == "comp_large" and "random" in inputType):
                print(masterDF[262144])
            
            plot_pandas(
                df=masterDF,
                title="SampleSort MPI, " + str(inputType.split("_")[1]) + " Input, " + str(name) + ", Avg time/rank",
                xlabel="Num Processors",
                ylabel="Time (seconds)",
                loglog=True
            )
# Out:
# 2            NaN
# 4       0.082967
# 8       0.088221
# 16      0.093475
# 32      0.104285
# 64      0.115095
# 128     0.147607
# 256     0.180118
# 512     0.294839
# 1024    0.409560
# Name: 262144, dtype: float64

# %% [markdown]
# # CUDA STRONG SCALING TIME PLOTS

# %%
for name in function_names:
    for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
        masterDF = pd.DataFrame()
        for inputType in ctks.keys():
            if("strong" in inputType and "cuda" in inputType):
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                tempDF = tempDF.rename(inputType.split('_')[1])    
                masterDF = pd.concat([masterDF, tempDF], axis=1) 
                
        if(inputSize == 1048576 and name == "comp_large"):
            print(list(masterDF["random"].values))

        plot_pandas(
            df=masterDF,
            title="SampleSort CUDA, " + str(name) + ", Sorting " + str(inputSize) + " Values, Avg time/rank",
            xlabel="Num_Blocks",
            ylabel="Time (seconds)",
            loglog=True
        )
# Out:
# [0.000188, 0.000198, 0.000203, 0.000211, 0.000186]

# %% [markdown]
# # CUDA WEAK SCALING TIME PLOTS

# %%
def count_nan(arr):
    count = 0
    for k in arr:
        if k >= 0:
            count += 1
    return count

for name in function_names:
    for inputType in ctks.keys():
        if "weak" in inputType and "cuda" in inputType:
            masterDF = pd.DataFrame()
            for inputSize in valsPerBlockList: #[32768, 65536, 131072, 262144, 524288, 1048576, 2097152]: #[64, 128, 256, 512, 1024]: 
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                
                if(count_nan(tempDF.values) > 3):
                    tempDF = tempDF.rename(inputSize)    
                    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
            masterDF = masterDF.apply(lambda x: x.fillna((x.shift() + x.shift(-1)) / 2))

            if(name == "comp_large" and "random" in inputType):
                print(masterDF[2048])
            
            plot_pandas(
                df=masterDF,
                title="SampleSort CUDA, " + str(inputType.split("_")[1]) + " Input, " + str(name) + ", Avg time/rank",
                xlabel="Num_Blocks",
                ylabel="Time (seconds)",
                loglog=True
            )
# Out:
# 64      0.000170
# 128     0.000158
# 256     0.000152
# 512     0.000211
# 1024    0.000235
# Name: 2048, dtype: float64

# %% [markdown]
# ## Speedup

# %%
for inputType in ctks.keys():
    if("mpi" in inputType and "strong" in inputType):
        masterDF = pd.DataFrame()
        for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
            tempDF = ctks[inputType].dataframe.loc["comp_large"][(inputSize, "Avg time/rank")]
            tempDF = tempDF.rename(inputSize)    
            masterDF = pd.concat([masterDF, tempDF], axis=1) 
            

        for inputSize in masterDF.columns:
            masterDF[inputSize] = masterDF[inputSize][2] / masterDF[inputSize]
            
        if("random" in inputType):
            print(masterDF[67108864])

        plot_pandas(
            df=masterDF,
            title="SampleSort MPI, " + str(inputType.split("_")[1]) + " Input, comp_large, Speed-up",
            xlabel="Num Processors",
            ylabel="Speed-Up",
            loglog=True
        )
# Out:
# 2         1.000000
# 4         1.996593
# 8         3.934802
# 16        7.880492
# 32       15.288235
# 64       28.146272
# 128      48.279405
# 256      76.244084
# 512     106.846122
# 1024    132.411555
# Name: 67108864, dtype: float64

# %%
for inputType in ctks.keys():
    if("cuda" in inputType and "strong" in inputType):
        masterDF = pd.DataFrame()
        for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
            tempDF = ctks[inputType].dataframe.loc["main"][(inputSize, "Avg time/rank")]
            tempDF = tempDF.rename(inputSize)    
            masterDF = pd.concat([masterDF, tempDF], axis=1) 

        for inputSize in masterDF.columns:
            masterDF[inputSize] = masterDF[inputSize][64] / masterDF[inputSize]
            
        if("random" in inputType):
            print(masterDF[1048576])

        plot_pandas(
            df=masterDF,
            title="SampleSort CUDA, " + str(inputType.split("_")[1]) + " Input, main, Speed-up",
            xlabel="Num Processors",
            ylabel="Speed-Up",
            loglog=True
        )
# Out:
# 64       1.000000
# 128      3.353742
# 256      6.972866
# 512     10.304181
# 1024    10.174195
# Name: 1048576, dtype: float64
