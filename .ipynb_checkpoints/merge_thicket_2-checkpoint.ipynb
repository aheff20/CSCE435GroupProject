# %% [markdown]
# # FINAL PROJECT THICKET

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
plt.rcParams.update({'figure.max_open_warning': 0})
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

print("done")
# Out:
# done

# %% [markdown]
# Read in all the files

# %% [markdown]
# # MPI Thicket Variables

# %%
mpi_random_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/random/*.cali"))
mpi_perturbed_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/perturbed/*.cali"))
mpi_sorted_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/sorted/*.cali"))
mpi_reverse_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/mpi/reverse/*.cali"))

# %% [markdown]
# # CUDA Thicket Variables

# %%
cuda_random_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/random2/*.cali"))
cuda_perturbed_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/perturbed2/*.cali"))
cuda_sorted_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/sorted2/*.cali"))
cuda_reverse_tk = th.Thicket.from_caliperreader(glob("merge_ProjectOuts/cuda/reverse2/*.cali"))

# %%
tks = {}

tks["mpi_sorted"] = mpi_sorted_tk
tks["mpi_reverse"] = mpi_reverse_tk
tks["mpi_random"] = mpi_random_tk
tks["mpi_perturbed"] = mpi_perturbed_tk

tks["cuda_sorted"] = cuda_sorted_tk
tks["cuda_reverse"] = cuda_reverse_tk
tks["cuda_random"] = cuda_random_tk
tks["cuda_perturbed"] = cuda_perturbed_tk

# %%
for i in tks.values():
    i.statsframe.dataframe["time"] = 1

print(tks["cuda_random"].tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  ├─ 1.000 comm_large
# │  └─ 1.000 comm_small
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
# Performance data
for inputType in tks.keys():
    if "mpi" in inputType:
        tks[inputType].metadata["values_per_proc"] = tks[inputType].metadata["InputSize"] // tks[inputType].metadata["num_procs"]
        
tks["mpi_random"].metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 126739998            2.11.0-dev              16
# 135998012            2.11.0-dev              64
# 170756329            2.11.0-dev             128
# 236483369            2.11.0-dev              16
# 279833928            2.11.0-dev               2
# 391233382            2.11.0-dev              32
# 477670914            2.11.0-dev               2
# 678962140            2.11.0-dev              16
# 777157599            2.11.0-dev               8
# 777171199            2.11.0-dev              16
# 814944200            2.11.0-dev               2
# 942921705            2.11.0-dev             128
# 953649664            2.11.0-dev               2
# 973322541            2.11.0-dev               4
# 1057970717           2.11.0-dev               4
# 1081557958           2.11.0-dev               8
# 1466031684           2.11.0-dev              32
# 1470413798           2.11.0-dev              64
# 1601200366           2.11.0-dev              32
# 1686756245           2.11.0-dev              64
# 1838211885           2.11.0-dev              32
# 1841984813           2.11.0-dev             128
# 1868618761           2.11.0-dev              64
# 1913950878           2.11.0-dev               2
# 1947517922           2.11.0-dev               4
# 2197662239           2.11.0-dev               2
# 2283043990           2.11.0-dev             128
# 2455432849           2.11.0-dev               8
# 2532419756           2.11.0-dev               4
# 2563967957           2.11.0-dev              64
# 2666770009           2.11.0-dev              64
# 2716965437           2.11.0-dev               8
# 2717719667           2.11.0-dev              32
# 2749333483           2.11.0-dev               4
# 2886223632           2.11.0-dev              16
# 2921704373           2.11.0-dev              32
# 2934121856           2.11.0-dev               8
# 3070460776           2.11.0-dev             128
# 3300404828           2.11.0-dev               4
# 3597322656           2.11.0-dev               2
# 3787455050           2.11.0-dev             128
# 3794481039           2.11.0-dev               8
# 3805141186           2.11.0-dev              64
# 3928713240           2.11.0-dev             128
# 4001942517           2.11.0-dev               8
# 4003808136           2.11.0-dev               4
# 4011824924           2.11.0-dev              32
# 4146364712           2.11.0-dev              16
# 4250107605           2.11.0-dev              16
#
#                                                  spot.metrics  \
# profile
# 126739998   min#inclusive#sum#time.duration,max#inclusive#...
# 135998012   min#inclusive#sum#time.duration,max#inclusive#...
# 170756329   min#inclusive#sum#time.duration,max#inclusive#...
# 236483369   min#inclusive#sum#time.duration,max#inclusive#...
# 279833928   min#inclusive#sum#time.duration,max#inclusive#...
# 391233382   min#inclusive#sum#time.duration,max#inclusive#...
# 477670914   min#inclusive#sum#time.duration,max#inclusive#...
# 678962140   min#inclusive#sum#time.duration,max#inclusive#...
# 777157599   min#inclusive#sum#time.duration,max#inclusive#...
# 777171199   min#inclusive#sum#time.duration,max#inclusive#...
# 814944200   min#inclusive#sum#time.duration,max#inclusive#...
# 942921705   min#inclusive#sum#time.duration,max#inclusive#...
# 953649664   min#inclusive#sum#time.duration,max#inclusive#...
# 973322541   min#inclusive#sum#time.duration,max#inclusive#...
# 1057970717  min#inclusive#sum#time.duration,max#inclusive#...
# 1081557958  min#inclusive#sum#time.duration,max#inclusive#...
# 1466031684  min#inclusive#sum#time.duration,max#inclusive#...
# 1470413798  min#inclusive#sum#time.duration,max#inclusive#...
# 1601200366  min#inclusive#sum#time.duration,max#inclusive#...
# 1686756245  min#inclusive#sum#time.duration,max#inclusive#...
# 1838211885  min#inclusive#sum#time.duration,max#inclusive#...
# 1841984813  min#inclusive#sum#time.duration,max#inclusive#...
# 1868618761  min#inclusive#sum#time.duration,max#inclusive#...
# 1913950878  min#inclusive#sum#time.duration,max#inclusive#...
# 1947517922  min#inclusive#sum#time.duration,max#inclusive#...
# 2197662239  min#inclusive#sum#time.duration,max#inclusive#...
# 2283043990  min#inclusive#sum#time.duration,max#inclusive#...
# 2455432849  min#inclusive#sum#time.duration,max#inclusive#...
# 2532419756  min#inclusive#sum#time.duration,max#inclusive#...
# 2563967957  min#inclusive#sum#time.duration,max#inclusive#...
# 2666770009  min#inclusive#sum#time.duration,max#inclusive#...
# 2716965437  min#inclusive#sum#time.duration,max#inclusive#...
# 2717719667  min#inclusive#sum#time.duration,max#inclusive#...
# 2749333483  min#inclusive#sum#time.duration,max#inclusive#...
# 2886223632  min#inclusive#sum#time.duration,max#inclusive#...
# 2921704373  min#inclusive#sum#time.duration,max#inclusive#...
# 2934121856  min#inclusive#sum#time.duration,max#inclusive#...
# 3070460776  min#inclusive#sum#time.duration,max#inclusive#...
# 3300404828  min#inclusive#sum#time.duration,max#inclusive#...
# 3597322656  min#inclusive#sum#time.duration,max#inclusive#...
# 3787455050  min#inclusive#sum#time.duration,max#inclusive#...
# 3794481039  min#inclusive#sum#time.duration,max#inclusive#...
# 3805141186  min#inclusive#sum#time.duration,max#inclusive#...
# 3928713240  min#inclusive#sum#time.duration,max#inclusive#...
# 4001942517  min#inclusive#sum#time.duration,max#inclusive#...
# 4003808136  min#inclusive#sum#time.duration,max#inclusive#...
# 4011824924  min#inclusive#sum#time.duration,max#inclusive#...
# 4146364712  min#inclusive#sum#time.duration,max#inclusive#...
# 4250107605  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 126739998                                             2
# 135998012                                             2
# 170756329                                             2
# 236483369                                             2
# 279833928                                             2
# 391233382                                             2
# 477670914                                             2
# 678962140                                             2
# 777157599                                             2
# 777171199                                             2
# 814944200                                             2
# 942921705                                             2
# 953649664                                             2
# 973322541                                             2
# 1057970717                                            2
# 1081557958                                            2
# 1466031684                                            2
# 1470413798                                            2
# 1601200366                                            2
# 1686756245                                            2
# 1838211885                                            2
# 1841984813                                            2
# 1868618761                                            2
# 1913950878                                            2
# 1947517922                                            2
# 2197662239                                            2
# 2283043990                                            2
# 2455432849                                            2
# 2532419756                                            2
# 2563967957                                            2
# 2666770009                                            2
# 2716965437                                            2
# 2717719667                                            2
# 2749333483                                            2
# 2886223632                                            2
# 2921704373                                            2
# 2934121856                                            2
# 3070460776                                            2
# 3300404828                                            2
# 3597322656                                            2
# 3787455050                                            2
# 3794481039                                            2
# 3805141186                                            2
# 3928713240                                            2
# 4001942517                                            2
# 4003808136                                            2
# 4011824924                                            2
# 4146364712                                            2
# 4250107605                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 126739998   time.variance,node.order  regionprofile         spot
# 135998012   time.variance,node.order  regionprofile         spot
# 170756329   time.variance,node.order  regionprofile         spot
# 236483369   time.variance,node.order  regionprofile         spot
# 279833928   time.variance,node.order  regionprofile         spot
# 391233382   time.variance,node.order  regionprofile         spot
# 477670914   time.variance,node.order  regionprofile         spot
# 678962140   time.variance,node.order  regionprofile         spot
# 777157599   time.variance,node.order  regionprofile         spot
# 777171199   time.variance,node.order  regionprofile         spot
# 814944200   time.variance,node.order  regionprofile         spot
# 942921705   time.variance,node.order  regionprofile         spot
# 953649664   time.variance,node.order  regionprofile         spot
# 973322541   time.variance,node.order  regionprofile         spot
# 1057970717  time.variance,node.order  regionprofile         spot
# 1081557958  time.variance,node.order  regionprofile         spot
# 1466031684  time.variance,node.order  regionprofile         spot
# 1470413798  time.variance,node.order  regionprofile         spot
# 1601200366  time.variance,node.order  regionprofile         spot
# 1686756245  time.variance,node.order  regionprofile         spot
# 1838211885  time.variance,node.order  regionprofile         spot
# 1841984813  time.variance,node.order  regionprofile         spot
# 1868618761  time.variance,node.order  regionprofile         spot
# 1913950878  time.variance,node.order  regionprofile         spot
# 1947517922  time.variance,node.order  regionprofile         spot
# 2197662239  time.variance,node.order  regionprofile         spot
# 2283043990  time.variance,node.order  regionprofile         spot
# 2455432849  time.variance,node.order  regionprofile         spot
# 2532419756  time.variance,node.order  regionprofile         spot
# 2563967957  time.variance,node.order  regionprofile         spot
# 2666770009  time.variance,node.order  regionprofile         spot
# 2716965437  time.variance,node.order  regionprofile         spot
# 2717719667  time.variance,node.order  regionprofile         spot
# 2749333483  time.variance,node.order  regionprofile         spot
# 2886223632  time.variance,node.order  regionprofile         spot
# 2921704373  time.variance,node.order  regionprofile         spot
# 2934121856  time.variance,node.order  regionprofile         spot
# 3070460776  time.variance,node.order  regionprofile         spot
# 3300404828  time.variance,node.order  regionprofile         spot
# 3597322656  time.variance,node.order  regionprofile         spot
# 3787455050  time.variance,node.order  regionprofile         spot
# 3794481039  time.variance,node.order  regionprofile         spot
# 3805141186  time.variance,node.order  regionprofile         spot
# 3928713240  time.variance,node.order  regionprofile         spot
# 4001942517  time.variance,node.order  regionprofile         spot
# 4003808136  time.variance,node.order  regionprofile         spot
# 4011824924  time.variance,node.order  regionprofile         spot
# 4146364712  time.variance,node.order  regionprofile         spot
# 4250107605  time.variance,node.order  regionprofile         spot
#
#            spot:node.order                            spot:output  \
# profile
# 126739998             true     cali_recent_2/p16-a1048576-tp.cali
# 135998012             true     cali_recent_2/p64-a1048576-tp.cali
# 170756329             true  cali_recent_2/p128-a268435456-tp.cali
# 236483369             true    cali_recent_2/p16-a16777216-tp.cali
# 279833928             true    cali_recent_2/p2-a268435456-tp.cali
# 391233382             true       cali_recent_2/p32-a65536-tp.cali
# 477670914             true        cali_recent_2/p2-a65536-tp.cali
# 678962140             true      cali_recent_2/p16-a262144-tp.cali
# 777157599             true    cali_recent_2/p8-a268435456-tp.cali
# 777171199             true    cali_recent_2/p16-a67108864-tp.cali
# 814944200             true      cali_recent_2/p2-a1048576-tp.cali
# 942921705             true    cali_recent_2/p128-a1048576-tp.cali
# 953649664             true     cali_recent_2/p2-a67108864-tp.cali
# 973322541             true      cali_recent_2/p4-a4194304-tp.cali
# 1057970717            true       cali_recent_2/p4-a262144-tp.cali
# 1081557958            true      cali_recent_2/p8-a1048576-tp.cali
# 1466031684            true     cali_recent_2/p32-a4194304-tp.cali
# 1470413798            true    cali_recent_2/p64-a67108864-tp.cali
# 1601200366            true     cali_recent_2/p32-a1048576-tp.cali
# 1686756245            true   cali_recent_2/p64-a268435456-tp.cali
# 1838211885            true      cali_recent_2/p32-a262144-tp.cali
# 1841984813            true    cali_recent_2/p128-a4194304-tp.cali
# 1868618761            true     cali_recent_2/p64-a4194304-tp.cali
# 1913950878            true      cali_recent_2/p2-a4194304-tp.cali
# 1947517922            true        cali_recent_2/p4-a65536-tp.cali
# 2197662239            true     cali_recent_2/p2-a16777216-tp.cali
# 2283043990            true     cali_recent_2/p128-a262144-tp.cali
# 2455432849            true      cali_recent_2/p8-a4194304-tp.cali
# 2532419756            true      cali_recent_2/p4-a1048576-tp.cali
# 2563967957            true    cali_recent_2/p64-a16777216-tp.cali
# 2666770009            true      cali_recent_2/p64-a262144-tp.cali
# 2716965437            true     cali_recent_2/p8-a16777216-tp.cali
# 2717719667            true    cali_recent_2/p32-a67108864-tp.cali
# 2749333483            true    cali_recent_2/p4-a268435456-tp.cali
# 2886223632            true       cali_recent_2/p16-a65536-tp.cali
# 2921704373            true    cali_recent_2/p32-a16777216-tp.cali
# 3597322656     [./merge_mpi, 262144, p]       c          2     262144
# 3787455050      [./merge_mpi, 65536, p]       c        128      65536
# 3794481039     [./merge_mpi, 262144, p]       c          8     262144
# 3805141186      [./merge_mpi, 65536, p]       c         64      65536
# 3928713240   [./merge_mpi, 16777216, p]       c        128   16777216
# 4001942517   [./merge_mpi, 67108864, p]       c          8   67108864
# 4003808136   [./merge_mpi, 16777216, p]       c          4   16777216
# 4011824924  [./merge_mpi, 268435456, p]       c         32  268435456
# 4146364712  [./merge_mpi, 268435456, p]       c         16  268435456
# 4250107605    [./merge_mpi, 4194304, p]       c         16    4194304
#
#              Algorithm Datatype  SizeOfDatatype     InputType  \
# profile
# 126739998   merge_sort    float               4  random_array
# 135998012   merge_sort    float               4  random_array
# 170756329   merge_sort    float               4  random_array
# 236483369   merge_sort    float               4  random_array
# 279833928   merge_sort    float               4  random_array
# 391233382   merge_sort    float               4  random_array
# 477670914   merge_sort    float               4  random_array
# 678962140   merge_sort    float               4  random_array
# 777157599   merge_sort    float               4  random_array
# 777171199   merge_sort    float               4  random_array
# 814944200   merge_sort    float               4  random_array
# 942921705   merge_sort    float               4  random_array
# 953649664   merge_sort    float               4  random_array
# 973322541   merge_sort    float               4  random_array
# 1057970717  merge_sort    float               4  random_array
# 1081557958  merge_sort    float               4  random_array
# 1466031684  merge_sort    float               4  random_array
# 1470413798  merge_sort    float               4  random_array
# 1601200366  merge_sort    float               4  random_array
# 1686756245  merge_sort    float               4  random_array
# 1838211885  merge_sort    float               4  random_array
# 1841984813  merge_sort    float               4  random_array
# 1868618761  merge_sort    float               4  random_array
# 1913950878  merge_sort    float               4  random_array
# 1947517922  merge_sort    float               4  random_array
# 2197662239  merge_sort    float               4  random_array
# 2283043990  merge_sort    float               4  random_array
# 2455432849  merge_sort    float               4  random_array
# 2532419756  merge_sort    float               4  random_array
# 2563967957  merge_sort    float               4  random_array
# 2666770009  merge_sort    float               4  random_array
# 2716965437  merge_sort    float               4  random_array
# 2717719667  merge_sort    float               4  random_array
# 2749333483  merge_sort    float               4  random_array
# 2886223632  merge_sort    float               4  random_array
# 2921704373  merge_sort    float               4  random_array
# 2934121856  merge_sort    float               4  random_array
# 3070460776  merge_sort    float               4  random_array
# 3300404828  merge_sort    float               4  random_array
# 3597322656  merge_sort    float               4  random_array
# 3787455050  merge_sort    float               4  random_array
# 3794481039  merge_sort    float               4  random_array
# 3805141186  merge_sort    float               4  random_array
# 3928713240  merge_sort    float               4  random_array
# 4001942517  merge_sort    float               4  random_array
# 4003808136  merge_sort    float               4  random_array
# 4011824924  merge_sort    float               4  random_array
# 4146364712  merge_sort    float               4  random_array
# 4250107605  merge_sort    float               4  random_array
#
#            ProgrammingModel MPI_Reduce-master_initialization_time  \
# profile
# 126739998               MPI                             data_init
# 135998012               MPI                             data_init
# 170756329               MPI                             data_init
# 236483369               MPI                             data_init
# 279833928               MPI                             data_init
# 391233382               MPI                             data_init
# 477670914               MPI                             data_init
# 678962140               MPI                             data_init
# 777157599               MPI                             data_init
# 777171199               MPI                             data_init
# 814944200               MPI                             data_init
# 942921705               MPI                             data_init
# 953649664               MPI                             data_init
# 973322541               MPI                             data_init
# 1057970717              MPI                             data_init
# 1081557958              MPI                             data_init
# 1466031684              MPI                             data_init
# 1470413798              MPI                             data_init
# 1601200366              MPI                             data_init
# 1686756245              MPI                             data_init
# 1838211885              MPI                             data_init
# 1841984813              MPI                             data_init
# 1868618761              MPI                             data_init
# 1913950878              MPI                             data_init
# 1947517922              MPI                             data_init
# 2197662239              MPI                             data_init
# 2283043990              MPI                             data_init
# 2455432849              MPI                             data_init
# 2532419756              MPI                             data_init
# 2563967957              MPI                             data_init
# 2666770009              MPI                             data_init
# 2716965437              MPI                             data_init
# 2717719667              MPI                             data_init
# 2749333483              MPI                             data_init
# 2886223632              MPI                             data_init
# 2921704373              MPI                             data_init
# 2934121856              MPI                             data_init
# 3070460776              MPI                             data_init
# 3300404828              MPI                             data_init
# 3597322656              MPI                             data_init
# 3787455050              MPI                             data_init
# 3794481039              MPI                             data_init
# 3805141186              MPI                             data_init
# 3928713240              MPI                             data_init
# 4001942517              MPI                             data_init
# 4003808136              MPI                             data_init
# 4011824924              MPI                             data_init
# 4146364712              MPI                             data_init
# 4250107605              MPI                             data_init
#
#            MPI_Reduce-master_send_time MPI_Reduce-master_receive_time  \
# profile
# 126739998                         comm          comm_large_MPI_Gather
# 135998012                         comm          comm_large_MPI_Gather
# 170756329                         comm          comm_large_MPI_Gather
# 236483369                         comm          comm_large_MPI_Gather
# 279833928                         comm          comm_large_MPI_Gather
# 391233382                         comm          comm_large_MPI_Gather
# 477670914                         comm          comm_large_MPI_Gather
# 678962140                         comm          comm_large_MPI_Gather
# 777157599                         comm          comm_large_MPI_Gather
# 777171199                         comm          comm_large_MPI_Gather
# 814944200                         comm          comm_large_MPI_Gather
# 942921705                         comm          comm_large_MPI_Gather
# 953649664                         comm          comm_large_MPI_Gather
# 973322541                         comm          comm_large_MPI_Gather
# 1057970717                        comm          comm_large_MPI_Gather
# 1081557958                        comm          comm_large_MPI_Gather
# 1466031684                        comm          comm_large_MPI_Gather
# 1470413798                        comm          comm_large_MPI_Gather
# 1601200366                        comm          comm_large_MPI_Gather
# 1686756245                        comm          comm_large_MPI_Gather
# 1838211885                        comm          comm_large_MPI_Gather
# 1841984813                        comm          comm_large_MPI_Gather
# 1868618761                        comm          comm_large_MPI_Gather
# 1913950878                        comm          comm_large_MPI_Gather
# 1947517922                        comm          comm_large_MPI_Gather
# 2197662239                        comm          comm_large_MPI_Gather
# 2283043990                        comm          comm_large_MPI_Gather
# 2455432849                        comm          comm_large_MPI_Gather
# 2532419756                        comm          comm_large_MPI_Gather
# 2563967957                        comm          comm_large_MPI_Gather
# 2666770009                        comm          comm_large_MPI_Gather
# 2716965437                        comm          comm_large_MPI_Gather
# 2717719667                        comm          comm_large_MPI_Gather
# 2749333483                        comm          comm_large_MPI_Gather
# 2886223632                        comm          comm_large_MPI_Gather
# 2921704373                        comm          comm_large_MPI_Gather
# 2934121856                        comm          comm_large_MPI_Gather
# 3070460776                        comm          comm_large_MPI_Gather
# 3300404828                        comm          comm_large_MPI_Gather
# 3597322656                        comm          comm_large_MPI_Gather
# 3787455050                        comm          comm_large_MPI_Gather
# 3794481039                        comm          comm_large_MPI_Gather
# 3805141186                        comm          comm_large_MPI_Gather
# 3928713240                        comm          comm_large_MPI_Gather
# 4001942517                        comm          comm_large_MPI_Gather
# 4003808136                        comm          comm_large_MPI_Gather
# 4011824924                        comm          comm_large_MPI_Gather
# 4146364712                        comm          comm_large_MPI_Gather
# 4250107605                        comm          comm_large_MPI_Gather
#
#             group_num num_threads num_blocks implementation_source  \
# profile
# 126739998           1         N/A        N/A             Online/AI
# 135998012           1         N/A        N/A             Online/AI
# 170756329           1         N/A        N/A             Online/AI
# 236483369           1         N/A        N/A             Online/AI
# 279833928           1         N/A        N/A             Online/AI
# 391233382           1         N/A        N/A             Online/AI
# 477670914           1         N/A        N/A             Online/AI
# 678962140           1         N/A        N/A             Online/AI
# 777157599           1         N/A        N/A             Online/AI
# 777171199           1         N/A        N/A             Online/AI
# 814944200           1         N/A        N/A             Online/AI
# 942921705           1         N/A        N/A             Online/AI
# 953649664           1         N/A        N/A             Online/AI
# 973322541           1         N/A        N/A             Online/AI
# 1057970717          1         N/A        N/A             Online/AI
# 1081557958          1         N/A        N/A             Online/AI
# 1466031684          1         N/A        N/A             Online/AI
# 1470413798          1         N/A        N/A             Online/AI
# 1601200366          1         N/A        N/A             Online/AI
# 1686756245          1         N/A        N/A             Online/AI
# 1838211885          1         N/A        N/A             Online/AI
# 1841984813          1         N/A        N/A             Online/AI
# 1868618761          1         N/A        N/A             Online/AI
# 1913950878          1         N/A        N/A             Online/AI
# 1947517922          1         N/A        N/A             Online/AI
# 2197662239          1         N/A        N/A             Online/AI
# 2283043990          1         N/A        N/A             Online/AI
# 2455432849          1         N/A        N/A             Online/AI
# 2532419756          1         N/A        N/A             Online/AI
# 2563967957          1         N/A        N/A             Online/AI
# 2666770009          1         N/A        N/A             Online/AI
# 2716965437          1         N/A        N/A             Online/AI
# 2717719667          1         N/A        N/A             Online/AI
# 2749333483          1         N/A        N/A             Online/AI
# 2886223632          1         N/A        N/A             Online/AI
# 2921704373          1         N/A        N/A             Online/AI
# 2934121856          1         N/A        N/A             Online/AI
# 3070460776          1         N/A        N/A             Online/AI
# 3300404828          1         N/A        N/A             Online/AI
# 3597322656          1         N/A        N/A             Online/AI
# 3787455050          1         N/A        N/A             Online/AI
# 3794481039          1         N/A        N/A             Online/AI
# 3805141186          1         N/A        N/A             Online/AI
# 3928713240          1         N/A        N/A             Online/AI
# 4001942517          1         N/A        N/A             Online/AI
# 4003808136          1         N/A        N/A             Online/AI
# 4011824924          1         N/A        N/A             Online/AI
# 4146364712          1         N/A        N/A             Online/AI
# 4250107605          1         N/A        N/A             Online/AI
#
#            MPI_Reduce-worker_comm_MPI_Barrier MPI_Reduce-worker_comp_large  \
# profile
# 126739998                    comm_MPI_Barrier                   comp_large
# 135998012                    comm_MPI_Barrier                   comp_large
# 170756329                    comm_MPI_Barrier                   comp_large
# 236483369                    comm_MPI_Barrier                   comp_large
# 279833928                    comm_MPI_Barrier                   comp_large
# 391233382                    comm_MPI_Barrier                   comp_large
# 477670914                    comm_MPI_Barrier                   comp_large
# 678962140                    comm_MPI_Barrier                   comp_large
# 777157599                    comm_MPI_Barrier                   comp_large
# 777171199                    comm_MPI_Barrier                   comp_large
# 814944200                    comm_MPI_Barrier                   comp_large
# 942921705                    comm_MPI_Barrier                   comp_large
# 953649664                    comm_MPI_Barrier                   comp_large
# 973322541                    comm_MPI_Barrier                   comp_large
# 1057970717                   comm_MPI_Barrier                   comp_large
# 1081557958                   comm_MPI_Barrier                   comp_large
# 1466031684                   comm_MPI_Barrier                   comp_large
# 1470413798                   comm_MPI_Barrier                   comp_large
# 1601200366                   comm_MPI_Barrier                   comp_large
# 1686756245                   comm_MPI_Barrier                   comp_large
# 1838211885                   comm_MPI_Barrier                   comp_large
# 1841984813                   comm_MPI_Barrier                   comp_large
# 1868618761                   comm_MPI_Barrier                   comp_large
# 1913950878                   comm_MPI_Barrier                   comp_large
# 1947517922                   comm_MPI_Barrier                   comp_large
# 2197662239                   comm_MPI_Barrier                   comp_large
# 2283043990                   comm_MPI_Barrier                   comp_large
# 2455432849                   comm_MPI_Barrier                   comp_large
# 2532419756                   comm_MPI_Barrier                   comp_large
# 2563967957                   comm_MPI_Barrier                   comp_large
# 2666770009                   comm_MPI_Barrier                   comp_large
# 2716965437                   comm_MPI_Barrier                   comp_large
# 2717719667                   comm_MPI_Barrier                   comp_large
# 2749333483                   comm_MPI_Barrier                   comp_large
# 2886223632                   comm_MPI_Barrier                   comp_large
# 2921704373                   comm_MPI_Barrier                   comp_large
# 2934121856                   comm_MPI_Barrier                   comp_large
# 3070460776                   comm_MPI_Barrier                   comp_large
# 3300404828                   comm_MPI_Barrier                   comp_large
# 3597322656                   comm_MPI_Barrier                   comp_large
# 3787455050                   comm_MPI_Barrier                   comp_large
# 3794481039                   comm_MPI_Barrier                   comp_large
# 3805141186                   comm_MPI_Barrier                   comp_large
# 3928713240                   comm_MPI_Barrier                   comp_large
# 4001942517                   comm_MPI_Barrier                   comp_large
# 4003808136                   comm_MPI_Barrier                   comp_large
# 4011824924                   comm_MPI_Barrier                   comp_large
# 4146364712                   comm_MPI_Barrier                   comp_large
# 4250107605                   comm_MPI_Barrier                   comp_large
#
#             values_per_proc
# profile
# 126739998             65536
# 135998012             16384
# 170756329           2097152
# 236483369           1048576
# 279833928         134217728
# 391233382              2048
# 477670914             32768
# 678962140             16384
# 777157599          33554432
# 777171199           4194304
# 814944200            524288
# 942921705              8192
# 953649664          33554432
# 973322541           1048576
# 1057970717            65536
# 1081557958           131072
# 1466031684           131072
# 1470413798          1048576
# 1601200366            32768
# 1686756245          4194304
# 1838211885             8192
# 1841984813            32768
# 1868618761            65536
# 1913950878          2097152
# 1947517922            16384
# 2197662239          8388608
# 2283043990             2048
# 2455432849           524288
# 2532419756           262144
# 2563967957           262144
# 2666770009             4096
# {32768: <thicket.thicket.Thicket object at 0x2b2315e44a00>, 65536: <thicket.thicket.Thicket object at 0x2b2315d3d220>, 131072: <thicket.thicket.Thicket object at 0x2b2315c74820>, 262144: <thicket.thicket.Thicket object at 0x2b2315c9fdf0>, 524288: <thicket.thicket.Thicket object at 0x2b2315e32400>, 1048576: <thicket.thicket.Thicket object at 0x2b2315412760>, 2097152: <thicket.thicket.Thicket object at 0x2b2315b91d60>, 4194304: <thicket.thicket.Thicket object at 0x2b2315ae2c40>, 16777216: <thicket.thicket.Thicket object at 0x2b2315f6da90>, 67108864: <thicket.thicket.Thicket object at 0x2b2315f3ea90>, 268435456: <thicket.thicket.Thicket object at 0x2b2315e9b610>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
print(gbs.keys())
# Out:
# dict_keys(['mpi_sorted_strong', 'mpi_sorted_weak', 'mpi_reverse_strong', 'mpi_reverse_weak', 'mpi_random_strong', 'mpi_random_weak', 'mpi_perturbed_strong', 'mpi_perturbed_weak', 'cuda_sorted_strong', 'cuda_sorted_weak', 'cuda_reverse_strong', 'cuda_reverse_weak', 'cuda_random_strong', 'cuda_random_weak', 'cuda_perturbed_strong', 'cuda_perturbed_weak'])

# %%
ctks = {}

for i in gbs.keys():
#     if "strong" in i:
    if "mpi" in i:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="num_procs"
        )
    else:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="num_threads"
        )

# %%
valsPerProcList = ctks["mpi_random_weak"].dataframe.columns.get_level_values(0).unique().drop("name")

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
for i in ctks.keys():
    if "cuda" in i:
        for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
            ctks[i].dataframe = ctks[i].dataframe.drop([(inputSize, "nid"), (inputSize, "spot.channel")], axis=1)
        ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
        ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

    else:
        if "strong" in i:
            for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(inputSize, "nid"), (inputSize, "spot.channel")], axis=1)

            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
            
        else: 
            for valPerProc in valsPerProcList: #[65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(valPerProc, "nid"), (valPerProc, "spot.channel")], axis=1)

            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

# %%
ctks["mpi_sorted_weak"].dataframe
# Out:
#                                512                                          \
#                      Min time/rank Max time/rank Avg time/rank  Total time
# name       num_procs
# main       2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32                  NaN           NaN           NaN         NaN
#            64                  NaN           NaN           NaN         NaN
#            128            2.850393      2.971963      2.903119  371.599183
# comm       2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32                  NaN           NaN           NaN         NaN
#            64                  NaN           NaN           NaN         NaN
#            128            0.012707      0.106925      0.059502    7.616285
# comm_large 2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32                  NaN           NaN           NaN         NaN
#            64                  NaN           NaN           NaN         NaN
#            128            0.012662      0.106872      0.059448    7.609385
# comm_small 2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32                  NaN           NaN           NaN         NaN
#            64                  NaN           NaN           NaN         NaN
#            128            0.000004      0.000005      0.000005    0.000591
# comp       2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32                  NaN           NaN           NaN         NaN
#            64                  NaN           NaN           NaN         NaN
#            128            0.000015      0.015053      0.000136    0.017440
# comp_large 2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32                  NaN           NaN           NaN         NaN
#            64                  NaN           NaN           NaN         NaN
#            128            0.015025      0.015025      0.015025    0.015025
# comp_small 2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32                  NaN           NaN           NaN         NaN
#            64                  NaN           NaN           NaN         NaN
#            128            0.000005      0.000022      0.000006    0.000737
# data_init  2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32                  NaN           NaN           NaN         NaN
#            64                  NaN           NaN           NaN         NaN
#            128            0.001713      0.001713      0.001713    0.001713
#
#                                                  1024                \
#                      Variance time/rank Min time/rank Max time/rank
# name       num_procs
# main       2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN      3.201228      3.217656
#            128                 0.000497           NaN           NaN
# comm       2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN      0.000132      0.012682
#            128                 0.001651           NaN           NaN
# comm_large 2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN      0.000090      0.012614
#            128                 0.001651           NaN           NaN
# comm_small 2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN      0.000004      0.000015
#            128                 0.000000           NaN           NaN
# comp       2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN      0.000015      0.011905
#            128                 0.000002           NaN           NaN
# comp_large 2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN      0.011884      0.011884
#            128                 0.000000           NaN           NaN
# comp_small 2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN      0.000005      0.000014
#            128                 0.000000           NaN           NaN
# data_init  2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN      0.001802      0.001802
#            128                 0.000000           NaN           NaN
#
#                                                                    \
#                      Avg time/rank  Total time Variance time/rank
# name       num_procs
# main       2                   NaN         NaN                NaN
#            4                   NaN         NaN                NaN
#            8                   NaN         NaN                NaN
#            16                  NaN         NaN                NaN
#            32                  NaN         NaN                NaN
#            64             3.207933  205.307717           0.000009
#            128                 NaN         NaN                NaN
# comm       2                   NaN         NaN                NaN
#            4                   NaN         NaN                NaN
#            8                   NaN         NaN                NaN
#            16                  NaN         NaN                NaN
#            32                  NaN         NaN                NaN
#            64             0.007012    0.448745           0.000013
#            128                 NaN         NaN                NaN
# comm_large 2                   NaN         NaN                NaN
#            4                   NaN         NaN                NaN
#            8                   NaN         NaN                NaN
#            16                  NaN         NaN                NaN
#            32                  NaN         NaN                NaN
#            64             0.006955    0.445104           0.000013
#            128                 NaN         NaN                NaN
# comm_small 2                   NaN         NaN                NaN
#            4                   NaN         NaN                NaN
#            8                   NaN         NaN                NaN
#            16                  NaN         NaN                NaN
#            32                  NaN         NaN                NaN
#            64             0.000005    0.000344           0.000000
#            128                 NaN         NaN                NaN
# comp       2                   NaN         NaN                NaN
#            4                   NaN         NaN                NaN
#            8                   NaN         NaN                NaN
#            16                  NaN         NaN                NaN
#            32                  NaN         NaN                NaN
#            64             0.000206    0.013198           0.000002
#            128                 NaN         NaN                NaN
# comp_large 2                   NaN         NaN                NaN
#            4                   NaN         NaN                NaN
#            8                   NaN         NaN                NaN
#            16                  NaN         NaN                NaN
#            32                  NaN         NaN                NaN
#            64             0.011884    0.011884           0.000000
#            128                 NaN         NaN                NaN
# comp_small 2                   NaN         NaN                NaN
#            4                   NaN         NaN                NaN
#            8                   NaN         NaN                NaN
#            16                  NaN         NaN                NaN
#            32                  NaN         NaN                NaN
#            64             0.000006    0.000408           0.000000
#            128                 NaN         NaN                NaN
# data_init  2                   NaN         NaN                NaN
#            4                   NaN         NaN                NaN
#            8                   NaN         NaN                NaN
#            16                  NaN         NaN                NaN
#            32                  NaN         NaN                NaN
#            64             0.001802    0.001802           0.000000
#            128                 NaN         NaN                NaN
#
#                               2048                                          \
#                      Min time/rank Max time/rank Avg time/rank  Total time
# name       num_procs
# main       2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32             1.656642      1.695404      1.677185   53.669927
#            64                  NaN           NaN           NaN         NaN
#            128            2.929570      3.021043      2.970989  380.286624
# comm       2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32             0.002360      0.041193      0.024250    0.776006
#            64                  NaN           NaN           NaN         NaN
#            128            0.004631      0.065054      0.035364    4.526539
# comm_large 2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32             0.002334      0.041137      0.024194    0.774224
#            64                  NaN           NaN           NaN         NaN
#            128            0.004588      0.064996      0.035309    4.519553
# comm_small 2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32             0.000004      0.000008      0.000005    0.000153
#            64                  NaN           NaN           NaN         NaN
#            128            0.000004      0.000013      0.000005    0.000611
# comp       2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32             0.000018      0.039063      0.001239    0.039660
#            64                  NaN           NaN           NaN         NaN
#            128            0.000014      0.021711      0.000188    0.024099
# comp_large 2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32             0.039039      0.039039      0.039039    0.039039
#            64                  NaN           NaN           NaN         NaN
#            128            0.021685      0.021685      0.021685    0.021685
# comp_small 2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32             0.000005      0.000007      0.000006    0.000179
#            64                  NaN           NaN           NaN         NaN
#            128            0.000005      0.000015      0.000006    0.000728
# data_init  2                   NaN           NaN           NaN         NaN
#            4                   NaN           NaN           NaN         NaN
#            8                   NaN           NaN           NaN         NaN
#            16                  NaN           NaN           NaN         NaN
#            32             0.001824      0.001824      0.001824    0.001824
#            64                  NaN           NaN           NaN         NaN
#            128            0.006806      0.006806      0.006806    0.006806
#
#                                                  4096                \
#                      Variance time/rank Min time/rank Max time/rank
# name       num_procs
# main       2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN      0.801726      0.807460
#            32                  0.000167           NaN           NaN
#            64                       NaN      3.080451      3.106495
#            128                 0.000319           NaN           NaN
# comm       2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN      0.000360      0.004997
#            32                  0.000172           NaN           NaN
#            64                       NaN      0.001790      0.034615
#            128                 0.000536           NaN           NaN
# comm_large 2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN      0.000342      0.004930
#            32                  0.000172           NaN           NaN
#            64                       NaN      0.001758      0.034561
#            128                 0.000536           NaN           NaN
# comm_small 2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN      0.000005      0.000007
#            32                  0.000000           NaN           NaN
#            64                       NaN      0.000004      0.000005
#            128                 0.000000           NaN           NaN
# comp       2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN      0.000018      0.005902
#            32                  0.000046           NaN           NaN
#            64                       NaN      0.000015      0.026514
#            128                 0.000004           NaN           NaN
# comp_large 2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN      0.005879      0.005879
#            32                  0.000000           NaN           NaN
#            64                       NaN      0.026491      0.026491
#            128                 0.000000           NaN           NaN
# comp_small 2                        NaN           NaN           NaN
#            4                        NaN           NaN           NaN
#            8                        NaN           NaN           NaN
#            16                       NaN      0.000005      0.000009
#            32                  0.000000           NaN           NaN
#            64                       NaN      0.
#            16                  NaN           NaN           NaN        NaN
#            32                  NaN           NaN           NaN        NaN
#            64                  NaN           NaN           NaN        NaN
#            128                 NaN           NaN           NaN        NaN
#
#                                              67108864                \
#                      Variance time/rank Min time/rank Max time/rank
# name       num_procs
# main       2                  34.428595           NaN           NaN
#            4                        NaN      7.078827     33.904744
#            8                  27.613252           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN           NaN           NaN
#            128                      NaN           NaN           NaN
# comm       2                   0.677007           NaN           NaN
#            4                        NaN      0.271405      6.830980
#            8                   4.606897           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN           NaN           NaN
#            128                      NaN           NaN           NaN
# comm_large 2                   0.676978           NaN           NaN
#            4                        NaN      0.271361      6.830902
#            8                   4.606869           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN           NaN           NaN
#            128                      NaN           NaN           NaN
# comm_small 2                   0.000000           NaN           NaN
#            4                        NaN      0.000005      0.000005
#            8                   0.000000           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN           NaN           NaN
#            128                      NaN           NaN           NaN
# comp       2                  34.522617           NaN           NaN
#            4                        NaN      0.000025     26.754121
#            8                  27.482849           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN           NaN           NaN
#            128                      NaN           NaN           NaN
# comp_large 2                   0.000000           NaN           NaN
#            4                        NaN     26.754075     26.754075
#            8                   0.000000           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN           NaN           NaN
#            128                      NaN           NaN           NaN
# comp_small 2                   0.000000           NaN           NaN
#            4                        NaN      0.000006      0.000006
#            8                   0.000000           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN           NaN           NaN
#            128                      NaN           NaN           NaN
# data_init  2                   0.000000           NaN           NaN
#            4                        NaN      6.519877      6.519877
#            8                   0.000000           NaN           NaN
#            16                       NaN           NaN           NaN
#            32                       NaN           NaN           NaN
#            64                       NaN           NaN           NaN
#            128                      NaN           NaN           NaN
#
#                                                                   \
#                      Avg time/rank Total time Variance time/rank
# name       num_procs
# main       2                   NaN        NaN                NaN
#            4             13.827303  55.309212         134.369359
#            8                   NaN        NaN                NaN
#            16                  NaN        NaN                NaN
#            32                  NaN        NaN                NaN
#            64                  NaN        NaN                NaN
#            128                 NaN        NaN                NaN
# comm       2                   NaN        NaN                NaN
#            4              5.150282  20.601126           7.936024
#            8                   NaN        NaN                NaN
#            16                  NaN        NaN                NaN
#            32                  NaN        NaN                NaN
#            64                  NaN        NaN                NaN
#            128                 NaN        NaN                NaN
# comm_large 2                   NaN        NaN                NaN
#            4              5.150210  20.600838           7.935935
#            8                   NaN        NaN                NaN
#            16                  NaN        NaN                NaN
#            32                  NaN        NaN                NaN
#            64                  NaN        NaN                NaN
#            128                 NaN        NaN                NaN
# comm_small 2                   NaN        NaN                NaN
#            4              0.000005   0.000015           0.000000
#            8                   NaN        NaN                NaN
#            16                  NaN        NaN                NaN
#            32                  NaN        NaN                NaN
#            64                  NaN        NaN                NaN
#            128                 NaN        NaN                NaN
# comp       2                   NaN        NaN                NaN
#            4              6.688550  26.754198         134.209048
#            8                   NaN        NaN                NaN
#            16                  NaN        NaN                NaN
#            32                  NaN        NaN                NaN
#            64                  NaN        NaN                NaN
#            128                 NaN        NaN                NaN
# comp_large 2                   NaN        NaN                NaN
#            4             26.754075  26.754075           0.000000
#            8                   NaN        NaN                NaN
#            16                  NaN        NaN                NaN
#            32                  NaN        NaN                NaN
#            64                  NaN        NaN                NaN
#            128                 NaN        NaN                NaN
# comp_small 2                   NaN        NaN                NaN
#            4              0.000006   0.000018           0.000000
#            8                   NaN        NaN                NaN
#            16                  NaN        NaN                NaN
#            32                  NaN        NaN                NaN
#            64                  NaN        NaN                NaN
#            128                 NaN        NaN                NaN
# data_init  2                   NaN        NaN                NaN
#            4              6.519877   6.519877           0.000000
#            8                   NaN        NaN                NaN
#            16                  NaN        NaN                NaN
#            32                  NaN        NaN                NaN
#            64                  NaN        NaN                NaN
#            128                 NaN        NaN                NaN
#
#                          134217728                                         \
#                      Min time/rank Max time/rank Avg time/rank Total time
# name       num_procs
# main       2              7.454507     57.272070     32.363288  64.726577
#            4                   NaN           NaN           NaN        NaN
#            8                   NaN           NaN           NaN        NaN
#            16                  NaN           NaN           NaN        NaN
#            32                  NaN           NaN           NaN        NaN
#            64                  NaN           NaN           NaN        NaN
#            128                 NaN           NaN           NaN        NaN
# comm       2              0.334614      6.946734      3.640674   7.281348
#            4                   NaN           NaN           NaN        NaN
#            8                   NaN           NaN           NaN        NaN
#            16                  NaN           NaN           NaN        NaN
#            32                  NaN           NaN           NaN        NaN
#            64                  NaN           NaN           NaN        NaN
#            128                 NaN           NaN           NaN        NaN
# comm_large 2              0.334567      6.946622      3.640594   7.281189
#            4                   NaN           NaN           NaN        NaN
#            8                   NaN           NaN           NaN        NaN
#            16                  NaN           NaN           NaN        NaN
#            32                  NaN           NaN           NaN        NaN
#            64                  NaN           NaN           NaN        NaN
#            128                 NaN           NaN           NaN        NaN
# comm_small 2              0.000005      0.000005      0.000005   0.000005
#            4                   NaN           NaN           NaN        NaN
#            8                   NaN           NaN           NaN        NaN
#            16                  NaN           NaN           NaN        NaN
#            32                  NaN           NaN           NaN        NaN
#            64                  NaN           NaN           NaN        NaN
#            128                 NaN           NaN           NaN        NaN
# comp       2              0.000041     49.902455     24.951248  49.902496
#            4                   NaN           NaN           NaN        NaN
#            8                   NaN           NaN           NaN        NaN
#            16                  NaN           NaN           NaN        NaN
#            32                  NaN           NaN           NaN        NaN
#            64                  NaN           NaN           NaN        NaN
#            128                 NaN           NaN           NaN        NaN
# comp_large 2             49.902406     49.902406     49.902406  49.902406
#            4                   NaN           NaN           NaN        NaN
#            8                   NaN           NaN           NaN        NaN
#            16                  NaN           NaN           NaN        NaN
#            32                  NaN           NaN           NaN        NaN
#            64                  NaN           NaN           NaN        NaN
#            128                 NaN           NaN           NaN        NaN
# comp_small 2              0.000006      0.000006      0.000006   0.000006
#            4                   NaN           NaN           NaN        NaN
#            8                   NaN           NaN           NaN        NaN
#            16                  NaN           NaN           NaN        NaN
#            32                  NaN           NaN           NaN        NaN
#            64                  NaN           NaN           NaN        NaN
#            128                 NaN           NaN           NaN        NaN
# data_init  2              6.524644      6.524644      6.524644   6.524644
#            4                   NaN           NaN           NaN        NaN
#            8                   NaN           NaN           NaN        NaN
#            16                  NaN           NaN           NaN        NaN
#            32                  NaN           NaN           NaN        NaN
#            64                  NaN           NaN           NaN        NaN
#            128                 NaN           NaN           NaN        NaN
#
#
#                      Variance time/rank
# name       num_procs
# main       2                 620.447382
#            4                        NaN
#            8                        NaN
#            16                       NaN
#            32                       NaN
#            64                       NaN
#            128                      NaN
# comm       2                  10.930030
#            4                        NaN
#            8                        NaN
#            16                       NaN
#            32                       NaN
#            64                       NaN
#            128                      NaN
# comm_large 2                  10.929819
#            4                        NaN
#            8                        NaN
#            16                       NaN
#            32                       NaN
#            64                       NaN
#            128                      NaN
# comm_small 2                   0.000000
#            4                        NaN
#            8                        NaN
#            16                       NaN
#            32                       NaN
#            64                       NaN
#            128                      NaN
# comp       2                 622.562725
#            4                        NaN
#            8                        NaN
#            16                       NaN
#            32                       NaN
#            64                       NaN
#            128                      NaN
# comp_large 2                   0.000000
#            4                        NaN
#            8                        NaN
#            16                       NaN
#            32                       NaN
#            64                       NaN
#            128                      NaN
# comp_small 2                   0.000000
#            4                        NaN
#            8                        NaN
#            16                       NaN
#            32                       NaN
#            64                       NaN
#            128                      NaN
# data_init  2                   0.000000
#            4                        NaN
#            8                        NaN
#            16                       NaN
#            32                       NaN
#            64                       NaN
#            128                      NaN

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %%
def plot_pandas_2(df, title, xlabel, ylabel, loglog, logy_base=10):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog,
        logy=True,  # Set the log scaling for the y-axis to True
        figsize=(10, 6)  # Set the desired figure size
    )
    plot.set_yscale('log', basey=logy_base)  # Set the base of the log scale for the y-axis
    return plot

# %% [markdown]
# # Examples

# %%
ctks["cuda_random_strong"].dataframe.loc["main"]
# Out:
#                     32768                                         \
#             Min time/rank Max time/rank Avg time/rank Total time
# num_threads
# 1                0.374171      0.374171      0.374171   0.374171
# 64               0.378449      0.378449      0.378449   0.378449
# 128              0.354759      0.354759      0.354759   0.354759
# 256              0.357512      0.357512      0.357512   0.357512
# 512              0.375736      0.375736      0.375736   0.375736
# 1024             0.363768      0.363768      0.363768   0.363768
#
#                                                                    \
#             Avg GPU time/rank Min GPU time/rank Max GPU time/rank
# num_threads
# 1                    0.016506          0.016506          0.016506
# 64                   0.015261          0.015261          0.015261
# 128                  0.014731          0.014731          0.014731
# 256                  0.014626          0.014626          0.014626
# 512                  0.014319          0.014319          0.014319
# 1024                 0.016521          0.016521          0.016521
#
#                                    65536                              \
#             Total GPU time Min time/rank Max time/rank Avg time/rank
# num_threads
# 1                 0.016506      0.385204      0.385204      0.385204
# 64                0.015261      0.370750      0.370750      0.370750
# 128               0.014731      0.386538      0.386538      0.386538
# 256               0.014626      0.386311      0.386311      0.386311
# 512               0.014319      0.393265      0.393265      0.393265
# 1024              0.016521      0.379728      0.379728      0.379728
#
#                                                                               \
#             Total time Avg GPU time/rank Min GPU time/rank Max GPU time/rank
# num_threads
# 1             0.385204          0.035945          0.035945          0.035945
# 64            0.370750          0.032383          0.032383          0.032383
# 128           0.386538          0.037306          0.037306          0.037306
# 256           0.386311          0.028699          0.028699          0.028699
# 512           0.393265          0.037451          0.037451          0.037451
# 1024          0.379728          0.031581          0.031581          0.031581
#
#                                   131072                              \
#             Total GPU time Min time/rank Max time/rank Avg time/rank
# num_threads
# 1                 0.035945      0.421857      0.421857      0.421857
# 64                0.032383      0.409491      0.409491      0.409491
# 128               0.037306      0.417716      0.417716      0.417716
# 256               0.028699      0.417758      0.417758      0.417758
# 512               0.037451      0.407406      0.407406      0.407406
# 1024              0.031581      0.401765      0.401765      0.401765
#
#                                                                               \
#             Total time Avg GPU time/rank Min GPU time/rank Max GPU time/rank
# num_threads
# 1             0.421857          0.068890          0.068890          0.068890
# 64            0.409491          0.066482          0.066482          0.066482
# 128           0.417716          0.067202          0.067202          0.067202
# 256           0.417758          0.062374          0.062374          0.062374
# 512           0.407406          0.061438          0.061438          0.061438
# 1024          0.401765          0.061020          0.061020          0.061020
#
#                                   262144                              \
#             Total GPU time Min time/rank Max time/rank Avg time/rank
# num_threads
# 1                 0.068890      0.477492      0.477492      0.477492
# 64                0.066482      0.489064      0.489064      0.489064
# 128               0.067202      0.496908      0.496908      0.496908
# 256               0.062374      0.501853      0.501853      0.501853
# 512               0.061438      0.503225      0.503225      0.503225
# 1024              0.061020      0.516213      0.516213      0.516213
#
#                                                                               \
#             Total time Avg GPU time/rank Min GPU time/rank Max GPU time/rank
# num_threads
# 1             0.477492          0.123262          0.123262          0.123262
# 64            0.489064          0.130923          0.130923          0.130923
# 128           0.496908          0.128391          0.128391          0.128391
# 256           0.501853          0.142897          0.142897          0.142897
# 512           0.503225          0.145996          0.145996          0.145996
# 1024          0.516213          0.155673          0.155673          0.155673
#
#                                   524288                              \
#             Total GPU time Min time/rank Max time/rank Avg time/rank
# num_threads
# 1                 0
#                                                                   \
#             Min time/rank Max time/rank Avg time/rank Total time
# num_threads
# 1                8.044514      8.044514      8.044514   8.044514
# 64               8.037972      8.037972      8.037972   8.037972
# 128              8.065105      8.065105      8.065105   8.065105
# 256              8.093481      8.093481      8.093481   8.093481
# 512              8.152650      8.152650      8.152650   8.152650
# 1024             8.058402      8.058402      8.058402   8.058402
#
#                                                                    \
#             Avg GPU time/rank Min GPU time/rank Max GPU time/rank
# num_threads
# 1                    7.270765          7.270765          7.270765
# 64                   7.268557          7.268557          7.268557
# 128                  7.293907          7.293907          7.293907
# 256                  7.316078          7.316078          7.316078
# 512                  7.367698          7.367698          7.367698
# 1024                 7.278667          7.278667          7.278667
#
#                            67108864                               \
#             Total GPU time      nid   spot.channel Min time/rank
# num_threads
# 1                 7.270765        1  regionprofile     31.379892
# 64                7.268557        1  regionprofile     31.286644
# 128               7.293907        1  regionprofile     31.212295
# 256               7.316078        1  regionprofile     31.347552
# 512               7.367698        1  regionprofile     31.339969
# 1024              7.278667        1  regionprofile     31.491826
#
#                                                                       \
#             Max time/rank Avg time/rank Total time Avg GPU time/rank
# num_threads
# 1               31.379892     31.379892  31.379892         29.334772
# 64              31.286644     31.286644  31.286644         29.245695
# 128             31.212295     31.212295  31.212295         29.237288
# 256             31.347552     31.347552  31.347552         29.309974
# 512             31.339969     31.339969  31.339969         29.300360
# 1024            31.491826     31.491826  31.491826         29.439270
#
#                                                                268435456  \
#             Min GPU time/rank Max GPU time/rank Total GPU time       nid
# num_threads
# 1                   29.334772         29.334772      29.334772         1
# 64                  29.245695         29.245695      29.245695         1
# 128                 29.237288         29.237288      29.237288         1
# 256                 29.309974         29.309974      29.309974         1
# 512                 29.300360         29.300360      29.300360         1
# 1024                29.439270         29.439270      29.439270         1
#
#                                                                       \
#               spot.channel Min time/rank Max time/rank Avg time/rank
# num_threads
# 1            regionprofile    125.325452    125.325452    125.325452
# 64           regionprofile    125.316419    125.316419    125.316419
# 128          regionprofile    125.099989    125.099989    125.099989
# 256          regionprofile    125.048110    125.048110    125.048110
# 512          regionprofile    125.046572    125.046572    125.046572
# 1024         regionprofile    125.236867    125.236867    125.236867
#
#                                                                                \
#              Total time Avg GPU time/rank Min GPU time/rank Max GPU time/rank
# num_threads
# 1            125.325452        118.213904        118.213904        118.213904
# 64           125.316419        118.198167        118.198167        118.198167
# 128          125.099989        117.986117        117.986117        117.986117
# 256          125.048110        117.942966        117.942966        117.942966
# 512          125.046572        118.197842        118.197842        118.197842
# 1024         125.236867        118.126362        118.126362        118.126362
#
#
#             Total GPU time
# num_threads
# 1               118.213904
# 64              118.198167
# 128             117.986117
# 256             117.942966
# 512             118.197842
# 1024            118.126362

# %%
ctks.keys()
# Out:
# dict_keys(['mpi_sorted_strong', 'mpi_sorted_weak', 'mpi_reverse_strong', 'mpi_reverse_weak', 'mpi_random_strong', 'mpi_random_weak', 'mpi_perturbed_strong', 'mpi_perturbed_weak', 'cuda_sorted_strong', 'cuda_sorted_weak', 'cuda_reverse_strong', 'cuda_reverse_weak', 'cuda_random_strong', 'cuda_random_weak', 'cuda_perturbed_strong', 'cuda_perturbed_weak'])

# %%
function_names = ("main", "comm", "comp_large")

# %% [markdown]
# # MPI STRONG SCALING TIME PLOTS

# %%
for name in function_names:
    for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
        masterDF = pd.DataFrame()
        for inputType in ctks.keys():
            if("strong" in inputType and "mpi" in inputType):
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                tempDF = tempDF.rename(inputType.split('_')[1])    
                masterDF = pd.concat([masterDF, tempDF], axis=1) 

        plot_pandas(
            df=masterDF,
            title="SampleSort MPI, " + str(name) + ", Sorting " + str(inputSize) + " Values, Avg time/rank",
            xlabel="Num_Procs",
            ylabel="Time (seconds)",
            loglog=True
        )

# %% [markdown]
# # MPI WEAK SCALING TIME PLOTS

# %%
def count_nan(arr):
    count = 0
    for k in arr:
        if k >= 0:
            count += 1
    return count

for name in function_names:
    for inputType in ctks.keys():
        if "weak" in inputType and "mpi" in inputType:
            masterDF = pd.DataFrame()
            for inputSize in valsPerProcList: #[65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]: #[262144.0, 524288.0, 1048576.0, 2097152.0, 4194304.0]: #[256.0, 512.0, 1024.0, 2048.0, 4096.0, 8192.0, 16384.0, 32768.0, 65536.0, 131072.0, 262144.0, 524288.0, 1048576.0, 2097152.0, 4194304.0, 8388608.0, 16777216.0, 33554432.0, 67108864.0, 134217728.0]: # for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                #print(tempDF)
                if(count_nan(tempDF.values) > 3):
                    tempDF = tempDF.rename(inputSize)    
                    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
                masterDF = masterDF.apply(lambda x: x.fillna((x.shift() + x.shift(-1)) / 2))
                #print(masterDF)
            plot_pandas(
                df=masterDF,
                title="SampleSort MPI, " + str(inputType.split("_")[1]) + " Input, " + str(name) + ", Avg time/rank",
                xlabel="Num Processors",
                ylabel="Time (seconds)",
                loglog=True
            )

# %% [markdown]
# # CUDA STRONG SCALING TIME PLOTS

# %%
for name in function_names:
    for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152,4194304 , 16777216,67108864]:
        masterDF = pd.DataFrame()
        for inputType in ctks.keys():
            if("strong" in inputType and "cuda" in inputType):
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                tempDF = tempDF.rename(inputType.split('_')[1])    
                masterDF = pd.concat([masterDF, tempDF], axis=1) 

        plot_pandas(
            df=masterDF,
            title="SampleSort CUDA, " + str(name) + ", Sorting " + str(inputSize) + " Values, Avg time/rank",
            xlabel="Num_Threads",
            ylabel="Time (seconds)",
            loglog=True
        )

# %% [markdown]
# # CUDA WEAK SCALING TIME PLOTS

# %%
for name in function_names:
    for inputType in ctks.keys():
        if "weak" in inputType and "cuda" in inputType:
            masterDF = pd.DataFrame()
            for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]: #[64, 128, 256, 512, 1024]: 
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                tempDF = tempDF.rename(inputSize)    
                masterDF = pd.concat([masterDF, tempDF], axis=1) 

            plot_pandas(
                df=masterDF,
                title="SampleSort CUDA, " + str(inputType.split("_")[1]) + " Input, " + str(name) + ", Avg time/rank",
                xlabel="Num_Threads",
                ylabel="Time (seconds)",
                loglog=True
            )

# %% [markdown]
# ## Speedup

# %%
for inputType in ctks.keys():
    if("mpi" in inputType and "strong" in inputType):
        masterDF = pd.DataFrame()
        for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
            tempDF = ctks[inputType].dataframe.loc["comp_large"][(inputSize, "Avg time/rank")]
            tempDF = tempDF.rename(inputSize)    
            masterDF = pd.concat([masterDF, tempDF], axis=1) 

        for inputSize in masterDF.columns:
            masterDF[inputSize] = masterDF[inputSize][2] / masterDF[inputSize]

        plot_pandas(
            df=masterDF,
            title="SampleSort MPI, " + str(inputType.split("_")[1]) + " Input, comp_large, Speed-up",
            xlabel="Num Processors",
            ylabel="Speed-Up",
            loglog=True
        )

# %%
for inputType in ctks.keys():
    if("cuda" in inputType and "strong" in inputType):
        masterDF = pd.DataFrame()
        for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
            tempDF = ctks[inputType].dataframe.loc["main"][(inputSize, "Avg time/rank")]
            tempDF = tempDF.rename(inputSize)    
            masterDF = pd.concat([masterDF, tempDF], axis=1) 

        for inputSize in masterDF.columns:
            masterDF[inputSize] = masterDF[inputSize][64] / masterDF[inputSize]

        plot_pandas(
            df=masterDF,
            title="SampleSort CUDA, " + str(inputType.split("_")[1]) + " Input, main, Speed-up",
            xlabel="Num Processors",
            ylabel="Speed-Up",
            loglog=True
        )
